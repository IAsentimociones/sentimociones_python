# %%
import requests
from bs4 import BeautifulSoup

# Obtiene el contenido web del resultado de búsqueda
url_busqueda_lyrics = "https://www.letras4u.com/search.php?hyv-search=TIAGO+PZK&Submit=Buscar"
page = requests.get(url_busqueda_lyrics)
print (page.content)
soup = BeautifulSoup(page.content, "html.parser")
#html.parser, lxml, lxml-xml, xml, html5lib
#print(soup)
# Out:
# b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd"><html xmlns="https://www.w3.org/1999/xhtml" xml:lang="es" lang="es">\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">\n<title>Busqueda: TIAGO PZK &raquo; Letras4U.com | Traducidas al Espa&ntilde;ol</title>\n<meta name="viewport" content="initial-scale=1.0,user-scalable=yes,width=device-width"/>\n<link rel="stylesheet" href="//code.jquery.com/ui/1.11.4/themes/smoothness/jquery-ui.css" type="text/css" />\n\t\t<script src="//code.jquery.com/jquery-2.1.4.js" type="text/javascript"></script>\n\t\t<script src="//code.jquery.com/ui/1.11.4/jquery-ui.js" type="text/javascript"></script>\n\t\t<script>\n\t\t  jQuery(function() {\n\t\t    jQuery( "#hyv-search" ).autocomplete({\n\t\t      source: function( request, response ) {\n\t\t      \t//console.log(request.term);\n\t\t    \tvar sqValue = [];\n\t\t        jQuery.ajax({\n\t\t\t        type: "POST",\n\t\t\t        url: "https://suggestqueries.google.com/complete/search?hl=en&ds=yt&client=youtube&hjson=t&cp=1",\n\t\t\t        dataType: \'jsonp\',\n\t\t\t        data: jQuery.extend({\n\t\t\t            q: request.term\n\t\t\t        }, {  }),\n\t\t\t        success: function(data){\n\t\t\t        \tconsole.log(data[1]);\n\t\t\t           \tobj = data[1];\n\t\t\t\t\t\tjQuery.each( obj, function( key, value ) {\n\t\t\t\t\t\t\tsqValue.push(value[0]);\n\t\t\t\t\t\t});\n\t\t\t           \tresponse( sqValue);\n\t\t\t        }\n\t\t\t    });\n\t\t      }\n\t\t    });\n\t\t  });\n\t  \t</script>\n\t<style type="text/css">\n\t\t\t.container-4 input#letrade {\n\t\t\t\twidth: 500px;\n\t\t\t\theight: 30px;\n\t\t\t\tborder: 1px solid #c6c6c6;\n\t\t\t    font-size: 10pt;\n\t\t\t    float: left;\n\t\t\t    padding-left: 15px;\n\t\t\t    -webkit-border-top-left-radius: 5px;\n\t\t\t    -webkit-border-bottom-left-radius: 5px;\n\t\t\t    -moz-border-top-left-radius: 5px;\n\t\t\t    -moz-border-bottom-left-radius: 5px;\n\t\t\t    border-top-left-radius: 5px;\n\t\t\t    border-bottom-left-radius: 5px;\n\t\t\t}\n\t\t\t.container-4 button.icon {\n\t\t\t\theight: 30px;\n\t\t\t\tbackground: #f0f0f0 url(\'https://www.letras4u.com/images/searchicon.png\') 10px 1px no-repeat;\n\t\t\t\tbackground-size: 24px;\n\t\t\t\t-webkit-border-top-right-radius: 5px;\n\t\t\t\t-webkit-border-bottom-right-radius: 5px;\n\t\t\t\t-moz-border-radius-topright: 5px;\n\t\t\t\t-moz-border-radius-bottomright: 5px;\n\t\t\t\tborder-top-right-radius: 5px;\n\t\t\t\tborder-bottom-right-radius: 5px;\n\t\t\t\tborder: 1px solid #c6c6c6;\n\t\t\t\twidth: 50px;\n\t\t\t\tmargin-left: -44px;\n\t\t\t\tcolor: #4f5b66;\n\t\t\t\tfont-size: 10pt;\n\t\t\t}\n\t  \t</style>\n<style type="text/css">body{background-color:#D7C1AC;margin:0}body,td,th{color:#000;font-family:Tahoma, Arial, Helvetica,Verdana , sans-serif;font-size:14px}#fon{max-width:888px;align:center;color:#000;background:#FFF;margin:0 auto;padding:0}#head{position:relative;height:70px;color:gray;margin:0;padding:0}form.search{position:absolute;max-width:880px;top:5px;right:0;border:none;background:#000}#main{float:left;max-width:100%;margin:0 0 0 15px;padding:0}#barra{float:left;width:20%;display:inline;margin:0;padding:0}#footer{clear:both;color:#666;padding:0}h1{font-size:14px}h2{font-size:12px}a.negro{color:#000}a.bl{color:#FFF}a.artista{color:#000;text-decoration:none}.capital{text-transform:capitalize}.cancion{font-size:16px;font-weight:700;text-transform:capitalize}a{color:#000}a:visited,active{color:#CEA682}a:hover{color:red;text-decoration:none}\n</style><link rel="Shortcut Icon" type="image/x-icon" href="https://www.letras4u.com/favicon.ico" /><script type="text/javascript">var _gaq = _gaq || [];  _gaq.push([\'_setAccount\', \'UA-1958749-22\']);  _gaq.push([\'_trackPageview\']); (function() {    var ga = document.createElement(\'script\'); ga.type = \'text/javascript\'; ga.async = true;    ga.src = (\'https:\' == document.location.prot ...

# %%
#obtiene el cuerpo del contenido autor - canción
results = soup.find(id="main")
#print(results.prettify())

# %%
#obtiene los elementos del cuerpo letra del autor - canción y parte de la letra
job_elements = results.find_all("span")
print(job_elements)
# Out:
# [<span>1. <a href="https://www.letras4u.com/bizarrap/tiago_pzk:_bzrp_music_sessions_vol_48.htm">Bizarrap - Tiago Pzk: Bzrp Music Sessions Vol. 48</a></span>, <span>2. <a href="https://www.letras4u.com/rusherking/now_ft_tiago_pzk.htm">Rusherking - Now Ft Tiago Pzk</a></span>, <span>3. <a href="https://www.letras4u.com/tiago_pzk/entre_nosotros_remix.htm">Tiago Pzk - Entre Nosotros (remix)</a></span>]

# %%
# obtiene elementos del autor, cancion y enlace donde está la letra de la canción
url_letra_cancion = ''
for job_element in job_elements:
    cancion_elem = job_element.find("a")
    print(cancion_elem.text)
    print(cancion_elem.get("href"))
# Out:
# Bizarrap - Tiago Pzk: Bzrp Music Sessions Vol. 48
# https://www.letras4u.com/bizarrap/tiago_pzk:_bzrp_music_sessions_vol_48.htm
# Rusherking - Now Ft Tiago Pzk
# https://www.letras4u.com/rusherking/now_ft_tiago_pzk.htm
# Tiago Pzk - Entre Nosotros (remix)
# https://www.letras4u.com/tiago_pzk/entre_nosotros_remix.htm

# %%
# obtiene contenido de la página web de la letra de la canción
url_letra_cancion = 'https://www.letras4u.com/bizarrap/tiago_pzk:_bzrp_music_sessions_vol_48.htm'
page_letra_cancion = requests.get(url_letra_cancion)
soup_letra_cancion = BeautifulSoup(page_letra_cancion.content, "html.parser")
#print(soup_letra_cancion)
# Out:
# <!DOCTYPE HTML>
# <html lang="es"><head><meta charset="utf-8"/><title>Tiago Pzk: Bzrp Music Sessions Vol. 48 - Bizarrap Letra  con Traducción  en Español de Ingles | Letras4u.com</title>
# <script type="application/ld+json">
# {
#   "@context":"https://schema.org",
#   "@type":"MusicRecording",
#   "byArtist": {
#     "@context":"https://schema.org",
#     "@type":"MusicGroup",
#     "name":"BIZARRAP",
#     "url":"https://www.letras4u.com/bizarrap"
#   },
#   "name":"Tiago Pzk: Bzrp Music Sessions Vol. 48",
#   "url":"https://www.letras4u.com/bizarrap/tiago_pzk:_bzrp_music_sessions_vol_48.htm"
# }
# </script><meta content="Letra Traducida de TIAGO PZK: BZRP MUSIC SESSIONS VOL. 48 (Tiago Pzk: Bzrp Music Sessions, Vol. 48) de BIZARRAP del disco  canción  TIAGO PZK: BZRP MUSIC SESSIONS VOL. 48 en Ingles traducida Español con traductor en Letras4U.com, Letras de canciones traducidas al Español gratis." name="description"><meta content="BIZARRAP, TIAGO PZK: BZRP MUSIC SESSIONS VOL. 48, traducción,traducir letra traducida, que dice, lyrics, Español" name="keywords"/><meta content="Tiago Pzk: Bzrp Music Sessions Vol. 48 - Bizarrap Letra " property="og:title"/> <meta content="https://img.youtube.com/vi/h7U8TqOVyxc/hqdefault.jpg" property="og:image"/><meta content="https://www.letras4u.com/bizarrap/tiago_pzk:_bzrp_music_sessions_vol_48.htm" property="og:url"/><link href="https://www.letras4u.com/bizarrap/tiago_pzk:_bzrp_music_sessions_vol_48.htm" rel="canonical"/>
# <link href="https://www.letras4u.com/amp/bizarrap/tiago_pzk:_bzrp_music_sessions_vol_48.htm" rel="amphtml"/> <link href="https://www.letras4u.com/bizarrap/tiago_pzk:_bzrp_music_sessions_vol_48.htm" hreflang="es" rel="alternate"/>
# <link href="https://www.letras4u.com/lyrics/bizarrap/tiago_pzk:_bzrp_music_sessions_vol_48.htm" hreflang="en" rel="alternate"/><link href="https://www.letras4u.com/favicon.ico" rel="Shortcut Icon" type="image/x-icon"/><meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/><style>
# 	body{margin:0;font-family:Programme,sans-serif;background-color:#f5f5f5}a.ex1:link{color:#fff},a.ex1:active{color:#fff}h1{color:blue;font-family:verdana;font-size:.9em}h2{color:blue;font-family:verdana;font-size:.8em}
# .nav{background-color:#87cefa;list-style:none;padding-left:0;margin:1px auto}.nav > li,.nav > li > a{display:inline-block;zoom:1}.inline-items{margin-top:0}.inline-items li{margin-left:0;border-left:1px solid #000;padding-left:10px;padding-right:10px}.inline-items li:first-child{margin-left:0;border:none;padding-left:0;padding-right:10px}.inline-items li:last-child{padding-right:0}
# table {
# background-color: #ffffff;
#   border-collapse: collapse;
#   width: 100%;
# }
#
# th, td {
#   text-align: left;
#   padding: 8px;
# }
#
# tr:nth-child(even) {background-color: #f2f2f2;}
# section{
#    background:#ffffff;
#    margin:10px auto;
#    overflow:hidden;
#    padding:10px 0;
#
#   margin-top: 5px;
#    text-align:center;
#    width:1000px;
# }
# @media screen and (max-width:1000px){
#    section{
#       width:100%;
#    }
# }
#
# @media screen and (max-width:700px){
#    article{
#       width:100%;
#    }
# }
# @media screen and (max-width:400px){
# iframe {
#     max-width: 100%;
#     height: auto;
#
# }
# </style><script async="" data-ad-client="ca-pub-1883682942130016" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script></meta></head><body>
# <center>
# <ul class="nav inline-items"><li><button class="buttons">Letras4u.com</button> <a href="https://www.letras4u.com">Letras Traducidas</a></li><li><a class="current" href="https://www.letras4u.com/populares.htm">Polulares</a></li><li><a href="https://www.letras4u.com/ultimas.htm">Últimas</a></li><li><a href="https://www.letras4u.com/videos.htm">Videos</a></li><li><a href="https://www.letras4u.com/noticias">Noticias</a></li><li><a href="https://www.letras4u.com/buscar.htm">Búsqueda</a></li><li><a href="https://www.letras4u.com/colabora.htm">Colabora</a></li><li><a href="https://www.lyrics.com.es" rel="nofollow">Music</a></li><li> <form action="https://www.letras4u.com/search.php" id="hyv-yt-search" method="get" name="hyv-yt-search" target="_top"> <input autocomplete="off" class="ui-autocomplete-input" id="hyv-search" name="hyv-search" placeholder="Search..." type="search"/><input id="hyv-searchBtn" name="Submit" type="submit" value="Buscar"/></form></li> </ul></center><br/>
# <section><script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- letras4uarriba -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1883682942130016" data-ad-format="auto" data-ad-slot="1478399363" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <div class="grid-container">
# <div class="header">
# <h1>bizarrap  tiago pzk: bzrp music sessions vol. 48  Traducida en Español</h1><p><a href="https://www.letras4u.com/bizarrap">bizarrap</a>  "tiago pzk: bzrp music sessions vol. 48" Letra Traducida -  Traducción: "<span>tiago pzk: bzrp music sessions, vol. 48</span>"   -  <br/>Aprende con Canciones de musica en Ingles y Traducida en Español <a href="https://www.quedeletras.com/canciones-2021.html" rel="nofollow" target="_blank">Quedeletrascom 2021</a>  -  <a href="https://www.letras4u.com/lyrics/bizarrap/tiago_pzk:_bzrp_music_sessions_vol_48.htm">Lyrics</a>
# </p></div>
# <script>
# /* Letras4u.com - top */
# cf_page_artist = "bizarrap";
# cf_page_song = "tiago pzk: bzrp music sessions vol. 48";
# cf_adunit_id = "39382349";
# </script>
# <script src="//srv.clickfuse.com/showads/showad.js"></script>
# <table>
# <tr valign="top">
# <td>
# <h2>Letra tiago pzk: bzrp music sessions vol. 48 Lyrics en Ingles</h2>
# <table>
# <tr>
# <td>
# ******vámono a un lugar donde no nos puedan ver (ver)</td>
# </tr>
# <tr>
# <td>
# elige el destino que yo pago el hotel (-tel)</td>
# </tr>
# <tr>
# <td>
# tengo más verde en la billetera que ayer (-yer)</td>
# </tr>
# <tr>
# <td>
# sé que hay más de un bobo que te quiere tener</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# y no, tú te fuiste conmigo</td>
# </tr>
# <tr>
# <td>
# y yo ahora estoy perdido</td>
# </tr>
# <tr>
# <td>
# amor, si me llamas, sabes que estoy-oy-oy-oy</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# bombona, todos quieren contigo, pero tú estás conmigo</td>
# </tr>
# <tr>
# <td>
# y no es casualidad, me clavó la mirá y nos fuimo</td>
# </tr>
# <tr>
# <td>
# bombona, todos quiеren contigo, pero tú estás conmigo</td>
# </tr>
# <tr>
# <td>
# y no еs casualidad, me clavó la mirá y nos fuimo</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# el biza la soltó pero el gotti la agarró</td>
# </tr>
# <tr>
# <td>
# y a la pista la partió en do, en do (el biza la sol)</td>
# </tr>
# <tr>
# <td>
# cuando piensan que sí, cuando digo que no</td>
# </tr>
# <tr>
# <td>
# soy la bestia del lápiz, como kendo</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# va-vamo a pegarno, como mis cancione</td>
# </tr>
# <tr>
# <td>
# porque si ese flow es droga, mami, yo soy al capone</td>
# </tr>
# <tr>
# <td>
# muchas dicen que no siguen esa moda que ella impone</td>
# </tr>
# <tr>
# <td>
# pero to lo que le queda bien, las nena se lo ponen</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# escucha anuel aa y se pone pila (brr)</td>
# </tr>
# <tr>
# <td>
# cuando sale por miami en la casa de argentina</td>
# </tr>
# <tr>
# <td>
# esa cintura slip pero ese c*lo está killah</td>
# </tr>
# <tr>
# <td>
# cuando ella ve cerrado el club, prende maría</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# si no lo tiene natural, yo le pago el plastic</td>
# </tr>
# <tr>
# <td>
# me tatuaría su body, shorty, porque soy fanatic</td>
# </tr>
# <tr>
# <td>
# la llaman pa un vídeo y no tiene que hacer el casting</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# loca, tirá locación solo pa darte castigo-go</td>
# </tr>
# <tr>
# <td>
# tengo lo que quieren todo</td>
# </tr>
# <tr>
# <td>
# entramo al party, lo baja slow cuando suena el dembow</td>
# </tr>
# <tr>
# <td>
# en la calle no soy Ñengo, pero saben de mi flow</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# a ella le gusta calle y yo no soy un real g</td>
# </tr>
# <tr>
# <td>
# pero sabe que conmigo va directo al v.i.p</td>
# </tr>
# <tr>
# <td>
# sabe que estoy pa hacer money pa gastarlo por ahí</td>
# </tr>
# <tr>
# <td>
# lo nuestro e un secreto, biza session twenty three</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# ¿cómo era la otra parte, biza?</td>
# </tr>
# <tr>
# <td>
# ah</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# y no, tú te fuiste conmigo</td>
# </tr>
# <tr>
# <td>
# y yo ahora estoy perdido</td>
# </tr>
# <tr>
# <td>
# amor, si me llamas, sabes que estoy-oy-oy-oy</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# bombona, todos quieren contigo, pero tú estás conmigo</td>
# </tr>
# <tr>
# <td>
# y no es casualidad, me clavó la mirá y nos fuimo</td>
# </tr>
# <tr>
# <td>
# bombona, todos quieren contigo, pero tú estás conmigo</td>
# </tr>
# <tr>
# <td>
# y no es casualidad, me clavó la mirá y nos fuimo</td>
# </tr>
# </table>
# <br/> <strong>bizarrap tiago pzk: bzrp music sessions vol. 48</strong> Lyrics Translate
# <br/><section><script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- letras4uarriba -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1883682942130016" data-ad-format="auto" data-ad-slot="1478399363" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <table>
# <tr>
# <td><h2>bizarrap traducción</h2>
# <p>******lets go to a place where they cant see us (see)</p></td>
# </tr>
# <tr>
# <td>
# choose the destination that i pay for the hotel (-tel)</td>
# </tr>
# <tr>
# <td>
# i have more green in my wallet than yesterday (-yer)</td>
# </tr>
# <tr>
# <td>
# i know there is more than one fool who wants to have you</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# and no , you left with me</td>
# </tr>
# <tr>
# <td>
# and now im lost</td>
# </tr>
# <tr>
# <td>
# love, if you call me, you know that im-oy-oy-oy</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# bombona, everyone wants with you, but youre with me</td>
# </tr>
# <tr>
# <td>
# and its no coincidence, she nailed me and we left</td>
# </tr>
# <tr>
# <td>
# bombona , you all quiеren, but you are with me</td>
# </tr>
# <tr>
# <td>
# and not еs chance, i nailed the mira and we fuimo</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# the biza let go but gotti grabbed her</td>
# </tr>
# <tr>
# <td>
# and to track the split in c in c (the biza sunshine -)</td>
# </tr>
# <tr>
# <td>
# when they think yes, when i say no</td>
# </tr>
# <tr>
# <td>
# i am the beast of the pencil, like kendo</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# va-vamo a pegarno, like my songs</td>
# </tr>
# <tr>
# <td>
# because if that flow is drug, mommy, i am al capone</td>
# </tr>
# <tr>
# <td>
# many say that they do not follow that fashion that she imposes</td>
# </tr>
# <tr>
# <td>
# but all that remains well, the girls put it on</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# listen to anuel aa and he gets on (brr)</td>
# </tr>
# <tr>
# <td>
# when he goes out in miami at the house in argentina</td>
# </tr>
# <tr>
# <td>
# that waist slip but that c * lo is killah</td>
# </tr>
# <tr>
# <td>
# when she sees the club closed, turn on maria</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# if she doesnt have it natural, i pay her the plastic</td>
# </tr>
# <tr>
# <td>
# i would tattoo her body, shorty, because i am a fan</td>
# </tr>
# <tr>
# <td>
# they call her for a video and she does not have to do the casting</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# crazy, she will throw location just to give you punishment-go</td>
# </tr>
# <tr>
# <td>
# i have what they want everything </td>
# </tr>
# <tr>
# <td>
# we enter the party, he lowers it slowly when the dembow sounds</td>
# </tr>
# <tr>
# <td>
# in the street i am not Ñengo, but they know about my flow</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# she likes the street and i am not a real g</td>
# </tr>
# <tr>
# <td>
# but she knows that with me it goes straight to the vip she</td>
# </tr>
# <tr>
# <td>
# knows that i am to do money to spend it there</td>
# </tr>
# <tr>
# <td>
# . ours is a secret, biza session twenty three</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# what was the other party like, biza?</td>
# </tr>
# <tr>
# <td>
# ah</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# and no, you left with me</td>
# </tr>
# <tr>
# <td>
# and now im lost</td>
# </tr>
# <tr>
# <td>
# love, if you call me, you know im-oy-oy-oy</td>
# </tr>
# <tr>
# <td>
# </td>
# </tr>
# <tr>
# <td>
# bombona, everyone wants with you, but youre with</td>
# </tr>
# <tr>
# <td>
# me we went </td>
# </tr>
# <tr>
# <td>
# bombona, everyone wants you, but you are with me</td>
# </tr>
# <tr>
# <td>
# and it is not by chance, she nailed me and we left
#  </td>
# </tr>
# </table>
# </section></td>
# </tr>
# </table> <script>
# /* Letras4u.com - top */
# cf_page_artist = "bizarrap";
# cf_page_song = "tiago pzk: bzrp music sessions vol. 48";
# cf_adunit_id = "39382350";
# </script>
# <script src="//srv.clickfuse.com/showads/showad.js"></script><p><a href="https://www.lyrics.com.es/search/songs/bizarrap" rel="nofollow">bizarrap</a> </p>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- letras4uabajo -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-
<a href="https://www.letras4u.com/abc/k.htm">K</a> <a href="https://www.letras4u.com/abc/l.htm">L</a> <a href="https://www.letras4u.com/abc/m.htm">M</a> <a href="https://www.letras4u.com/abc/n.htm">N</a> <a href="https://www.letras4u.com/abc/o.htm">O</a> <a href="https://www.letras4u.com/abc/p.htm">P</a> <a href="https://www.letras4u.com/abc/q.htm">Q</a> <a href="https://www.letras4u.com/abc/r.htm">R</a> <a href="https://www.letras4u.com/abc/s.htm">S</a> <a href="https://www.letras4u.com/abc/t.htm">T</a> <a href="https://www.letras4u.com/abc/u.htm">U</a> <a href="https://www.letras4u.com/abc/v.htm">V</a> <a href="https://www.letras4u.com/abc/w.htm">W</a> <a href="https://www.letras4u.com/abc/x.htm">X</a> <a href="https://www.letras4u.com/abc/y.htm">Y</a> <a href="https://www.letras4u.com/abc/z.htm">Z</a> <p><hr><a href="https://www.facebook.com/letrasdecanciones" rel="nofollow">Facebook</a> - <a href="https://www.letras4u.com/avisolegal.html" rel="nofollow">Aviso legal</a></hr></p><br/> <br/><br/> | ©2012 Copyright Ballnavgroup...<a href="https://www.letras4u.com/politica-privacidad.php" rel="nofollow">Politica Privacidad</a> <a href="https://www.letras4u.com/politica-cookies.php" rel="nofollow">Politica Cookies</a></section>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-712091-47"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-1958749-22');
# </script>
# </body></html>

# %%
# obtiene el cuerpo del contenido web de la letra de la canción
results_letra_cancion = soup_letra_cancion.find("div", class_="grid-container")
#print(results_letra_cancion.prettify())

# %%
# obtiene el contenedor principal donde está la letra de la canción
job_elements_letra = results_letra_cancion.find_all("table")
#print(job_elements_letra)

# %%
# obtiene la letra de la canción
letra_cancion = ''
for job_element in job_elements_letra:
    letra = job_element.find("td")
    if (hasattr(letra, 'text')):
        letra_cancion = letra_cancion + letra.text.replace('\n\n\n', '')
print(letra_cancion)
# Out:
# Letra tiago pzk: bzrp music sessions vol. 48 Lyrics en Ingles
# ******vámono a un lugar donde no nos puedan ver (ver)
# elige el destino que yo pago el hotel (-tel)
# tengo más verde en la billetera que ayer (-yer)
# sé que hay más de un bobo que te quiere tener
#
# y no, tú te fuiste conmigo
# y yo ahora estoy perdido
# amor, si me llamas, sabes que estoy-oy-oy-oy
#
# bombona, todos quieren contigo, pero tú estás conmigo
# y no es casualidad, me clavó la mirá y nos fuimo
# bombona, todos quiеren contigo, pero tú estás conmigo
# y no еs casualidad, me clavó la mirá y nos fuimo
#
# el biza la soltó pero el gotti la agarró
# y a la pista la partió en do, en do (el biza la sol)
# cuando piensan que sí, cuando digo que no
# soy la bestia del lápiz, como kendo
#
# va-vamo a pegarno, como mis cancione
# porque si ese flow es droga, mami, yo soy al capone
# muchas dicen que no siguen esa moda que ella impone
# pero to lo que le queda bien, las nena se lo ponen
#
# escucha anuel aa y se pone pila (brr)
# cuando sale por miami en la casa de argentina
# esa cintura slip pero ese c*lo está killah
# cuando ella ve cerrado el club, prende maría
#
# si no lo tiene natural, yo le pago el plastic
