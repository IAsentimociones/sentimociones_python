# %%
import requests
from bs4 import BeautifulSoup

# Obtiene el contenido web del resultado de búsqueda
url_busqueda = "https://www.google.com/search?q=letra+Cold+Heart+Pnau+Remix+Elton+John+Dua+Lipa"
page = requests.get(url_busqueda)
print (page.content)
soup = BeautifulSoup(page.content, "html.parser")
print(soup)

# %%
a_main = soup.findAll("a")
print(a_main)

# %%
# obtiene elementos del autor, cancion y enlace donde está la letra de la canción
from re import search


url_letra_cancion = ''
for a in a_main:
    href = a.get("href") 
    if search ('https', href) and search ('letra', href) and not search('google', href) and search ('Cold', href) and search ('Elton', href):
        print(href.replace('/url?q=', ''))

# %%
import requests
from bs4 import BeautifulSoup

# obtiene contenido de la página web de la letra de la canción
url_letra_cancion = 'https://www.letras.com/jhay-cortez/dile-homenaje/' 
page_letra_cancion = requests.get(url_letra_cancion)
soup_letra_cancion = BeautifulSoup(page_letra_cancion.content, "html.parser")
print(soup_letra_cancion)
# Out:
# <!DOCTYPE HTML>
#  <html dir="ltr" lang="es"> <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"> <title>DILE (HOMENAJE) - Jhay Cortez - LETRAS.COM</title> <meta content="Jhay Cortez - Dile (Homenaje) (Letras y canción para escuchar) - Dile que no te has decidido / Que no sabe' lo de tener marido / Dile que no' vemo' a seguido / Qué tú me escribe' aunque no me ha' seguido / Y cuando" name="description"/> <meta content="DILE (HOMENAJE), DILE (HOMENAJE) Jhay Cortez, DILE (HOMENAJE) letra, letras de canciones, letras, subtítulos" name="keywords"/> <link href="https://www.letras.com/jhay-cortez/dile-homenaje/" rel="canonical"/> <meta charset="utf-8"/> <meta content="app-id=com.studiosol.player.letras" name="google-play-app"/> <meta content="214701744179" property="fb:pages"> <meta content="357922461263649" property="fb:app_id"/> <meta content="telephone=no" name="format-detection"/> <meta content="#FFFFFF" name="theme-color"/> <meta content="async" name="include_mode"> <meta content="app-id=773347891" name="apple-itunes-app"/> <meta content="width=device-width, initial-scale=1.0" name="viewport"/> <link crossorigin="" href="https://akamai.sscdn.co" rel="preconnect"/>
# <link href="https://solr.sscdn.co" rel="dns-prefetch"/>
# <link href="https://tpc.googlesyndication.com" rel="dns-prefetch"/>
# <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="https://prg.smartadserver.com" rel="dns-prefetch"/>
# <link href="https://fastlane.rubiconproject.com" rel="dns-prefetch"/>
# <link href="https://htlb.casalemedia.com/" rel="dns-prefetch"/>
# <link href="http://a9.com/-/spec/opensearch/1.1/" rel="profile"/> <link href="https://akamai.sscdn.co/letras/static/img/favicon.vbc34a3b.ico" rel="icon" type="image/x-icon"> <link href="//akamai.sscdn.co/mletras/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon"/> <link href="//akamai.sscdn.co/mletras/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon" sizes="72x72"/> <link href="//akamai.sscdn.co/mletras/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon" sizes="114x114"/> <link href="//akamai.sscdn.co/mletras/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon" sizes="144x144"/> <link as="font" crossorigin="" href="https://akamai.sscdn.co/letras/common/static/font/opensans.woff2" rel="preload" type="font/woff2"> <link as="font" crossorigin="" href="https://akamai.sscdn.co/letras/common/static/font/lato.woff2" rel="preload" type="font/woff2"> <style> body,h1,h2,h3,p,ol,ul,hr,button{margin:0;padding:0} article,header,section,footer{display:block} html{word-wrap:break-word;overflow-wrap:break-word} body{min-width:980px;padding-top:68px;color:#444;position:relative;background:#fff} input,button,a{outline:none} ul,ol{list-style:none} button{border:0;cursor:pointer} img{border:0;font-size:0} a{text-decoration:none;color:#b7b700} iframe{overflow:hidden} body,input,button{font-style:normal;font-variant:normal;font-weight:normal;font-size:13px;line-height:1;font-family:Arial,sans-serif} h1,h2,h3{font-weight:inherit;font-size:inherit} .g-1{width:1055px;margin:0 auto} .g-2-3{width:695px} .g-1-3{width:335px} .g-1-4,.w-1-4{width:245px} .g-1-5,.w-1-5{width: 191px} .g-1-6{width:155px} @media (max-width:1300px){ .g-1-2,.w-1-2{width:467.5px} .g-1{width:960px} .g-2-3{width:631.66667px} .g-1-3{width:303.33333px} .g-1-4,.w-1-4{width:221.25px} .g-1-5,.w-1-5{width:172px} .g-1-6{width:139.16667px} } .g-1-2,.g-2-3,.g-1-3,.g-1-4,.g-1-5,.g-1-6{float:left;min-height:1px} .g-1-2+.g-1-2,.g-1-3+.g-2-3,.g-2-3+.g-1-3,.g-1-3+.g-1-3,.g-1-4+.g-1-4,.g-1-5+.g-1-5,.g-1-6+.g-1-6{margin-left:25px} .g-1-4:nth-child(4n+1), .g-1-5:nth-child(5n+1){clear:both;margin-left:0} .g-mb{margin-bottom:25px} .g-sp{margin-bottom:50px} .g-pr{position:relative} .g-flex{display:flex} .g-fix::after{content:'';display:block;clear:both;width:100%;height:1px} .hr{height:0;border:0;border-bottom:1px solid #eee;margin-bottom:25px} .hr+.hr{display:none} @media only screen and (max-device-width:1024px) and (min-device-width:768px){ body{width:1020px} } .bt-ouvir,.cnt-more,.bt-b{display:inline-block;line-height:30px;border-radius:6px;font-weight:bold;border:1px solid;cursor:pointer;position:relative;padding:0 12px;font-size:13px} .bt-b,.bt-fa{border-color:#ccc;color:#444;background:#fff} .bt-ouvir{padding:0 15px 0 34px;background:#5eb70b;border-color:#5eb70b;color:#fff} .cnt-more{position:absolute;top:0;right:0;color:#444;border-color:transparent;font-size:15px} .cnt-an-square{width:336px;min-height:250px} .an-full{background:#f5f5f5;position:relative;min-height:90px;z-index:auto} .an-full[data-slotempty="false"],.cnt-an-square[data-slotempty="false"]{display:flex!important;align-items:center;justify-content:center} .an-full div[id*="google_ads_iframe_"],.cnt-an-square div[id*="google_ads_iframe_"]{display:inline} @media (max-width:1300px){ .cnt-an-square{width:300px} .an-full,#pub_10{left:-5px} } #pub_10{height:90px;margin-bottom:25px;display:block} .cnt-space-top{height:115px;overflow:hidden;position:relative} .cnt-space-top::before{content:'';height:90px;position:absolute;top:0;left:0;right:0;background:#f5f5f5} @media only screen and (max-device-width:1024px) and (min-device-width:768px){ .an-full{overflow:hidden} } .an-outpage{position:fixed;left:0;bottom:0} .ps{position:relative;overflow:hidden} .modal{position:absolute;background:#FFF;border:1px solid #ddd;border-radius:12px;box-shadow:rgba(0,0,0,0) 0 1px 3px;visibility:hidden;opacity:0;transition:opacity 0.1s,visibility 0s 0.3s;-webkit-transition:opacity 0.1s,visibility 0s 0.3s ...
# <link href="https://www.letras.com/jhay-cortez/dile-homenaje/" hreflang="es" rel="alternate">
# <link href="https://www.letras.mus.br/jhay-cortez/dile-homenaje/" hreflang="pt-br" rel="alternate">
# <link href="https://m.letras.com/jhay-cortez/dile-homenaje/" media="only screen and (max-width: 640px)" rel="alternate"/> <script type="application/ld+json">{"@context":"http://schema.org/","@type":"WebSite","name":"Letras.com","url":"https://www.letras.com/"}</script><script type="application/ld+json">{"@context":"http://schema.org/","@id":"https://www.letras.com/jhay-cortez/dile-homenaje/","@type":"MusicRecording","byArtist":{"@context":"http://schema.org/","@id":"https://www.letras.com/jhay-cortez/","@type":"MusicGroup","description":"Canciones de Jhay Cortez , artista del estilo Hip Hop/Rap","genre":"Hip Hop/Rap","image":"https://akamai.sscdn.co/uploadfile/letras/fotos/c/9/d/8/c9d826a4bb98e6b9b5200a9cfd2017b7.jpg","name":"Jhay Cortez","potentialAction":{"@type":"ListenAction","expectsAcceptanceOf":{"@type":"Offer","eligibleRegion":[{"@type":"Country","name":"BR"},{"@type":"Country","name":"US"},{"@type":"Country","name":"AR"},{"@type":"Country","name":"CL"},{"@type":"Country","name":"VE"},{"@type":"Country","name":"EC"},{"@type":"Country","name":"MX"},{"@type":"Country","name":"ES"},{"@type":"Country","name":"UY"}]},"target":[{"@type":"EntryPoint","actionPlatform":["http://schema.org/DesktopWebPlatform","http://schema.org/MobileWebPlatform"],"inLanguage":["pt-BR","en-US","es-ES"],"urlTemplate":"https://www.letras.com/jhay-cortez/ouvir.html"},{"@type":"EntryPoint","actionPlatform":"http://schema.org/AndroidPlatform","inLanguage":["pt-BR","en-US","es-ES"],"urlTemplate":"android-app://com.studiosol.player.letras/http/www.letras.mus.br/jhay-cortez/"}]},"sameAs":["https://www.cifraclub.com/jhay-cortez/"],"url":"https://www.letras.com/jhay-cortez/"},"description":"Dile (Homenaje) es una canción de Jhay Cortez, artista del estilo Hip Hop/Rap","duration":"PT3M49S","genre":"Hip Hop/Rap","image":"https://akamai.sscdn.co/uploadfile/letras/fotos/c/9/d/8/c9d826a4bb98e6b9b5200a9cfd2017b7.jpg","inAlbum":{"@context":"http://schema.org/","@id":"https://www.letras.com/jhay-cortez/discografia/timelezz-2021/","@type":"MusicAlbum","byArtist":{"@id":"https://www.letras.com/jhay-cortez/","@type":"MusicGroup","name":"Jhay Cortez"},"datePublished":2021,"description":"Timelezz es un álbum de Jhay Cortez, artista del estilo Hip Hop/Rap","genre":"Hip Hop/Rap","image":"https://akamai.sscdn.co/uploadfile/letras/albuns/4/7/8/a/1144911630684926.jpg","name":"Timelezz","numtracks":17,"publisher":"UMG Recordings, Inc.  /  Universal Music Latino","url":"https://www.letras.com/jhay-cortez/discografia/timelezz-2021/"},"name":"Dile (Homenaje)","url":"https://www.letras.com/jhay-cortez/dile-homenaje/"}</script><script type="application/ld+json">{"@context":"http://schema.org/","@id":"https://www.letras.com/","@type":"BreadcrumbList","ItemListElement":[{"@context":"http://schema.org/","@id":"https://www.letras.com/","@type":"ListItem","item":{"@id":"https://www.letras.com/","name":"Página Inicial"},"position":0},{"@context":"http://schema.org/","@id":"https://www.letras.com/estilos/hip-hop-rap/","@type":"ListItem","item":{"@id":"https://www.letras.com/estilos/hip-hop-rap/","name":"Hip Hop/Rap"},"position":1},{"@context":"http://schema.org/","@id":"https://www.letras.com/jhay-cortez/","@type":"ListItem","item":{"@id":"https://www.letras.com/jhay-cortez/","name":"Jhay Cortez"},"position":2},{"@context":"http://schema.org/","@id":"https://www.letras.com","@type":"ListItem","item":"https://www.letras.com/jhay-cortez/dile-homenaje/","name":"Dile (Homenaje)","position":3}]}</script> <meta content="https://www.letras.com/jhay-cortez/dile-homenaje/" property="og:url"> <meta content="DILE (HOMENAJE) - Jhay Cortez - LETRAS.COM" property="og:title"> <meta content="Dile que no te has decidido / Que no sabe' lo de tener marido / Dile que no' vemo' a seguido / Qué tú me escribe' aunque no me ha' seguido / Y cuando" property="og:description"> <meta content="https://akamai.sscdn.co/uploadfile/letras/fotos/c/9/d/8/c9d826a4bb98e6b9b5200a9cfd2017b7.jpg" property="og:image"/> <meta  ...
# <script id="head_scripts_vars">
#     //APS script
#     !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#
#     window.__pageArgs={"album_name":"Timelezz","artist_name":"Jhay Cortez","dns":"jhay-cortez","genre":"hip-hop-rap","lyric_lang":"es","page":"lyric","track_name":"Dile (Homenaje)","url":"dile-homenaje"};
#
#     window.__pageArgs = window.__pageArgs || {};
#     window.__Region = "es";window.__LocaleLang = "es";window.__Locale = "es_ES";
#     window.__Hash = window.location.hash.replace("#","");
#     window.__IsMobile = false;
#     window.__SafeFrameActive = false;
#     window.disabledAdsense = false;
#     var _plq = _plq || [];var _omq = _omq || [];var _hscmd = _hscmd || [];var googletag = googletag || {};googletag.cmd = googletag.cmd || [];
#     var _adunitSlots = {};var _adunitLazySlots ={};var _adunitDynamicSlots = {};var _adunitRefreshSlots = {};
#     var pbjs = pbjs || {};pbjs.que = pbjs.que || [];pbjs.bidderTimeout = 1300;
#     window._adunitSlots["pub_10_ad"] = {ID:"Letras:728x90:firstView:reload",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_10_ad",outofpage:false,refresh:false};window._adunitSlots["pub_10_ad_refresh"] = {ID:"Letras:728x90:firstView",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_10_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_3_ad"] = {ID:"Letras:336x250_belowVideo:reload",sizes:[[1,1],[300,250],[336,280],[300,600]],div:"pub_3_ad",outofpage:false,refresh:false};window._adunitSlots["pub_3_ad_refresh"] = {ID:"Letras:336x250_belowVideo",sizes:[[1,1],[300,250],[336,280],[300,600]],div:"pub_3_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_24_ad"] = {ID:"Letras:728x90:middle:reload",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_24_ad",outofpage:false,refresh:false};window._adunitSlots["pub_24_ad_refresh"] = {ID:"Letras:728x90:middle",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_24_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_5_ad"] = {ID:"Letras:728x90:belowLyrics:reload",sizes:[[1,1],[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_5_ad",outofpage:false,refresh:false};window._adunitSlots["pub_5_ad_refresh"] = {ID:"Letras:728x90:belowLyrics",sizes:[[1,1],[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_5_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_11_ad"] = {ID:"Letras:300x250:comentarios:reload",sizes:[[300,250],[300,600]],div:"pub_11_ad",outofpage:false,refresh:false};window._adunitSlots["pub_11_ad_refresh"] = {ID:"Letras:300x250:comentarios",sizes:[[300,250],[300,600]],div:"pub_11_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_6_ad"] = {ID:"Letras:floatingAds",div:"pub_6_ad",outofpage:true,refresh:false};window._adunitSlots["pub_7_ad"] = {ID:"Letras:PlayerPreroll",div:"pub_7_ad",outofpage:true,refresh:false};window._adunitSlots["pub_8_ad"] = {ID:"Letras:bg:internas",div:"pub_8_ad",outofpage:true,refresh:false};window._adunitSlots["pub_9_ad"] = {ID:"Letras:1055x90:billboardInternas:reload",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_9_ad",outofpage:false,refresh:false};window._adunitSlots["pub_9_ad_refresh"] = {ID:"Letras:1055x90:billboardInternas",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_9_ad_refresh",outofpage:false,refresh:true};window._adunitDynamicSlots["pub_21_ad"] = {ID:"Letras:inBetweenLyrics",div:"pub_21_ad",outofpage:true,refresh:false};window._adunitSlots["pub_25_ad"] = {ID:"LetrasDesktop:footer:fixed:reload",sizes:[[728,90],[970,90],[1055,90]],div:"pub_25_ad",outofpage:false,refresh:false};window._adunitSlots["pub_25_ad_refresh"] = {ID:"LetrasDesktop:footer:fixed",sizes:[[728,90],[970,90],[1055,90]],div:"pub_25_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_38_ad"] = {ID:"LetrasDesktop:top:left:fixed:reload",sizes:[[320,50]],div:"pub_38_ad",outofpage:false,refresh:false};window._adunitSlots["pub_38_ad_refresh"] = {ID:"LetrasDesktop:top:left:fixed",sizes:[[320,50]],div:"pub_38_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_39_ad"] = {ID:"LetrasDesktop:top:right:fixed:reload",sizes:[[320,50]],div:"pub_39_ad",outofpage:false,refresh:false};window._adunitSlots["pub_39_ad_refresh"] = {ID:"LetrasDesktop:top:right:fixed",sizes:[[320,50]],div:"pub_39_ad_refresh",outofpage:false,refresh:true};
#     var prebidAdUnits = [{"code":"pub_10_ad","mediaTypes":{"banner":{"sizes":[[728,90],[970,90],[1055,90]]}},"bids":[{"id":"yahoossp-8a969457017575d60376d79fe424003f-letras_728x90_firstview_reload","bidder":"yahoossp","params":{"dcn":"8a969457017575d60376d79fe424003f","pos":"letras_728x90_firstview_reload"}},{"id":"appnexus-13893938","bidder":"appnexus","params":{"placementId":"13893938"}},{"id":"rubicon-14458-101116-1046420","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1046420"}},{"id":"smartadserver-69269","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"69269","pageId":887594,"siteId":202484}},{"id":"ix-376640","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376640"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}}]},{"code":"pub_3_ad","mediaTypes":{"banner":{"sizes":[[1,1],[300,250],[336,280],[300,600]]},"video":{"context":"outstream","playerSize":[[300,250]],"minduration":0,"mimes":["video/mp4","video/x-flv","video/webm","video/ogg","application/javascript"],"protocols":[1,2,3,4,5,6,7,8],"api":[1,2,3,4,5,6,7],"playbackmethod":[2,3,4,6],"placement":2,"linearity":2}},"bids":[{"id":"yahoossp-8a969457017575d60376d79fe424003f-letras_336x250_belowvideo_reload","bidder":"yahoossp","params":{"dcn":"8a969457017575d60376d79fe424003f","pos":"letras_336x250_belowvideo_reload"}},{"id":"teads","bidder":"teads","params":{"pageId":120546,"placementId":130727}},{"id":"appnexus-13893906","bidder":"appnexus","params":{"placementId":"13893906","video":{"context":"outstream","maxduration":60,"minduration":0}}},{"id":"rubicon-14458-101116-1046422","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1046422"}},{"id":"smartadserver-69267","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"69267","pageId":887594,"siteId":202484}},{"id":"ix-376643","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376643","video":{"api":[1,2,3,4,5,6,7],"h":250,"maxduration":60,"mimes":["video/mp4","video/x-flv","video/webm","video/ogg","application/javascript"],"minduration":0,"protocols":[2,3,5,6],"w":300}}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}}]},{"code":"pub_24_ad","mediaTypes":{"banner":{"sizes":[[728,90],[970,90],[970,250],[1055,90],[1055,250]]}},"bids":[{"id":"yahoossp-8a969457017575d60376d79fe424003f-letras_728x90_middle_reload","bidder":"yahoossp","params":{"dcn":"8a969457017575d60376d79fe424003f","pos":"letras_728x90_middle_reload"}},{"id":"appnexus-14155112","bidder":"appnexus","params":{"placementId":"14155112"}},{"id":"rubicon-14458-101116-1079488","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1079488"}},{"id":"smartadserver-70348","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"70348","pageId":887594,"siteId":202484}},{"id":"ix-376639","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376639"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}}]},{"code":"pub_5_ad","mediaTypes":{"banner":{"sizes":[[1,1],[728,90],[970,90],[970,250],[1055,90],[1055,250]]}},"bids":[{"id":"yahoossp-8a969457017575d60376d79fe424003f-letras_728x90_belowlyrics_reload","bidder":"yahoossp","params":{"dcn":"8a969457017575d60376d79fe424003f","pos":"letras_728x90_belowlyrics_reload"}},{"id":"appnexus-13893936","bidder":"appnexus","params":{"placementId":"13893936"}},{"id":"rubicon-14458-101116-1046424","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1046424"}},{"id":"smartadserver-69264","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"69264","pageId":887594,"siteId":202484}},{"id":"ix-376642","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376642"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}}]},{"code":"pub_11_ad","mediaTypes":{"banner":{"sizes":[[300,250],[300,600]]}},"bids":[{"id":"yahoossp-8a96945 ...
# 	var __activeBids = ["rubicon","smartadserver","ix","eplanning","teads","yahoossp","appnexus"];
#     _hscmd.push(function() {initADPipeline();});
#
# </script> <link href="https://www.letras.com/opensearchdescription.xml" rel="search" title="Búsqueda de letras" type="application/opensearchdescription+xml">
# <link href="/destaques.rss" rel="alternate" title="RSS Feed - Destacados - Letras.com" type="application/rss+xml">
# <link href="/destaques.atom" rel="alternate" title="Atom Feed - Destacados - Letras.com" type="application/atom+xml">
# <link href="/playlists.rss" rel="alternate" title="RSS Feed - Playlists - Letras.com" type="application/rss+xml">
# <link href="/playlists.atom" rel="alternate" title="Atom Feed - Playlists - Letras.com" type="application/atom+xml">
# <link href="/blog.rss" rel="alternate" title="RSS Feed - Blog - Letras.com" type="application/rss+xml"> <link href="/manifest.json" rel="manifest"/> <script>
# 	if (!("Promise" in window)) {
# 		document.write('<script src="//akamai.sscdn.co/letras/common/static/js/promise.vd6adfb0c.js"><\/script>');
# 	}
# </script>
# </link></link></link></link></link></link></meta></meta></meta></link></link></link></link></link></meta></meta></head> <body class="es-es" data-locale="es-es"> <script type="text/javascript">if(window.document.cookie.match(new RegExp("lasub=([^;][A-Za-z0-9]{2,5})"))){document.body.classList.add("has-subscription");}</script> <div class="wrapper"> <header class="main-header g-mb"> <div class="g-1"> <h2 class="main-header_logo"><a href="/">LETRAS.COM - Letras de canciones</a></h2> <button class="main-header_bt">menu</button> <form class="main-search suggest"> <label><input aria-label="¿Qué quieres escuchar ahora?" autocomplete="off" class="main-search_input" id="main_suggest" placeholder="¿Qué quieres escuchar ahora?"/></label> <button class="main-search_submit" title="buscar">buscar</button> <div class="suggest__drop modal"> <ul class="suggest__list"></ul> <div class="suggest__all"></div> </div> </form> <div class="main-header_ccid"><span id="js-user-send"></span><span id="js-user-menu"></span></div> </div> </header> <div class="page-lyric" id="all"> <div id="cnt_top"> <div class="breadcrumb cor_1 g-1" id="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList"> <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"> <a href="/" itemprop="item"><span itemprop="name">Página Inicial</span></a> <meta content="1" itemprop="position"/> </span> <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"> <a href="/estilos/hip-hop-rap/" itemprop="item"><span itemprop="name">Hip Hop/Rap</span></a> <meta content="2" itemprop="position"/> </span> <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"> <a href="/jhay-cortez/" itemprop="item"><span itemprop="name">Jhay Cortez</span></a> <meta content="3" itemprop="position"/> </span> <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"> <span itemprop="name">Dile (Homenaje)</span> <meta content="https://www.letras.com/jhay-cortez/dile-homenaje/" itemprop="item"/> <meta content="4" itemprop="position"/> </span> </div> <div class="an-outpage an-pub" id="pub_6" style="display:block;"><div id="pub_6_ad"></div></div> <div class="an-outpage an-pub" id="pub_7" style="display:block;"><div id="pub_7_ad"></div></div> <div class="an-outpage an-pub" id="pub_8" style="display:block;"><div id="pub_8_ad"></div></div> <div class="an-pub" id="pub_21" style="display:none;"><div id="pub_21_ad"></div></div> <div class="g-1 g-mb" id="js-lyric-cnt"> <div class="cnt-space-top"><div class="an-full g-1 g-mb with-refresh an-pub" data-intersectionratio="0.40" data-refresh="15" id="pub_10" style="display:block;"><div id="pub_10_ad_refresh"><div id="pub_10_ad"></div></div></div></div> <article> <div class="cnt-head cnt-head--l"> <div class="cnt-info"> <div class="cnt-info_exib">vistas <b> 971</b></div> </div> <div class="cnt-head_title"> <h1>Dile (Homenaje)</h1> <h2> <a href="/jhay-cortez/"> <img alt="" height="44" src="https://akamai.sscdn.co/uploadfile/letras/fotos/c/9/d/8/c9d826a4bb98e6b9b5200a9cfd2017b7-tb2.jpg" srcset="https://akamai.sscdn.co/uploadfile/letras/fotos/c/9/d/8/c9d826a4bb98e6b9b5200a9cfd2017b7-tb2.jpg 1x, https://akamai.sscdn.co/uploadfile/letras/fotos/c/9/d/8/c9d826a4bb98e6b9b5200a9cfd2017b7-tb.jpg 2x" title="Jhay Cortez" width="44"/> <span>Jhay Cortez</span> </a> </h2> <br/> </div> </div> <div class="cnt-letra-trad g-pr g-sp">
# <div class="an-pub an-above is-on above" id="an-above-above"></div>
# <div class="cnt-letra p402_premium"> <p>Dile que no te has decidido<br>Que no sabe' lo de tener marido<br/>Dile que no' vemo' a seguido</br></p><p>Qué tú me escribe' aunque no me ha' seguido<br/>Y cuando están a sola'<br/>Él te trata mal, no te valora<br/>Llega a la casa a saber la hora</p><p>Dile que bailando te conocí-í, cuéntale<br/>Dile que esta noche me quieres ve-er, cuéntale<br/>Dile que solo quiero otra noche</p><p>Cuéntale lo que hicimo' anoche<br/>Mi piel huele a tu perfume Dolce<br/>Baby, él no te conoce y<br/>Dile que bailando te conocí-í, cuéntale</p><p>Tú siempre encima de mí-í, cuéntale<br/>Dile que solo quiero otra noche<br/>Cuéntale lo que hicimo' anoche</p><p>Mi piel huele a tu perfume Dolce<br/>Baby, él no te conoce<br/>(No te conoce, ¿me sigue'?), yeh</p><p>Dime, baby, lo que está' haciendo<br/>Con él siempre peleando, conmigo bebiendo<br/>Se comenta por ahí que se está enterando<br/>Yo no sé por qué carajo' tú' no' está' escondiendo</p><p>No seas una pobre diabla (diabla)<br/>Cuando está contigo ni te habla (habla)<br/>Tú te siente' sola y eso te endiabla<br/>Lleva tiempo que no te da tabla</p><p>Y olvídate de la gente<br/>Lo comenta' bien diferente<br/>Baby, a vece' te acalora, te besa, te abraza, pero no te siente</p><p>Conmigo es algo diferente<br/>Tú lo que quiere' es que te entre<br/>Porque a vece' él no te acalora, te besa, por eso cuando tú me siente'</p><p>Dile que bailando te conocí-í, cuéntale<br/>Dile que esta noche me quieres ve-er, cuéntale<br/>Dile que solo quiero otra noche<br/>Cuéntale lo que hicimo' anoche</p><p>Mi piel huele a tu perfume Dolce<br/>Baby, él no te conoce y<br/>Dile que bailando te conocí-í, cuéntale<br/>Tú siempre encima de mí-í, cuéntale</p><p>Dile que solo quiero otra noche<br/>Cuéntale lo que hicimo' anoche<br/>Mi piel huele a tu perfume Dolce<br/>Baby, él no te conoce, yeh<br/>(La Presión)</p><p>Otra, otra noche, otra<br/>(Ay, que yo no te boté)<br/>Otra, otra noche, otra</p><p>(Aunque tú vuelva' con él)<br/>Otra, otra noche, otra<br/>(Ay, que yo-yo no te boté)<br/>Otra, otra noche, otra</p><p>Y olvídate de la gente<br/>Lo comenta' bien diferente<br/>Baby, a vece' te acalora, te besa, te abraza, pero no te siente</p><p>Conmigo es algo diferente<br/>Tú lo que quiere' es que te entre<br/>Porque a vece' no te acalora, te besa, por eso cuando tú me siente'</p><p>Dile que bailando te conocí-í, cuéntale<br/>Dile que esta noche me quieres ve-er, cuéntale<br/>Dile que solo quiero otra noche</p><p>Cuéntale lo que hicimo' anoche<br/>Mi piel huele a tu perfume Dolce<br/>Baby, él no te conoce</p> </div> <div class="letra-menu"> <a class="lyric_event lm_add" data-action="Adicionar à playlist" data-namespace="Menu lateral" href="#"><i></i>Agregar a la playlist</a> <b class="lm_siz"><i></i>Tamaño <span> <button class="lyric_event lm_siz_l" data-action="Reduzir Tamanho" data-namespace="Menu lateral">A</button> <button class="lyric_event lm_siz_r" data-action="Restaurar Tamanho" data-namespace="Menu lateral">Restaurar</button> <button class="lyric_event lm_siz_m" data-action="Aumentar Tamanho" data-namespace="Menu lateral">A</button> </span> </b> <a class="lyric_event lm_cif" data-action="Nav Cifra" data-namespace="Menu lateral" href="https://www.cifraclub.com/jhay-cortez/" rel="noopener" target="_blank"><i></i>Cifrado</a> <a class="lyric_event lm_pri" data-action="Imprimir" data-namespace="Menu lateral" href="/jhay-cortez/dile-homenaje/dile-homenaje-print.html" rel="nofollow noopener" target="_blank"><i></i>Imprimir</a> <a class="lm_edi" data-ct-action="Nav Enviar Correcao" data-ct-label="Menu lateral (letra)" href="/contribuicoes/enviar_correcao/jhay-cortez/dile-homenaje/" rel="nofollow"><i></i>Corregir</a> <script class="addToPlaylistTemplate -lyricPage" type="text/template"> <div data-songid="" class="addToPlaylist modal -lyricPage">  <div class="addToPlaylist-body"> <ul class="js-playlist-list-create"> <li class="addToPlaylist-new"> <i></i>Crear playlist <div class="addToPlaylist-c ...
# <div class="an-pub an-above is-on below" id="an-above-below" style="display:none;"></div>
# </div> <div class="letra-info g-sp"> <div class="letra-info_comp"> <a class="contrib-link" data-ct-action="Enviar compositor" data-ct-label="Letra" href="/contribuicoes/enviar_correcao/jhay-cortez/dile-homenaje/compositor/" rel="nofollow">¿Sabes quién compuso esta canción? Envíanoslo.</a> </div> <div class="letra-info_user">  Enviada por <a class="contrib-link" data-ct-action="Click User que enviou letra" data-ct-label="Letra" href="/membros/49240982/">Gustavo</a>.     <a class="contrib-link letra-info_contrib" data-mct-action="Click Link Enviar Revisão" data-mct-label="Letra" href="/contribuicoes/enviar_correcao/jhay-cortez/dile-homenaje/" rel="nofollow">¿Viste algún error? Envíanos una revisión.</a> </div> </div> <div class="an-full g-1 g-mb with-refresh an-pub" data-intersectionratio="0.40" data-refresh="15" id="pub_5" style="display:block;"><div id="pub_5_ad_refresh"><div id="pub_5_ad"></div></div></div> </article> <hr class="hr"/> <div class="comments g-fix" id="comments"> <div class="g-2-3"> <div class="js-fb-comments"></div> </div> <div class="g-1-3"> <div class="with-refresh an-pub" data-intersectionratio="0.40" data-refresh="15" id="pub_11" style="display:block;"><div id="pub_11_ad_refresh"><div id="pub_11_ad"></div></div></div> </div> </div> </div> </div> <div id="cnt_footer"> <div class="an-full g-1 g-mb with-refresh an-pub" data-intersectionratio="0.40" data-refresh="15" id="pub_9" style="display:block;"><div id="pub_9_ad_refresh"><div id="pub_9_ad"></div></div></div> <div class="an-full g-1 g-mb with-refresh an-pub" data-intersectionratio="0.40" data-refresh="15" id="pub_25" style="display:none;"><div id="pub_25_ad_refresh"><div id="pub_25_ad"></div></div></div> <hr class="hr"/> <div class="g-1"> <div class="artista-top g-sp g-pr"> <script class="addToPlaylistTemplate -songlistPage" type="text/template"> <div data-songid="" class="addToPlaylist modal -songlistPage">  <div class="addToPlaylist-header"> Agregar a la playlist <a class="bt-close -no-space" href="#" rel="nofollow" id="js-close-a"></a> </div>  <div class="addToPlaylist-body"> <ul class="js-playlist-list-create"> <li class="addToPlaylist-new"> <i></i>Crear playlist <div class="addToPlaylist-create"> <input type="text" class="addToPlaylist-input"> <span class="addToPlaylist-counter">0/100</span> <button class="js-create-playlist bt-x">Crear</button> </div> </li> </ul> <ul class="playlist-lists"></ul> </div> </div> </script> <div class="modal_overlay"></div> <script id="cnt-list-options-modal" type="text/template"> <div class="cnt-list-options-modal -spaced"> <ol class="cnt-list-options-list"> <li> <button class="js-add-to-playlist cnt-list-option -bt" href="#">Agregar a la playlist</button> </li> </ol> <ol class="cnt-list-options-list -share"> <li class="cnt-list-option"> <div> <span>Compartir</span> <div class="sh-container"> <div class="sh js-share-playlist"> <a class="sh-bt sh-f" rel="nofollow" data-nofollow="true" title="Facebook" href="http://www.facebook.com/sharer.php?u=<%= shareurl %>&quote=<%- sharetext %>">Facebook</a> <a class="sh-bt sh-t" rel="nofollow" data-nofollow="true" title="Twitter" href="http://twitter.com/share?url=<%= shareurl %>&related=letras&text=%E2%99%AB%20<%- sharetext %>%20en%20@letras">Twitter</a> </div> <div title="Copiar vínculo" data-share="<%= shareurl %>" class="sh-link">Copiar vínculo</div> </div> </div> </li> </ol> </div> </script> <h2 class="h3"><a href="/jhay-cortez/">Las más escuchadas de Jhay Cortez</a></h2> <a class="cnt-more" href="/jhay-cortez/">Ver todas las canciones de Jhay Cortez</a> <i class="h-sep"></i> <div class="list-container"> <div class="list-overlay"></div> <ol class="cnt-list cnt-list--num -flex-col-2 js-song-list"> <li class="cnt-list-row -song" data-artist="Jhay Cortez" data-dns="jhay-cortez" data-id="3149044" data-name="No Me Conoce (remix) (part. J Balvin y Bad Bunny)" data-sharetext="No Me Conoce (remix) (part. J Balvin y Bad Bunny) de Jhay Cortez" data-shareurl="https://www.letras.com/jhay-co ...
# </script> </div> <footer class="footer"> <div class="g-1"> <div class="footer_alphabet"> <strong>Todos los artistas</strong> <ul> <li><a href="/letra/A/">A</a></li><li><a href="/letra/B/">B</a></li><li><a href="/letra/C/">C</a></li><li><a href="/letra/D/">D</a></li><li><a href="/letra/E/">E</a></li><li><a href="/letra/F/">F</a></li><li><a href="/letra/G/">G</a></li><li><a href="/letra/H/">H</a></li><li><a href="/letra/I/">I</a></li><li><a href="/letra/J/">J</a></li><li><a href="/letra/K/">K</a></li><li><a href="/letra/L/">L</a></li><li><a href="/letra/M/">M</a></li><li><a href="/letra/N/">N</a></li><li><a href="/letra/O/">O</a></li><li><a href="/letra/P/">P</a></li><li><a href="/letra/Q/">Q</a></li><li><a href="/letra/R/">R</a></li><li><a href="/letra/S/">S</a></li><li><a href="/letra/T/">T</a></li><li><a href="/letra/U/">U</a></li><li><a href="/letra/V/">V</a></li><li><a href="/letra/W/">W</a></li><li><a href="/letra/X/">X</a></li><li><a href="/letra/Y/">Y</a></li><li><a href="/letra/Z/">Z</a></li><li><a href="/letra/1/">0/9</a></li> </ul> </div> <hr/> <div class="g-fix" id="checkbox-bids"></div> <div class="footer_links g-fix"> <div class="footer_nav g-1-4"> <strong>Canciones</strong> <ul> <li><a href="/mais-acessadas/">Top canciones</a></li> <li><a href="/novidades.html">Actualizaciones</a></li> <li><a href="/lancamentos.html">Lanzamientos</a></li> <li><a class="no_tt" href="/playlists.html">Playlists del Letras</a></li> </ul> </div> <div class="footer_nav g-1-4"> <strong>Artistas</strong> <ul> <li><a href="/mais-acessadas/">Top Artistas</a></li> <li><a href="/top-albuns/">Top Álbumes</a></li> </ul> </div> <div class="footer_nav g-1-4"> <strong>Participa</strong> <ul> <li><a href="/perfil_musical.html">Crea tu perfil musical</a></li> <li><a data-ct-action="Nav Enviar Album" data-ct-label="Link (rodape)" href="/contribuicoes/enviar_album/" rel="nofollow">Envía álbumes</a></li> <li><a data-ct-action="Nav Enviar Letras" data-ct-label="Link (rodape)" href="/contribuicoes/enviar_letra/" rel="nofollow">Envía letras</a></li> <li><a data-ct-action="Nav Enviar Correcao" data-ct-label="Link (rodape)" href="/contribuicoes/enviar_correcao/" rel="nofollow">Correcciones de letras</a></li> </ul> </div> <div class="footer_nav g-1-4"> <strong>Sobre el sitio web</strong> <ul id="legal-links"> <li><a href="/faq.html">Ayuda</a></li> <li><a href="/aviso-legal.html">Condiciones de Uso y Política de Privacidad</a></li> <li><a href="/aviso-legal-academy.html">Condiciones de Uso de Letras Academy</a></li> <li id="change-consent" style="display:none;"><a href="#change-consent" onclick="window.__tcfapi('displayConsentUi', 2, function() {} );">Ajustes de privacidad</a></li> <li><a href="/padroes-para-envios.html">Normas para envío</a></li> <li><a href="/trabalheconosco">Trabaja con nosotros</a></li> </ul> </div> </div> <hr/> <div class="footer_apps g-fix"> <div class="g-1-2"> <strong>Aplicaciones</strong> <a class="footer_apps_g" href="https://play.google.com/store/apps/details?id=com.studiosol.player.letras&amp;hl=es" rel="noopener" target="_blank"><i></i><span>Disponible en <b>Google Play</b></span></a> <a class="footer_apps_a" href="https://itunes.apple.com/es/app/letras.mus.br/id773347891?mt=8" rel="noopener" target="_blank"><i></i><span>Descargar en <b>App Store</b></span></a> <a class="footer_apps_w" href="https://www.microsoft.com/es-es/p/letrasmusbr/9wzdncrfj184/" rel="noopener" target="_blank"><i></i><span>Descargar en <b>Microsoft</b></span></a> </div> <div class="g-1-2"> <strong>Plugins</strong> <a class="footer_apps_ch" href="/plugin/chrome/"><i></i><span>Plugin <b>Chrome</b></span></a> <a class="footer_apps_mp" href="/plugin/windows/"><i></i><span>Windows <b>Media Player</b></span></a> <a class="footer_apps_wn" href="/plugin/windows/"><i></i><span>Windows <b>Winamp</b></span></a> </div> </div> <hr/> <div class="footer_social g-fix"> <div class="g-1-2"> <strong>Sigue a Letras</strong> <div class="footer_follows"> <a class="footer_follow -y ...
# 	if (!("IntersectionObserver" in window)) {
# 		var s = document.createElement("script");
# 		s.async = false;
# 		s.src = '//akamai.sscdn.co/letras/static/js/polyfills-es.vdb7f638b.js';
# 		document.head.appendChild(s);
# 	}
# </script>
# <script async="" src="//akamai.sscdn.co/letras/common/static/js/headscripts.v04e1ccfa.js"></script>
# <script async="" src="//akamai.sscdn.co/letras/common/static/js/prebid.v134045b4.js"></script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script async="" src="//akamai.sscdn.co/letras/static/js/index.m-es.vd66ae103.js" type="module"></script>
# <script async="" nomodule="" src="//akamai.sscdn.co/letras/static/js/index-es.v66259d3d.js"></script>
# <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-446764-1', 'auto', {'sampleRate': 10});
# ga('send', 'pageview');
# (function (w, d, s, l, i) {
#     w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#             new Date().getTime(), event: 'gtm.js'
#     }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#             'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-KWMSHG8');
# window.dataLayer = window.dataLayer || [];
# </script>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KWMSHG8" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) --> </body> </html>

# %%
# obtiene el cuerpo del contenido web de la letra de la canción
p_main = soup_letra_cancion.find_all("p")
print(p_main)
# Out:
# [<p>Dile que no te has decidido<br>Que no sabe' lo de tener marido<br/>Dile que no' vemo' a seguido</br></p>, <p>Qué tú me escribe' aunque no me ha' seguido<br/>Y cuando están a sola'<br/>Él te trata mal, no te valora<br/>Llega a la casa a saber la hora</p>, <p>Dile que bailando te conocí-í, cuéntale<br/>Dile que esta noche me quieres ve-er, cuéntale<br/>Dile que solo quiero otra noche</p>, <p>Cuéntale lo que hicimo' anoche<br/>Mi piel huele a tu perfume Dolce<br/>Baby, él no te conoce y<br/>Dile que bailando te conocí-í, cuéntale</p>, <p>Tú siempre encima de mí-í, cuéntale<br/>Dile que solo quiero otra noche<br/>Cuéntale lo que hicimo' anoche</p>, <p>Mi piel huele a tu perfume Dolce<br/>Baby, él no te conoce<br/>(No te conoce, ¿me sigue'?), yeh</p>, <p>Dime, baby, lo que está' haciendo<br/>Con él siempre peleando, conmigo bebiendo<br/>Se comenta por ahí que se está enterando<br/>Yo no sé por qué carajo' tú' no' está' escondiendo</p>, <p>No seas una pobre diabla (diabla)<br/>Cuando está contigo ni te habla (habla)<br/>Tú te siente' sola y eso te endiabla<br/>Lleva tiempo que no te da tabla</p>, <p>Y olvídate de la gente<br/>Lo comenta' bien diferente<br/>Baby, a vece' te acalora, te besa, te abraza, pero no te siente</p>, <p>Conmigo es algo diferente<br/>Tú lo que quiere' es que te entre<br/>Porque a vece' él no te acalora, te besa, por eso cuando tú me siente'</p>, <p>Dile que bailando te conocí-í, cuéntale<br/>Dile que esta noche me quieres ve-er, cuéntale<br/>Dile que solo quiero otra noche<br/>Cuéntale lo que hicimo' anoche</p>, <p>Mi piel huele a tu perfume Dolce<br/>Baby, él no te conoce y<br/>Dile que bailando te conocí-í, cuéntale<br/>Tú siempre encima de mí-í, cuéntale</p>, <p>Dile que solo quiero otra noche<br/>Cuéntale lo que hicimo' anoche<br/>Mi piel huele a tu perfume Dolce<br/>Baby, él no te conoce, yeh<br/>(La Presión)</p>, <p>Otra, otra noche, otra<br/>(Ay, que yo no te boté)<br/>Otra, otra noche, otra</p>, <p>(Aunque tú vuelva' con él)<br/>Otra, otra noche, otra<br/>(Ay, que yo-yo no te boté)<br/>Otra, otra noche, otra</p>, <p>Y olvídate de la gente<br/>Lo comenta' bien diferente<br/>Baby, a vece' te acalora, te besa, te abraza, pero no te siente</p>, <p>Conmigo es algo diferente<br/>Tú lo que quiere' es que te entre<br/>Porque a vece' no te acalora, te besa, por eso cuando tú me siente'</p>, <p>Dile que bailando te conocí-í, cuéntale<br/>Dile que esta noche me quieres ve-er, cuéntale<br/>Dile que solo quiero otra noche</p>, <p>Cuéntale lo que hicimo' anoche<br/>Mi piel huele a tu perfume Dolce<br/>Baby, él no te conoce</p>, <p> Música comienza con letras<br/> © 2003 - 2022, 3.2 millones de canciones <br/> Hecho con <b>amor</b> en Belo Horizonte - Brasil </p>, <p>Asociados:</p>, <p style="display: none;">Quiero recibir notificaciones de artistas destacados y noticias.<span class="bt-toggle" id="js-toggle-push"></span></p>]

# %%
from queue import Empty

letra_cancion = ''
aux = 0
for p in p_main:
    #print(p.text)
    #if (es_letras_com):
    spans = p.findAll("span")
    if (not spans):
        if hasattr(p, 'text'):
            letra_cancion = letra_cancion + p.text + ' '
            print(p.text)
    else:
        for span in spans:
            if hasattr(span, 'text'):
                letra_cancion = letra_cancion + span.text + ' '
        
#print(letra_cancion)
# Out:
# Dile que no te has decididoQue no sabe' lo de tener maridoDile que no' vemo' a seguido
# Qué tú me escribe' aunque no me ha' seguidoY cuando están a sola'Él te trata mal, no te valoraLlega a la casa a saber la hora
# Dile que bailando te conocí-í, cuéntaleDile que esta noche me quieres ve-er, cuéntaleDile que solo quiero otra noche
# Cuéntale lo que hicimo' anocheMi piel huele a tu perfume DolceBaby, él no te conoce yDile que bailando te conocí-í, cuéntale
# Tú siempre encima de mí-í, cuéntaleDile que solo quiero otra nocheCuéntale lo que hicimo' anoche
# Mi piel huele a tu perfume DolceBaby, él no te conoce(No te conoce, ¿me sigue'?), yeh
# Dime, baby, lo que está' haciendoCon él siempre peleando, conmigo bebiendoSe comenta por ahí que se está enterandoYo no sé por qué carajo' tú' no' está' escondiendo
# No seas una pobre diabla (diabla)Cuando está contigo ni te habla (habla)Tú te siente' sola y eso te endiablaLleva tiempo que no te da tabla
# Y olvídate de la genteLo comenta' bien diferenteBaby, a vece' te acalora, te besa, te abraza, pero no te siente
# Conmigo es algo diferenteTú lo que quiere' es que te entrePorque a vece' él no te acalora, te besa, por eso cuando tú me siente'
# Dile que bailando te conocí-í, cuéntaleDile que esta noche me quieres ve-er, cuéntaleDile que solo quiero otra nocheCuéntale lo que hicimo' anoche
# Mi piel huele a tu perfume DolceBaby, él no te conoce yDile que bailando te conocí-í, cuéntaleTú siempre encima de mí-í, cuéntale
# Dile que solo quiero otra nocheCuéntale lo que hicimo' anocheMi piel huele a tu perfume DolceBaby, él no te conoce, yeh(La Presión)
# Otra, otra noche, otra(Ay, que yo no te boté)Otra, otra noche, otra
# (Aunque tú vuelva' con él)Otra, otra noche, otra(Ay, que yo-yo no te boté)Otra, otra noche, otra
# Y olvídate de la genteLo comenta' bien diferenteBaby, a vece' te acalora, te besa, te abraza, pero no te siente
# Conmigo es algo diferenteTú lo que quiere' es que te entrePorque a vece' no te acalora, te besa, por eso cuando tú me siente'
# Dile que bailando te conocí-í, cuéntaleDile que esta noche me quieres ve-er, cuéntaleDile que solo quiero otra noche
# Cuéntale lo que hicimo' anocheMi piel huele a tu perfume DolceBaby, él no te conoce
#  Música comienza con letras © 2003 - 2022, 3.2 millones de canciones  Hecho con amor en Belo Horizonte - Brasil
# Asociados:
