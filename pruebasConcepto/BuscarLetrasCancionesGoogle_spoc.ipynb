# %%
import requests
from bs4 import BeautifulSoup

# Obtiene el contenido web del resultado de búsqueda
url_busqueda = "https://www.google.com/search?q=letra+Cold+Heart+Pnau+Remix+Elton+John+Dua+Lipa"
page = requests.get(url_busqueda)
print (page.content)
soup = BeautifulSoup(page.content, "html.parser")
print(soup)
# Out:
# b'<!doctype html><html lang="es-419"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>letra Cold Heart Pnau Remix Elton John Dua Lipa - Buscar con Google</title><script nonce="GJSQRf_LaKBYpPLXGZfx7g">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){\nvar a=window.performance;window.start=Date.now();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Mat
# ...

# %%
a_main = soup.findAll("a")
print(a_main)
# Out:
# [<a href="/?sa=X&amp;ved=0ahUKEwi3yZi2-Yz6AhWmomoFHZEADq0QOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a>, <a href="/search?q=letra+Cold+Heart+Pnau+Remix+Elton+John+Dua+Lipa&amp;ie=UTF-8&amp;gbv=1&amp;sei=fPAdY7ebGKbFqtsPkYG46Ao">aquí</a>, <a class="eZt8xd" href="/search?q=letra+Cold+Heart+Pnau+Remix+Elton+John+Dua+Lipa&amp;ie=UTF-8&amp;source=lnms&amp;tbm=vid&amp;sa=X&amp;ved=0ahUKEwi3yZi2-Yz6AhWmomoFHZEADq0Q_AUIBigB">Videos</a>, <a class="eZt8xd" href="/search?q=letra+Cold+Heart+Pnau+Remix+Elton+John+Dua+Lipa&amp;ie=UTF-8&amp;source=lnms&amp;tbm=isch&amp;sa=X&amp;ved=0ahUKEwi3yZi2-Yz6AhWmomoFHZEADq0Q_AUIBygC">Imágenes</a>, <a class="eZt8xd" href="/search?q=letra+Cold+Heart+Pnau+Remix+Elton+John+Dua+Lipa&amp;ie=UTF-8&amp;source=lnms&amp;tbm=nws&amp;sa=X&amp;ved=0ahUKEwi3yZi2-Yz6AhWmomoFHZEADq0Q_AUICCgD">Noticias</a>, <a href="https://maps.goog
# ...

# %%
# obtiene elementos del autor, cancion y enlace donde está la letra de la canción
from re import search


url_letra_cancion = ''
for a in a_main:
    href = a.get("href") 
    if search ('https', href) and search ('letra', href) and not search('google', href) and search ('Cold', href) and search ('Elton', href):
        print(href.replace('/url?q=', ''))
# Out:
# https://www.letraseningles.es/letrascanciones/traduccionesDF/EltonJohnDuaLipa-ColdHeart-Traducida.html&sa=U&ved=2ahUKEwi3yZi2-Yz6AhWmomoFHZEADq0QFnoECAUQAg&usg=AOvVaw1udzDA6dfYp3Kfd2k3h5vK
# https://www.musixmatch.com/es/letras/Elton-John-Dua-Lipa-PNAU/Cold-Heart-PNAU-Remix/traduccion/espanol&sa=U&ved=2ahUKEwi3yZi2-Yz6AhWmomoFHZEADq0QFnoECAkQAg&usg=AOvVaw1PdbxcPu5vPMpHS5sEU-Vz

# %%
# obtiene contenido de la página web de la letra de la canción
url_letra_cancion = 'https://www.letras.com/elton-john/cold-heart-pnau-remix-feat-dua-lipa/traduccion.html' 
#'https://www.letraseningles.es/letrascanciones/traduccionesDF/EltonJohnDuaLipa-ColdHeart-Traducida.html'
page_letra_cancion = requests.get(url_letra_cancion)
soup_letra_cancion = BeautifulSoup(page_letra_cancion.content, "html.parser")
print(soup_letra_cancion)
# Out:
# <!DOCTYPE HTML>
# ...

# %%
# obtiene el cuerpo del contenido web de la letra de la canción
p_main = soup_letra_cancion.find_all("p")
print(p_main)
# Out:
# [<p><span>It's a human sign</span><br><span>When things go wrong</span><br/><span>When the scent of her lingers</span><br/><span>And temptation's strong</span><br/></br></p>, <p><span>Cold, cold heart</span><br/><span>Hardened by you (oh)</span><br/><span>Some things looking better, baby</span><br/><span>Just passin' through (oh no, no, no, no)</span><br/></p>, <p><span>And I think it's gonna be a long, long time</span><br/><span>Till touchdown brings me 'round again to find</span><br/><span>I'm not the man they think I am at home</span><br/><span>Oh no, no, no, no (no, no, no, no)</span><br/><span>And this is what I should have said</span><br/><span>Well, I thought it but I kept it hid</span><br/></p>, <p><span>Cold, cold heart</span><br/><span>Hardened by you (oh)</span><br/><span>Some things looking better, baby</span><br/><span>Just passin' through (oh, no, no, no, no)</span><br/></p>, <p><span>And I think it's gonna be a long, long time</span><br/><span>Till touchdown brings me 
# ...

# %%
# obtiene la letra de la canción
letra_cancion = ''
aux = 0
for p in p_main:
    #print(p)
    spans = p.findAll("span")
    for span in spans:
        if hasattr(span, 'text'):
            print(span.text)
            letra_cancion = letra_cancion + span.text + ' '
#print(letra_cancion)
# Out:
# It's a human sign
# When things go wrong
# When the scent of her lingers
# And temptation's strong
# Cold, cold heart
# Hardened by you (oh)
# Some things looking better, baby
# Just passin' through (oh no, no, no, no)
# And I think it's gonna be a long, long time
# Till touchdown brings me 'round again to find
# I'm not the man they think I am at home
# Oh no, no, no, no (no, no, no, no)
# And this is what I should have said
# Well, I thought it but I kept it hid
# Cold, cold heart
# Hardened by you (oh)
# Some things looking better, baby
# Just passin' through (oh, no, no, no, no)
# And I think it's gonna be a long, long time
# Till touchdown brings me 'round again to find
# I'm not the man they think I am at home
# Oh no, no, no, no (no, no, no, no)
# And this is what I should have said
# Well, I thought it but I kept it hid
# Cold, cold heart (oh)
# Hardened by you
# Some things looking better, baby (oh)
# Just passin' through (oh, no, no, no, no)
# ...
