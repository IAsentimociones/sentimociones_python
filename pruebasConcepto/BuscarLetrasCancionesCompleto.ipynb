# %%
''' 
Prepara URL para búsqueda de canciones
url_busqueda = WEB_LETRAS + CANCION + AUTOR
'''
# pelele morad https://www.lyrics.com/lyrics/pelele%20morad 
# HAWÁI Maluma  https://www.lyrics.com/lyrics/hawai%20maluma
# SIN FRENOS ELADIO CARRIÓN / BIZARRAP / DUKI https://www.lyrics.com/lyrics/BUSCATE%20OTRO%20JC
# BUSCATE OTRO JC LA NEVULA / ATOMIC OTRO WAY
WEB_LYRICS = "https://www.lyrics.com/lyrics/"
cancion = "hawai" # utilizar %20 cuando hay espacios. Utilizar un método que traiga con %20 el nombre de la cancion 
autor = "%20" + "maluma" # utilizar %20 cuando hay espacios. Utilizar un método que codifique con %20 el nombre del autor
url_busqueda = '%s%s%s' % (WEB_LYRICS, cancion, autor) #"https://www.lyrics.com/lyrics/sin%20frenos%20BIZARRAP"
print(url_busqueda)
# Out:
# https://www.lyrics.com/lyrics/hawai%20maluma

# %%
import requests
from bs4 import BeautifulSoup

# Obtiene el contenido web del resultado de búsqueda
page = requests.get(url_busqueda)
soup = BeautifulSoup(page.content, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Lyrics containing the term: hawai maluma</title>
# <meta content="A list of lyrics, artists and songs that contain the term &amp;quot;hawai maluma&amp;quot; - from the Lyrics.com website." name="description"/>
# <meta content="hawai maluma lyrics, hawai maluma lyric, hawai maluma songs, hawai maluma artists, lyrics for hawai maluma" name="keywords"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="#830C66" name="theme-color">
# <base href="https://www.lyrics.com/"/>
# <script>
# s4Prefix = 'https://static.stands4.com';
# version = '1.4.5';
# </script>
# <link as="style" href="https://static.stands4.com/app_common/css/bootstrap-3.4.1.min.css" rel="preload"/>
# <link href="https://static.stands4.com/app_common/css/bootstrap-3.4.1.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect">
# <link as="style" href="//fonts.googleapis.com/css2?family=Yanone+Kaffeesatz:wght@400;700&amp;family=Oxygen:wght@400;700&amp;family=Droid+Serif:ital,wght@0,400;0,700;1,400;1,700&amp;family=Droid+Sans+Mono&amp;family=Alegreya+Sans:wght@800&amp;family=Original+Surfer&amp;display=swap" rel="preload">
# <link href="//fonts.googleapis.com/css2?family=Yanone+Kaffeesatz:wght@400;700&amp;family=Oxygen:wght@400;700&amp;family=Droid+Serif:ital,wght@0,400;0,700;1,400;1,700&amp;family=Droid+Sans+Mono&amp;family=Alegreya+Sans:wght@800&amp;family=Original+Surfer&amp;display=swap" media="print" onload="this.media='all'" rel="stylesheet"/>
# <noscript><link href="//fonts.googleapis.com/css2?family=Yanone+Kaffeesatz:wght@400;700&amp;family=Oxygen:wght@400;700&amp;family=Droid+Serif:ital,wght@0,400;0,700;1,400;1,700&amp;family=Droid+Sans+Mono&amp;family=Alegreya+Sans:wght@800&amp;family=Original+Surfer&amp;display=swap" rel="stylesheet"/></noscript>
# <link href="https://static.stands4.com/app_common/css/lyrc.css?v=1.8.80" rel="stylesheet"/>
# <link href="https://static.stands4.com/app_common/img/favicon_lyrc.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://static.stands4.com/app_common/img/favicon_lyrc.ico" rel="icon" type="image/x-icon"/>
# <link href="https://static.stands4.com/app_lyrics/open-search.xml" rel="search" title="Lyrics.com" type="application/opensearchdescription+xml"/>
# <!-- DFP head code - START -->
# <script>
#     var adsStart = (new Date()).getTime();
#     function detectWidth() {
#         return window.screen.width || window.innerWidth || window.document.documentElement.clientWidth || Math.min(window.innerWidth, window.document.documentElement.clientWidth) || window.innerWidth || window.document.documentElement.clientWidth || window.document.getElementsByTagName('body')[0].clientWidth;
#     }
#
#     function doDisplay(code){
#         for (var i = adUnits.length - 1; i >= 0; i--) {
#             if(adUnits[i].code == code){
#                 googletag.cmd.push(function() { googletag.display(code); });
#                 return true;
#             }
#         }
#         return false;
#     }
#
#     var TIMEOUT = 1000;
#     var EXCHANGE_RATE = 3.45;
#     var screenSizeMobile = 768;
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     var pbjs = pbjs || {};
#     pbjs.que = pbjs.que || [];
#     var adUnits = adUnits || [];
#
#     function initAdServer() {
#         if (pbjs.initAdserverSet) return;
#         (function() {
#             var gads = document.createElement('script');
#             gads.async = true;
#             gads.type = 'text/javascript';
#             gads.src = 'https://securepubads.g.doubleclick.net/tag/js/gpt.js';
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(gads, node);
#         })();
#         pbjs.initAdserverSet = true;
#     };
#     pbjs.timeout = setTimeout(initAdServer, TIMEOUT);
#     pbjs.timeStart = adsStart;
#
#     var dfpNetwork = '52304935';
#
#     // SizeMapping
#     var isDesk = detectWidth() >= screenSizeMobile;
#     var mapSizeMRU = [[300, 250], [300, 600]];
#     if(!isDesk) mapSizeMRU = [[300, 250]];
#
#     // START: Defining Adunits
#     if(isDesk){
#         /* Desktop Adunits */
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_IA_300x250_A",
#                 size: [[300, 250],[1,1]],
#                 code: 'div-gpt-ad-Lyrics_IA_300x250_A',
#                 assignToVariableName: false // false if not in use
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_IA_300x250_B",
#                 size: [[300, 250]],
#                 code: 'div-gpt-ad-Lyrics_IA_300x250_B',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_LR_300x250_A",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_LR_300x250_A',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_LR_300x250_B",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_LR_300x250_B',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_LR_300x250_C",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_LR_300x250_C',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_LR_300x250_D",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_LR_300x250_D',
#                 assignToVariableName: false
#              });
#     } else {
#         /* Mobile Adunits */
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_IA_300x250_A",
#                 size: [300, 250],
#                 code: 'div-gpt-ad-Lyrics_Mobile_IA_300x250_A',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_IA_300x250_B",
#                 size: [[300, 250]],
#                 code: 'div-gpt-ad-Lyrics_Mobile_IA_300x250_B',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_LR_300x250_A",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_Mobile_LR_300x250_A',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_LR_300x250_B",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_Mobile_LR_300x250_B',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_LR_300x250_C",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_Mobile_LR_300x250_C',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_LR_300x250_D",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_Mobile_LR_300x250_D',
#                 assignToVariableName: false
#              });
#     }
#     /* All devices*/
#     adUnits.push({
#             network: dfpNetwork,
#             adunit: "Lyrics_LR_125x125",
#             size: [[125, 125]],
#             code: 'div-gpt-ad-Lyrics_LR_125x125',
#             assignToVariableName: false
#          });
#
#     // END: Defining Adunits
#
#     googletag.cmd.push(function() {
#       if(adUnits){
#         var dfpSlots = [];
#         for (var i = 0, len = adUnits.length; i < len; i++) {
#           dfpSlots[i] = googletag.defineSlot('/'+adUnits[i].network+'/'+adUnits[i].adunit, adUnits[i].size, adUnits[i].code).addService(googletag.pubads());
#           if(adUnits[i].assignToVariableName && (adUnits[i].assignToVariableName !== null)) window[adUnits[i].assignToVariableName] = dfpSlots[i];
#         }
#       }
#     });
#     googletag.cmd.push(function() {
#         // Header Bidding Targeting
#         pbjs.que.push(function() {pbjs.setTargetingForGPTAsync();});
#
#         // Set targeting
#         googletag.pubads().setTargeting("device", !isDesk ? "mobile" : "desktop");
#
#         // Init DFP
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().collapseEmptyDivs();
#         googletag.enableServices();
#     });
# </script>
# <script async="" src="https://static.stands4.com/app_common/js/prebid.js" type="text/javascript"></script>
# <!-- DFP head code - END --><meta content="118234861672613" property="fb:app_id">
# <meta content="567628204450-49mrbnlqde6k322k6j1nmpstf86djv24.apps.googleusercontent.com" name="google-signin-client_id"/>
# </meta></link></link></meta></head>
# <body data-atp="ra-4f75bf3d5305fac2" data-fb="118234861672613" id="s4-page-serp">
# <div id="page-container">
# <header id="header">
# <div class="clearfix" id="header-int">
# <div id="user-hist"><a href="/search-history" title="History"><i class="fas fa-history"></i></a></div>
# <div id="user-login">
# <a href="login.php">Login</a> <i aria-hidden="true" class="fas fa-sign-in-alt"></i>
# </div>
# <div id="network-header"><span id="network-header-trigger">The <span class="hidden-xs">STANDS4 </span>Network<span class="arw">☰</span></span>
# <ul id="network-header-links" style="display:none;">
# <li class="nw-abbreviations"><a href="https://www.abbreviations.com/">ABBREVIATIONS</a></li>
# <li class="nw-anagrams"><a href="https://www.anagrams.net/">ANAGRAMS</a></li>
# <li class="nw-biographies"><a href="https://www.biographies.net/">BIOGRAPHIES</a></li>
# <li class="nw-calculator"><a href="https://www.calculators.net/">CALCULATORS</a></li>
# <li class="nw-convert"><a href="https://www.convert.net/">CONVERSIONS</a></li>
# <li class="nw-definitions"><a href="https://www.definitions.net/">DEFINITIONS</a></li>
# <li class="nw-grammar"><a href="https://www.grammar.com/">GRAMMAR</a></li>
# <li class="nw-literature"><a href="https://www.literature.com/">LITERATURE</a></li>
# <li class="nw-lyrics"><a href="https://www.lyrics.com/">LYRICS</a></li>
# <li class="nw-phrases"><a href="https://www.phrases.com/">PHRASES</a></li>
# <li class="nw-poetry"><a href="https://www.poetry.com/">POETRY</a></li>
# <li class="nw-quotes"><a href="https://www.quotes.net/">QUOTES</a></li>
# <li class="nw-references"><a href="https://www.references.net/">REFERENCES</a></li>
# <li class="nw-rhymes"><a href="https://www.rhymes.com/">RHYMES</a></li>
# <li class="nw-scripts"><a href="https://www.scripts.com/">SCRIPTS</a></li>
# <li class="nw-symbols"><a href="https://www.symbols.com/">SYMBOLS</a></li>
# <li class="nw-synonyms"><a href="https://www.synonyms.com/">SYNONYMS</a></li>
# <li class="nw-uszip"><a href="https://www.uszip.com/">USZIP</a></li>
# </ul>
# </div> </div>
# </header><div class="container" id="main" role="main"><div class="content-top" id="content-top">
# <div class="view-search view-desktop hidden-xs">
# <form action="subserp.php" id="search-frm" method="get">
# <input name="genre" type="hidden" value=""/>
# <input name="style" type="hidden" value=""/>
# <input name="year" type="hidden" value=""/>
# <input name="dec" type="hidden" value=""/>
# <div class="page-top-search rc5">
# <div class="page-word-search">
# <input autocomplete="off" class="page-word-search-query rc5" id="search" name="st" placeholder="Search for lyrics or artists..." type="text" value="hawai maluma"/>
# <div class="page-word-search-icon"><i aria-hidden="true" class="fas fa-search"></i></div>
# <button class="btn primary" id="page-word-search-button" type="submit">Search</button>
# </div>
# <div class="page-word-search-ops">
# <div><input checked="checked" class="custom-rb" id="page-word-search-op1" name="qtype" type="radio" value="1"/><label for="page-word-search-op1"><span>In Lyrics</span></label></div>
# <div><input class="custom-rb" id="page-word-search-op2" name="qtype" type="radio" value="2"/><label for="page-word-search-op2"><span>By Artist</span></label></div>
# <div><input class="custom-rb" id="page-word-search-op3" name="qtype" type="radio" value="3"/><label for="page-word-search-op3"><span>By Album</span></label></div>
# </div>
# </div>
# <div class="page-letter-search rc5"><a href="/artists/0">#</a><a href="/artists/A">A</a><a href="/artists/B">B</a><a href="/artists/C">C</a><a href="/artists/D">D</a><a href="/artists/E">E</a><a href="/artists/F">F</a><a href="/artists/G">G</a><a href="/artists/H">H</a><a href="/artists/I">I</a><a href="/artists/J">J</a><a href="/artists/K">K</a><a href="/artists/L">L</a><a href="/artists/M">M</a><a href="/artists/N">N</a><a href="/artists/O">O</a><a href="/artists/P">P</a><a href="/artists/Q">Q</a><a href="/artists/R">R</a><a href="/artists/S">S</a><a href="/artists/T">T</a><a href="/artists/U">U</a><a href="/artists/V">V</a><a href="/artists/W">W</a><a href="/artists/X">X</a><a href="/artists/Y">Y</a><a href="/artists/Z">Z</a><span class="vbar"> </span><a class="z" href="/justadded">NEW</a><a aria-label="Random Lyrics" class="z" href="random.php"><i aria-hidden="true" class="fas fa-random"></i></a></div>
# </form> <div class="page-top-logo" onclick="location.href='https://www.lyrics.com/';"><img alt="Lyrics.com" src="https://static.stands4.com/app_common/img/top_logo_lyr.png" title="Lyrics.com"/></div>
# </div>
# <div class="view-search view-mobile visible-xs">
# <form action="subserp.php" id="search-frm-mob" method="get">
# <input name="genre" type="hidden" value=""/>
# <input name="style" type="hidden" value=""/>
# <input name="year" type="hidden" value=""/>
# <input name="dec" type="hidden" value=""/>
# <div class="page-top-search">
# <div class="page-word-search" style="width: calc(100% - 110px);">
# <div class="input-group">
# <input autocomplete="off" class="page-word-search-query form-control rc5" id="search-mob" name="st" placeholder="Search for lyrics..." type="text" value="hawai maluma"/>
# <span class="input-group-btn"><button aria-label="Search for lyrics or artists" class="btn primary" id="page-word-search-button-mob" type="submit"><i aria-hidden="true" class="fas fa-search"></i></button></span>
# </div>
# </div>
# <div class="page-word-search-ops">
# <div><input checked="checked" class="custom-rb" id="page-word-search-m-op1" name="qtype" type="radio" value="1"/><label for="page-word-search-m-op1"><span>In Lyrics</span></label></div>
# <div><input class="custom-rb" id="page-word-search-m-op2" name="qtype" type="radio" value="2"/><label for="page-word-search-m-op2"><span>By Artist</span></label></div>
# <div><input class="custom-rb" id="page-word-search-m-op3" name="qtype" type="radio" value="3"/><label for="page-word-search-m-op3"><span>by Album</span></label></div>
# </div>
# </div>
# <div class="page-letter-search"></div>
# </form> <div class="page-top-logo" onclick="location.href='https://www.lyrics.com/';"><img alt="Lyrics.com" src="https://static.stands4.com/app_common/img/top_logo_lyr.png" title="Lyrics.com"/></div>
# </div>
# </div>
# <div class="row">
# <div class="col-sm-8 col-sm-push-4" id="content-main">
# <div class="row">
# <div class="col-xs-12 col-sm-12">
# <div class="category-header clearfix">
# <div class="sub-category-header-icon hidden-xs"><i class="fas fa-music fa-4x"></i></div>
# <hgroup>
# <h3><a href="signup.php">Lyrics.com »</a></h3>
# <h1>Search results for 'hawai maluma'</h1>
# <h4>Yee yee! We've found <strong>19</strong> lyrics, <strong>5</strong> artists, and <strong>9</strong> albums matching <strong>hawai maluma</strong>.</h4>
# </hgroup>
# </div>
# </div>
# </div>
# <div class="row" id="content-body">
# <div class="col-xs-12 col-sm-12">
# <div class="row">
# <div class="adunit-middle adunit-middle-2col clearfix">
# <div class="col-xs-12 col-sm-12"><div id="div-gpt-ad-Lyrics_IA_300x250_A">
# <script>
# doDisplay('div-gpt-ad-Lyrics_IA_300x250_A');
# </script>
# </div>
# <div id="div-gpt-ad-Lyrics_Mobile_IA_300x250_A">
# <script>
# doDisplay('div-gpt-ad-Lyrics_Mobile_IA_300x250_A');
# </script>
# </div></div>
# </div>
# </div>
# <div class="clearfix row" id="content-filters">
# <div class="col-sm-5 col-xs-12 no-padding-right">
# <div class="col-sm-2 col-xs-1 no-padding"><strong>Year:</strong></div>
# <div class="col-sm-4 col-xs-3 no-padding">
# <div class="input-group">
# <input class="year-filter form-control" data-link="genres.php?genre=" max="2022" min="1900" placeholder="Year" step="1" type="number" value="">
# <input name="page" type="hidden" value="serp"/>
# <input name="qtype" type="hidden" value="1"/>
# <input name="stype" type="hidden" value="0"/>
# <span class="input-group-btn">
# <button class="btn primary" id="filter-year" type="button">Apply</button>
# </span>
# </input></div>
# </div>
# <div class="col-sm-4 col-xs-3 no-padding">
# <div class="decades">
# <select class="decades-filter">
# <option value="">Decade</option>
# <option value="1930">1930's</option>
# <option value="1940">1940's</option>
# <option value="1950">1950's</option>
# <option value="1960">1960's</option>
# <option value="1970">1970's</option>
# <option value="1980">1980's</option>
# <option value="1990">1990's</option>
# <option value="2000">2000's</option>
# <option value="2010">2010's</option>
# <option value="2020">2020's</option>
# </select>
# </div>
# </div>
# </div>
# <div class="col-sm-7 col-xs-12 no-padding-left">
# <span class="sort">
# <span class="sort"><strong>Search type:</strong><a class="rc3 s" href="/lyrics/hawai%20maluma">Within Lyrics</a><a class="rc3" href="serp.php?st=hawai+maluma&amp;stype=2">Lyrics Exact Match</a><a class="rc3" href="serp.php?st=hawai+maluma&amp;stype=1">Titles<span class="hidden-xs"> Exact Match</span></a></span> </span>
# </div>
# <br/><br/>
# <div class="col-xs-12">
# <strong>Filter by gender:</strong>
# <div aria-label="genders" class="btn-group genders-group" role="group">
# <button class="filter-gender btn btn-default xsml" data-val="m" onclick="javascript: location.href='serp.php?st=hawai+maluma&amp;gender=m';" title="Male" type="button"><i class="fas fa-male"></i></button>
# <button class="filter-gender btn btn-default xsml" data-val="f" onclick="javascript: location.href='serp.php?st=hawai+maluma&amp;gender=f';" title="Female" type="button"><i class="fas fa-female"></i></button>
# <button class="filter-gender btn btn-default xsml" data-val="g" onclick="javascript: location.href='serp.php?st=hawai+maluma&amp;gender=g';" title="Group" type="button"><i class="fas fa-users"></i></button>
# </div>
# </div>
# </div>
# <div>
# <h3>Artists:</h3>
# <table class="table tdata"><colgroup><col style="width: 210px;"/><col style="width: 210px;"/><col style="width: 210px;"/></colgroup><tbody><tr><td class="tal fx"><a aria-label="TLOTW Hawai'i" href="artist/TLOTW-Hawai%27i/2138049269" title="TLOTW Hawai'i"><img alt="" class="author-thumb-xs" loading="lazy" src="https://static.stands4.com/app_common/img/avatar_male.jpg"/></a><a class="name" href="artist/TLOTW-Hawai%27i/2138049269" title="TLOTW Hawai'i">TLOTW Hawai'i</a></td><td class="tal fx"><a aria-label="Larry Maluma" href="artist/Larry-Maluma/309342" title="Larry Maluma"><img alt="" class="author-thumb-xs" loading="lazy" src="https://static.stands4.com/app_common/img/avatar_male.jpg"/></a><a class="name" href="artist/Larry-Maluma/309342" title="Larry Maluma">Larry Maluma</a></td><td class="tal fx"><a aria-label="Maluma" href="artist/Maluma/2669415" title="Maluma"><img alt="" class="author-thumb-xs" loading="lazy" src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Maluma_-_Espaço_das_Américas_(37591053894).jpg/244px-Maluma_-_Espaço_das_Américas_(37591053894).jpg"/></a><a class="name" href="artist/Maluma/2669415" title="Maluma">Maluma</a></td></tr><tr><td class="tal fx"><a aria-label="Ilyas Maluma" href="artist/Ilyas-Maluma/2138070413" title="Ilyas Maluma"><img alt="" class="author-thumb-xs" loading="lazy" src="https://static.stands4.com/app_common/img/avatar_male.jpg"/></a><a class="name" href="artist/Ilyas-Maluma/2138070413" title="Ilyas Maluma">Ilyas Maluma</a></td><td class="tal fx"><a aria-label="Maluma" href="sub-artist/Maluma/35607" title="Maluma"><img alt="" class="author-thumb-xs" loading="lazy" src="https://www.lyrics.com/images/artist/sub/35607_maluma.png"/></a><a class="name" href="sub-artist/Maluma/35607" title="Maluma">Maluma</a></td><td class="tal fx"> </td></tr></tbody></table> </div>
# <div>
# <h3>Albums:</h3>
# <table class="table tdata"><colgroup><col style="width: 210px;"/><col style="width: 210px;"/><col style="width: 210px;"/></colgroup><tbody><tr><td class="tal fx df"><div><a aria-label="50 Greatest Songs of Hawai'i" href="/album/1316889/50-Greatest-Songs-of-Hawai%27i" title="50 Greatest Songs of Hawai'i"><img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRxF-Ey_Ikn2S9uBqn6YEC9FYPYUWV9ujMQ-ZuUyjkkI0OEzauabLLFRe0"/></a></div><div><div><a class="name" href="/album/1316889/50-Greatest-Songs-of-Hawai%27i" title="50 Greatest Songs of Hawai'i">50 Greatest Songs o…</a></div><div style="font-weight: 500;"><span>Various Artists</span></div></div></td><td class="tal fx df"><div><a aria-label="Boat Days in Hawai'i" href="/album/815342/Boat-Days-in-Hawai%27i" title="Boat Days in Hawai'i"><img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRfJrSPrqd9X0JRZZqBMDC6CFXSxgJpW__STJiTb0Di-BUR0Cpd9BXudA&amp;s"/></a></div><div><div><a class="name" href="/album/815342/Boat-Days-in-Hawai%27i" title="Boat Days in Hawai'i">Boat Days in Hawai'i</a></div><div style="font-weight: 500;"><a href="artist/Moana-Chang/531945">Moana Chang</a></div></div></td><td class="tal fx df"><div><a aria-label="Christmas in Hawai'i" href="/album/812302/Christmas-in-Hawai%27i" title="Christmas in Hawai'i"><img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTqewRBvcYmAg7kc69VIOG2cEAwdLypElzkPe56DwYzwj8i4cRXfBzEusg&amp;s"/></a></div><div><div><a class="name" href="/album/812302/Christmas-in-Hawai%27i" title="Christmas in Hawai'i">Christmas in Hawai'i</a></div><div style="font-weight: 500;"><a href="artist/Danny-Couch/276738">Danny Couch</a></div></div></td></tr><tr><td class="tal fx df"><div><a aria-label="Hawaï" href="/album/537649/Hawa%C3%AF" title="Hawaï"><img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTIPUj_nPgMpMqx_hUKXL3ANQsXX36fxcXiiIKOZ7xm0JWm28M5xG-yj8UT"/></a></div><div><div><a class="name" href="/album/537649/Hawa%C3%AF" title="Hawaï">Hawaï</a></div><div style="font-weight: 500;"><a href="artist/Java/482497">Java</a></div></div></td><td class="tal fx df"><div><a aria-label="Hawaï [Bonus Tracks]" href="/album/981509/Hawa%C3%AF-%5BBonus-Tracks%5D" title="Hawaï [Bonus Tracks]"><img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT_iu2Wy7ITr9VBHPbNRo9x33O_rGXe0FsR6NeKsgz8ROk9wG07yWi0fhY"/></a></div><div><div><a class="name" href="/album/981509/Hawa%C3%AF-%5BBonus-Tracks%5D" title="Hawaï [Bonus Tracks]">Hawaï [Bonus Tracks]</a></div><div style="font-weight: 500;"><a href="artist/Java/482497">Java</a></div></div></td><td class="tal fx df"><div><a aria-label="I Miss You My Hawai'i" href="/album/514371/I-Miss-You-My-Hawai%27i" title="I Miss You My Hawai'i"><img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQY9AKLwaDCSe0xpZVsY3Bnm8ubqeGNN9vwi-evsmqLnouqqL5gGNKHfxds_Q"/></a></div><div><div><a class="name" href="/album/514371/I-Miss-You-My-Hawai%27i" title="I Miss You My Hawai'i">I Miss You My Hawai…</a></div><div style="font-weight: 500;"><a href="artist/N%C3%A3-Leo-Pilimehana/205947">Nã Leo Pilimehana</a></div></div></td></tr><tr><td class="tal fx df"><div><a aria-label="Mele O Hawai'i (Songs of Hawaii)" href="/album/2170095/Mele-O-Hawai%27i-%28Songs-of-Hawaii%29" title="Mele O Hawai'i (Songs of Hawaii)"><img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRE9l-BpMiq-exPxJXi6RsOwlFDghNn_AEMf4gcop0hWIPGVf8aJywfziA"/></a></div><div><div><a class="name" href="/album/2170095/Mele-O-Hawai%27i-%28Songs-of-Hawaii%29" title="Mele O Hawai'i (Songs of Hawaii)">Mele O Hawai'i (Son…</a></div><div style="font-weight: 500;"><a href="artist/Hapa/169773">Hapa</a></div></div></td><td class="tal fx ...
# <div>
# <h3>Lyrics:</h3>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5883205/Poeta+Alternativo/Mueve+tus+neuronas">Mueve tus neuronas</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Poeta-Alternativo/2137958449">Poeta Alternativo</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5883205/Poeta+Alternativo/Mueve+tus+neuronas';">Yo ofreciéndole hasta la luna
# Y quiere un caramelo de Ozuna
# Se siente en <em>Hawái</em> con <em>Maluma</em>
# Pero viven en mi colonia
# La bebida les endemonia
# Homenajean</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6190838/Danny+Romero/El+Otro">El Otro</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Danny-Romero/2024124">Danny Romero</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6190838/Danny+Romero/El+Otro';">Que ni <em>Maluma</em> por <em>Hawái</em>
#
# Emborracharnos con ganas
# En una calita escondía
# Hacerlo toda la noche
# Hasta que no podamos más
#
# Dime si la Luna te la</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5767654/Antonio+Delight/Desentendida">Desentendida</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Antonio-Delight/2137976548">Antonio Delight</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5767654/Antonio+Delight/Desentendida';">se esconde del puma
# Antes sacaba dieces, ahora diez se fuma
# Roba más suspiros que <em>Hawai</em> a <em>Maluma</em>
# Se excusa diciendo "no somos nada" si te engaña
# Pobre</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6232647/Pelouv/Entro+fresco+al+party+%28Radio+Edit%29">Entro fresco al party (Radio Edit)</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Pelouv/2137990826">Pelouv</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6232647/Pelouv/Entro+fresco+al+party+%28Radio+Edit%29';">tienes envidia pai. Muy lindo lo que en instagram posteas, <em>maluma</em> <em>Hawai</em>. Im nobody quiero una shorty que se quite el pantie quiero agraderme a mi. Hablar</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5531410/Camy+Gonzz%2C+Nico+R/Odisea">Odisea</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Camy-Gonzz%2C-Nico-R/2138208387">Camy Gonzz, Nico R</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5531410/Camy+Gonzz%2C+Nico+R/Odisea';">Déjame decirte nena, tu ausencia y la distancia
# Es lo que mi mente mas suena
# <em>Hawái</em> de vacaciones flow <em>Maluma</em>, ese es mi lema
# Bichota como Karol se te nota</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5293843/strak+baby/Esc%C3%A1pate+Conmigo+%28Kidd+Kream%29">Escápate Conmigo (Kidd Kream)</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/strak-baby/2137917359">strak baby</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5293843/strak+baby/Esc%C3%A1pate+Conmigo+%28Kidd+Kream%29';">fortuna
# Es mas caro que un viaje a la luna
# Baby como tu no hay otra, no existe ninguna
# Vacaciones en <em>Hawai</em> como lo dice <em>Maluma</em>
# Baby me tienes Hookeao' sin</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/2413107/Wuiinpic/En+TikTok">En TikTok</a></p>
# <p class="lyric-meta-artists"><a href="artist/Wuiinpic">Wuiinpic</a></p>
# <div class="album-thumb"><a aria-label="En TikTok by Wuiinpic" href="/album/"><img alt="" loading="lazy" src="..." title="En TikTok by Wuiinpic"/></a></div>
# <div class="clearfix"></div>
# <p class="lyric-meta-album"><a href="/album/"></a></p>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/2413107/Wuiinpic/En+TikTok';">TikTok TikTok TikTok
# que lo bailen que lo bailen
# TikTok TikTok TikTok  TikTok TikTok TikTok
# que lo bailen en TikTok
#
# Yo no soy <em>Maluma</em> dedicándote en <em>Hawái</em></pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/2384582/The+Weeknd/Haw%C3%A1i+%5BRemix%5D">Hawái [Remix]</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/The-Weeknd/2377309">The Weeknd</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/2384582/The+Weeknd/Haw%C3%A1i+%5BRemix%5D';">we'll share something that's real (oh yeah)
# I can tell that you're just tryna feel (oh no)
#
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6055786/Maluma/La+Botella">La Botella</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Maluma/2669415">Maluma</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6055786/Maluma/La+Botella';">Yeah-yeah-yeah
# <em>Maluma</em>, baby
# J Quiles
# Ay, Justin Quiles, mami
# For you my lova
# <em>Maluma</em>
#
# Me cansé, me cansé de buscar
# En otros beso' los labios</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6393896/Rodri+Roberts/La+Botella+%28Si+Estuviera+Ella%29">La Botella (Si Estuviera Ella)</a></p>
# <p class="lyric-meta-artists"><a href="artist/Rodri-Roberts">Rodri Roberts</a></p>
# <div class="album-thumb"><a aria-label="La Botella (Si Estuviera Ella) by Rodri Roberts" href="/album/"><img alt="" loading="lazy" src="..." title="La Botella (Si Estuviera Ella) by Rodri Roberts"/></a></div>
# <div class="clearfix"></div>
# <p class="lyric-meta-album"><a href="/album/"></a></p>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6393896/Rodri+Roberts/La+Botella+%28Si+Estuviera+Ella%29';">[Verso 2: <em>Maluma</em>]
# Ya he pasado por <em>Hawái</em> y Madrid (Yeah, yeah)
# Me he comido cuantos culo' por ahí
# Pero ninguna daría la vida por la mía
# Del modo que lo</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/1843281/Maluma/Haw%C3%A1i">Hawái</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Maluma/2669415">Maluma</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/1843281/Maluma/Haw%C3%A1i';">yo llegué primero
# Sé que te va ir bien pero no te quiere como yo te quiero
#
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones,</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6135931/DJ+Gustavo+Cabrera/Perreo+En+Hawai">Perreo En Hawai</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/DJ-Gustavo-Cabrera/2138335471">DJ Gustavo Cabrera</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6135931/DJ+Gustavo+Cabrera/Perreo+En+Hawai';">falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones
# Muy lindo en Instagram lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/2373405/MASSIVO/Haw%C3%A1i">Hawái</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/MASSIVO/2137864630">MASSIVO</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/2373405/MASSIVO/Haw%C3%A1i';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/3145286/Jhonny+Evidence/Hawai">Hawai</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Jhonny-Evidence/2137853027">Jhonny Evidence</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/3145286/Jhonny+Evidence/Hawai';">a ir bien, pero no te quiere como yo te quiero
#
# Puede que no te haga falta nada, aparentemente nada
# <em>Hawái</em> de vacaciones, mis felicitaciones
# Muy lindo en</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6303861/Pablo+Mariano/Hawaii">Hawaii</a></p>
# <p class="lyric-meta-artists"><a href="artist/Pablo-Mariano">Pablo Mariano</a></p>
# <div class="album-thumb"><a aria-label="Hawaii by Pablo Mariano" href="/album/"><img alt="" loading="lazy" src="..." title="Hawaii by Pablo Mariano"/></a></div>
# <div class="clearfix"></div>
# <p class="lyric-meta-album"><a href="/album/"></a></p>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6303861/Pablo+Mariano/Hawaii';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/3149480/Miky+Mendozza/Haw%C3%A1i">Hawái</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Miky-Mendozza/2137958309">Miky Mendozza</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/3149480/Miky+Mendozza/Haw%C3%A1i';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/7372960/Boricua+Boys/Haw%C3%A1i">Hawái</a></p>
# <p class="lyric-meta-artists"><a href="artist/Boricua-Boys">Boricua Boys</a></p>
# <div class="album-thumb"><a aria-label="Hawái by Boricua Boys" href="/album/"><img alt="" loading="lazy" src="..." title="Hawái by Boricua Boys"/></a></div>
# <div class="clearfix"></div>
# <p class="lyric-meta-album"><a href="/album/"></a></p>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/7372960/Boricua+Boys/Haw%C3%A1i';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5974729/Almighty/Me+Llueven+2">Me Llueven 2</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Almighty/3527">Almighty</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5974729/Almighty/Me+Llueven+2';">pa' que lo' recoja' (baby)
# No quiere' bala', mi herma, desaloja (¡wuh!)
# Aprende a surfear, por ahí viene la ola
# Yo vivo en <em>hawái</em>, bajo el cristal,</pre>
# </div>
# <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5974712/Almighty/Me+Llueven+%5BExtended%5D">Me Llueven [Extended]</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Almighty/3527">Almighty</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5974712/Almighty/Me+Llueven+%5BExtended%5D';">(baby)
# No quiere' bala', mi herma, desaloja (¡wuh!)
# Aprende a surfear, por ahí viene la ola
# Yo vivo en <em>Hawái</em>, bajo el cristal, grito: "Aloha" (hello)
# Y</pre>
# </div>
# <div class="tdata-ext">
# <div class="hidden-xs">
# </div>
# <div class="hidden-sm hidden-md hidden-lg">
# </div>
# </div>
# </div>
# <div class="row visible-xs">
# <div class="adunit-middle adunit-middle-2col clearfix">
# <div class="col-xs-12 col-sm-6 text-center"><div id="div-gpt-ad-Lyrics_Mobile_LR_300x250_D">
# <script>
# doDisplay('div-gpt-ad-Lyrics_Mobile_LR_300x250_D');
# </script>
# </div></div>
# </div>
# </div>
# <div class="callout comments-area">
# <div id="s4-comments">
# <h4>Discuss these <a href="/lyrics/hawai%20maluma">hawai maluma Lyrics</a> with the community:</h4>
# <div class="comment-form-container">
# <form id="frm-comment">
# <input id="commentId" name="comment_id" type="hidden">
# <input id="cmtPart" name="cmt_part" type="hidden" value="1">
# <input id="current-website" type="hidden" value="3">
# <input id="current-entity" type="hidden" value="">
# <input id="current-entityid" type="hidden" value="">
# <input id="comments-limit" type="hidden" value="10">
# <div class="form-group">
# <h5 id="frm-comment-count">0 Comments</h5>
# <div class="form-control" contenteditable="true" data-placeholder="Add a comment..." id="comment"></div>
# <div class="cmt-options">
# <div class="cmt-tools">
# <span class="cmt-tool rc5" data-action="picture" id="pic-toggle" title="Upload an image"><span class="glyphicon glyphicon-picture"></span></span>
# <div class="hidden" id="picture-btns">
# <input accept="image/*" class="pic-upload hidden" type="file"/>
# <input id="pic-stream" name="picture" type="hidden"/>
# <input id="pic-type" name="picture_type" type="hidden"/>
# <img alt="" height="14" id="pic-preview" src="" title="Preview" width="14"/>
# <span class="pic-name hidden-xs" style="display:none;"></span>
# <button class="btn secondary xxsml pic-clear" id="pic-clear" style="display:none;" type="button"><i class="fas fa-trash-alt"></i></button>
# </div>
# <span class="cmt-tool record-tool rc5 text-center" data-action="sound" id="start" title="Record a sound">
# <!-- <span class="glyphicon glyphicon-music"></span> -->
# <span class="ready"><i class="fas fa-microphone"></i></span>
# <span class="recording equalizer hidden"><span class="bar bar-1"></span><span class="bar bar-2"></span><span class="bar bar-3"></span></span>
# </span>
# <div class="record-tool hidden" id="record-btns">
# <button class="btn tertiary xxsml hidden" id="stop" title="Stop Recording" type="button"><i class="fas fa-stop"></i></button>
# <button class="btn tertiary xxsml hidden" id="play" title="Play" type="button"><i class="fas fa-play"></i></button>
# <audio hidden="" id="recorder" muted=""></audio>
# <audio hidden="" id="player"></audio>
# <small hidden="" id="play-time">0:00</small>
# <small hidden="" id="rec-time">0:00</small>
# <small> <button class="btn xxsml" hidden="" id="clear-audio" type="button">clear</button></small>
# <input id="rec-stream" name="sound" type="hidden"/>
# </div>
# </div>
# <div class="cmt-publish clearfix">
# <div class="col-xs-10 no-padding">
# <div class="checkbox" id="notify-box">
# <label class="small"><input id="notify" type="checkbox"/> Notify me of new comments via email.</label>
# </div>
# </div>
# <div class="col-xs-2 no-padding text-right">
# <button aria-label="Publish" class="btn btn-submit primary btn-sm btn-3" data-target="#login-modal" data-uid="" id="submitButton" type="button">
# <span class="hidden-xs">Publish</span><span class="visible-xs"><span class="glyphicon glyphicon-check"></span></span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <div id="comment-message"></div>
# </input></input></input></input></input></input></form>
# </div>
# <ul class="clearfix" id="comments-list"></ul>
# </div>
# <!-- Modal -->
# <div aria-hidden="true" aria-labelledby="cmt-report-label" class="modal fade" id="cmt-report-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span><span class="sr-only">Close</span></button>
# <h4 class="modal-title" id="cmt-report-label">Report Comment</h4>
# </div>
# <div class="modal-body">
# <p>We're doing our best to make sure our content is useful, accurate and safe.<br/>If by any chance you spot an inappropriate comment while navigating through our website please use this form to let us know, and we'll take care of it shortly.</p>
# <div class="form-group">
# <textarea class="form-control" id="cmt-report-reason" placeholder="You may specify the reason for the report here..." rows="3"></textarea>
# </div>
# <input id="cmt-reported" type="hidden"/>
# </div>
# <div class="modal-footer">
# <button class="btn" data-dismiss="modal" type="button">Cancel</button>
# <button class="btn primary report-comment" type="button">Report</button>
# </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="cmt-attachment-label" class="modal fade" id="cmt-attachment-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span><span class="sr-only">Close</span></button>
# <h4 class="modal-title" id="cmt-attachment-label">Attachment</h4>
# </div>
# <div class="modal-body flex-align-center justify-center">
# <img alt="" class="thumbnail" id="cmt-image"/>
# <audio controls="" id="cmt-player"></audio>
# </div>
# <div class="modal-footer">
# <button class="btn tertiary" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# <style>#login-modal.modal #or{background-color:#fff}#login-modal.modal .sn-message{list-style:none;font-size:11px;text-align:center;padding:0;margin:20px 0 -20px}#login-modal.modal .ptext{font-size:12px}#login-modal.modal .waiting{opacity:0;font-size:5px;height:15px}#login-modal.modal ul.errors-list{margin:0 0 10px;padding:0;list-style:none;line-height:12px;font-size:12px}</style>
# <div aria-hidden="true" aria-labelledby="loginModal" class="modal fade" id="login-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title" id="loginModal">You need to be logged in to <span class="modal-type">favorite</span>.</h4>
# </div>
# <div class="modal-body edit-content">
# <div class="row social-signin">
# <div class="col-xs-12 col-sm-6">
# <div class="g-signin2" data-height="40" data-longtitle="true" data-onfailure="onFailure" data-onsuccess="onSuccess" data-scope="profile email" data-theme="dark" data-width="240"></div> </div>
# <div class="col-xs-12 col-sm-6">
# <div class="fb-login-button" data-auto-logout-link="false" data-max-rows="3" data-onlogin="checkLoginState();" data-scope="email" data-show-faces="false" data-size="large" data-use-continue-as="true" data-width="240px"></div> </div>
# </div>
# <ul class="sn-message"></ul>
# <div class="or-container">
# <hr class="or-hr"/>
# <div id="or">or fill the form below</div>
# </div>
# <div class="row">
# <div class="col-sm-6 short_signin">
# <h4>Create a new account</h4>
# <div class="text-center waiting"><i class="fas fa-spinner fa-spin fa-3x fa-fw"></i></div>
# <form id="modal-signup-frm" method="post">
# <ul class="errors-list"></ul>
# <input id="frm-action" name="action" type="hidden" value="short_signin"/>
# <input id="frm-source" name="source" type="hidden" value="0"/>
# <input id="website" name="website" type="hidden" value="3"/>
# <input id="fld-sra" name="sra" type="hidden" value="200.105.247.2"/>
# <div class="bcols clearfix row">
# <section class="col-xs-12">
# <div class="col-left">
# <p>
# <label for="fld-rname">Your name:<span class="mandatory">*<span>Required</span></span></label>
# <input class="fw" id="fld-rname" maxlength="100" name="rname" type="text" value=""/>
# </p>
# </div>
# </section>
# <section class="col-xs-12">
# <div class="col-left">
# <p>
# <label for="fld-uemail">Your email address:<span class="mandatory">*<span>Required</span></span></label>
# <input class="fw" id="fld-uemail" maxlength="100" name="uemail" type="text" value=""/>
# </p>
# </div>
# </section>
# <section class="col-xs-12">
# <div class="col-left">
# <p>
# <label for="fld-uname">Pick a user name:<span class="mandatory">*<span>Required</span></span></label>
# <input class="fw" id="fld-uname" maxlength="50" name="uname" type="text" value=""/>
# </p>
# </div>
# </section>
# <section class="col-xs-12">
# <div class="col-left text-right">
# <p><button class="btn primary" type="submit">Join</button></p>
# </div>
# </section>
# </div>
# </form>
# </div>
# <div class="col-sm-6 short_login">
# <h4>Log In</h4>
# <div class="text-center waiting"><i class="fas fa-spinner fa-spin fa-3x fa-fw"></i></div>
# <form id="modal-login-frm" method="post">
# <ul class="errors-list"></ul>
# <input id="frm-action-2" name="action" type="hidden" value="short_login"/>
# <div class="scols clearfix">
# <section>
# <p>
# <label for="fld-uname-2">Username:<span class="mandatory">*<span>Required</span></span></label>
# <input class="fw" id="fld-uname-2" maxlength="50" name="uname" type="text" value=""/>
# </p>
# </section>
# <section>
# <p>
# <label for="fld-upass">Password:<span class="mandatory">*<span>Required</span></span></label>
# <input autocomplete="off" class="fw" id="fld-upass" maxlength="30" name="upass" type="password" value=""/>
# </p>
# </section>
# <section>
# <div class="inner-section text-right">
# <p><button class="btn primary" type="submit">Log In</button></p>
# <br/>
# <p class="ptext">Forgot your password?   <button class="btn secondary xxsml" onclick="location.href='https://www.lyrics.com/forgotpass.php';" type="button">Retrieve it</button></p>
# </div>
# </section>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div> </div>
# <div class="callout clearfix row">
# <div>
# <div class="callout-int">
# <div class="row">
# <div class="col-xs-12 col-sm-8">
# <hgroup>
# <h2>We need you!</h2>
# <h3>Help build the largest human-edited lyrics collection on the web!</h3>
# </hgroup>
# </div>
# <div class="col-xs-12 col-sm-4">
# <div class="actions"><button class="btn btn-2 primary lrg" onclick="location.href='https://www.lyrics.com/addlyric.php';" type="button">Add Lyrics</button></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-sm-pull-8" id="content-aside">
# <div class="hidden-xs">
# <div class="sep-area"><hr class="sep"/></div>
# <div class="tagline">
# <h3>The Web's Largest Resource for</h3>
# <h2>Music, Songs <span>&amp;</span> Lyrics</h2>
# </div> <div class="nsep"><hr/><h3>A Member Of The <span>STANDS4 Network</span></h3></div>
# <div id="sb-social">
# <div class="clearfix">
# <div class="social"><a href="#" id="share-facebook" rel="noopener noreferrer nofollow" target="_blank" title="Share this page on Facebook"><span class="fb"><i aria-hidden="true" class="fab fa-facebook-f"></i></span></a></div>
# <div class="social"><a href="#" id="share-twitter" rel="noopener noreferrer nofollow" target="_blank" title="Share this page on Twitter"><span class="tw"><i aria-hidden="true" class="fab fa-twitter"></i></span></a></div>
# <div class="social"><a href="#" id="share-reddit" rel="noopener noreferrer nofollow" target="_blank" title="Share this page on Reddit"><span class="rd"><i aria-hidden="true" class="fab fa-reddit-alien"></i></span></a></div>
# ...
# </div>
# </div>
# <script>if(!/chrome/.test(navigator.userAgent.toLowerCase())) {document.getElementById('install-button').style.display = 'none';}</script></div>
# <div class="cblocks"><div class="cblock fflag" id="install-button-ff">
# <div class="hp-sym-group-thumb"><i aria-hidden="true" class="fa-3x fab fa-firefox-browser"></i></div>
# <hgroup class="clearfix">
# <h4><a href="https://addons.mozilla.org/en-US/firefox/addon/lyrics-com/">Free, no signup required</a>:</h4>
# <h3 style="font-size: 28px; font-weight: 600; line-height: 36px;"><a href="https://addons.mozilla.org/en-US/firefox/addon/lyrics-com/">Add to Firefox</a></h3>
# </hgroup>
# <div class="cblock-int clearfix" style="padding: 10px 12px; margin-top: -10px;">
# <span style="font-size: 14px; color: #555;">Get instant explanation for any acronym or abbreviation that hits you anywhere on the web!</span>
# <div style="margin-top: 10px;"><button class="btn btn-2 primary" onclick="location.href='https://addons.mozilla.org/en-US/firefox/addon/lyrics-com/'" title="Add to Firefox" type="button">Two clicks install »</button></div>
# </div>
# </div>
# <script>if(navigator.userAgent.toLowerCase().indexOf('firefox') == -1) {document.getElementById('install-button-ff').style.display = 'none';}</script></div>
# <section class="ad-slot"><div id="div-gpt-ad-Lyrics_LR_300x250_D">
# <script>
# doDisplay('div-gpt-ad-Lyrics_LR_300x250_D');
# </script>
# </div></section>
# <br/>
# </div>
# </div>
# </div>
# <footer id="footer">
# <div class="clearfix container-fluid" id="footer-int">
# <div class="clearfix">
# <div class="col-xs-12 col-sm-3">
# <div class="row">
# <div class="col-xs-6 col-sm-5">
# <div class="h5">Company</div>
# <ul>
# <li><a href="https://www.lyrics.com/">Home</a></li>
# <li><a href="about.php">About</a></li>
# <li><a href="news.php">News</a></li>
# <li class="ex"><a href="press.php">Press</a></li>
# <li><a href="awards.php">Awards</a></li>
# <li><a href="testimonials.php">Testimonials</a></li>
# </ul>
# </div>
# <div class="col-xs-6 col-sm-7">
# <div class="h5">Editorial</div>
# <ul>
# <li><a href="login.php">Login</a></li>
# <li><a href="addlyric.php">Add new Lyrics</a></li>
# <li><a href="addalbum.php">Add a new Album</a></li>
# <li class="ex"><a href="signup.php">Become a Member</a></li>
# <li><a href="editors.php">Meet the Editors</a></li>
# <li><a href="/justadded">Recently Added</a></li>
# <li class="ex"><a href="/song-parodies">Song Parodies <b><i class="far fa-smile"></i></b></a></li>
# <li><a href="activity.php">Activity Log</a></li>
# <li><a href="toplyrics.php">Most Popular</a></li>
# <li class="ex"><a href="/sell-your-lyrics">Sell Your Lyrics</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4">
# <div class="row">
# <div class="col-xs-6 col-sm-6">
# <div class="h5">Services</div>
# <ul>
# <li class="ex"><a href="/playlist">Your Playlist</a></li>
# <li><a href="invite.php">Tell a Friend</a></li>
# <li><a href="#" id="page-bookmark">Bookmark Us</a></li>
# <li class="ex"><a href="promotion.php">Promote <i class="fas fa-bullhorn fa-1x"></i></a></li>
# <li><a href="help-me-find-the-song.php">Help me Out!</a></li>
# <li><a href="lyrics_api.php">Lyrics API</a></li>
# <li class="ex"><a href="top-on-radio.php">Top on Radio <i class="fas fa-microphone fa-1x"></i></a></li>
# <li><a href="/song-lyrics-generator">Lyrics Generator</a></li>
# <li class="ex"><a href="https://www.lyrics.com/lyrics-quiz">The Lyrics Quiz</a></li>
# <li><a href="/marketplace">Marketplace <i class="fas fa-shopping-bag fa-1x"></i></a></li>
# <li><a href="articles.php">Articles</a></li>
# </ul>
# </div>
# <div class="col-xs-6 col-sm-6">
# <div class="h5">Legal &amp; Contact</div>
# <ul class="last">
# <li><a href="terms.php">Terms of Use</a></li>
# <li><a href="privacy.php">Privacy Policy</a></li>
# <li><a href="contact.php">Contact Us</a></li>
# <li class="ex"><a href="advertise.php">Advertise</a></li>
# <li><a href="affiliate-program.php">Affiliate Program	</a></li>
# <li> </li>
# <li><span class="light">Get the Apps:</span></li>
# <li>
# <a aria-label="Lyrics.com on App Store" href="https://apps.apple.com/us/app/lyrics-com/id1467868195" style="font-size:20px; display: inline-block;" target="_blank">
# <i class="fab fa-apple"></i>
# </a>
# 								<a aria-label="Lyrics.com on Google Play" href="https://play.google.com/store/apps/details?id=com.stand4.lyrics" style="font-size:20px; display: inline-block" target="_blank">
# <i class="fab fa-android"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-5" id="s4-network">
# <div class="row">
# <div class="h5 col-xs-12 col-sm-12">The STANDS4 Network</div>
# </div>
# <!-- Desktop version -->
# <div class="clearfix row hidden-xs">
# <div class="col-xs-12 col-sm-8">
# <div class="row">
# <div class="col-xs-6 col-sm-6">
# <ul>
# <li class="nw-abbreviations"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.abbreviations.com/" rel="nofollow noopener noreferrer">Abbreviations</a></li>
# <li class="nw-calculator"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.calculators.net/" rel="nofollow noopener noreferrer">Calculators</a></li>
# <li class="nw-grammar"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.grammar.com/" rel="nofollow noopener noreferrer">Grammar</a></li>
# <li class="nw-phrases"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.phrases.com/" rel="nofollow noopener noreferrer">Phrases</a></li>
# <li class="nw-references"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.references.net/" rel="nofollow noopener noreferrer">References</a></li>
# <li class="nw-symbols"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.symbols.com/" rel="nofollow noopener noreferrer">Symbols</a></li>
# </ul>
# </div>
# <div class="col-xs-6 col-sm-6">
# <ul>
# <li class="nw-anagrams"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.anagrams.net/" rel="nofollow noopener noreferrer">Anagrams</a></li>
# <li class="nw-convert"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.convert.net/" rel="nofollow noopener noreferrer">Conversions</a></li>
# <li class="nw-ua"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.literature.com/" rel="nofollow noopener noreferrer">Literature</a></li>
# <li class="nw-poetry"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.poetry.com/" rel="nofollow noopener noreferrer">Poetry</a></li>
# <li class="nw-rhymes"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.rhymes.com/" rel="nofollow noopener noreferrer">Rhymes</a></li>
# <li class="nw-synonyms"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.synonyms.com/" rel="nofollow noopener noreferrer">Synonyms</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4">
# <ul class="last">
# <li class="nw-biographies"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.biographies.net/" rel="nofollow noopener noreferrer">Biographies</a></li>
# <li class="nw-definitions"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.definitions.net/" rel="nofollow noopener noreferrer">Definitions</a></li>
# <li class="nw-lyrics"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.lyrics.com/" rel="nofollow noopener noreferrer">Lyrics</a></li>
# <li class="nw-quotes"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.quotes.net/" rel="nofollow noopener noreferrer">Quotes</a></li>
# <li class="nw-scripts"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.scripts.com/" rel="nofollow noopener noreferrer">Scripts</a></li>
# <li class="nw-uszip"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.uszip.com/" rel="nofollow noopener noreferrer">Zip Codes</a></li>
# </ul>
# </div>
# </div>
# <!-- Mobile version -->
# <div class="clearfix row hidden-sm hidden-md hidden-lg">
# <div class="col-xs-12 col-sm-8">
# <div class="row">
# <div class="col-xs-6 col-sm-6">
# <ul>
# <li class="nw-abbreviations"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.abbreviations.com/" rel="nofollow noopener noreferrer">Abbreviations</a></li>
# <li class="nw-anagrams"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.anagrams.net/" rel="nofollow noopener noreferrer">Anagrams</a></li>
# <li class="nw-biographies"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.biographies.net/" rel="nofollow noopener noreferrer">Biographies</a></li>
# <li class="nw-convert"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.convert.net/" rel="nofollow noopener noreferrer">Conversions</a></li>
# <li class="nw-calculator"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.calculators.net/" rel="nofollow noopener noreferrer">Calculators</a></li>
# <li class="nw-definitions"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.definitions.net/" rel="nofollow noopener noreferrer">Definitions</a></li>
# <li class="nw-grammar"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.grammar.com/" rel="nofollow noopener noreferrer">Grammar</a></li>
# <li class="nw-ua"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.literature.com/" rel="nofollow noopener noreferrer">Literature</a></li>
# <li class="nw-lyrics"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.lyrics.com/" rel="nofollow noopener noreferrer">Lyrics</a></li>
# </ul>
# </div>
# <div class="col-xs-6 col-sm-6">
# <ul>
# <li class="nw-phrases"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.phrases.com/" rel="nofollow noopener noreferrer">Phrases</a></li>
# <li class="nw-poetry"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.poetry.com/" rel="nofollow noopener noreferrer">Poetry</a></li>
# <li class="nw-quotes"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.quotes.net/" rel="nofollow noopener noreferrer">Quotes</a></li>
# <li class="nw-references"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.references.net/" rel="nofollow noopener noreferrer">References</a></li>
# <li class="nw-rhymes"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.rhymes.com/" rel="nofollow noopener noreferrer">Rhymes</a></li>
# <li class="nw-scripts"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.scripts.com/" rel="nofollow noopener noreferrer">Scripts</a></li>
# <li class="nw-symbols"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.symbols.com/" rel="nofollow noopener noreferrer">Symbols</a></li>
# <li class="nw-synonyms"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.synonyms.com/" rel="nofollow noopener noreferrer">Synonyms</a></li>
# <li class="nw-uszip"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.uszip.com/" rel="nofollow noopener noreferrer">Zip Codes</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix">
# <div class="copyright"><strong>© 2001-2022 STANDS4 LLC.</strong><br/>All rights reserved.</div>
# <div id="social-icons">
# <a href="https://www.facebook.com/STANDS4" rel="nofollow noopener noreferrer" target="_blank" title="Facebook"><span class="social fb"><i aria-hidden="true" class="fab fa-facebook-f"></i></span></a>
# <a href="https://twitter.com/lyrics_dot_com" rel="nofollow noopener noreferrer" target="_blank" title="Twitter"><span class="social tw"><i aria-hidden="true" class="fab fa-twitter"></i></span></a>
# <a href="https://www.linkedin.com/company/stands4/" rel="nofollow noopener noreferrer" target="_blank" title="LinkedIn"><span class="social lkd"><i aria-hidden="true" class="fab fa-linkedin-in"></i></span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <link href="https://static.stands4.com/app_common/css/font-awesome-5.0.min.css" rel="stylesheet"/>
# <link href="https://static.stands4.com/app_common/css/smoothness/jquery-ui-1.13.2.custom.min.css?v=1.0.1" rel="stylesheet"/>
# <link href="https://static.stands4.com/app_common/css/chosen.min.css" rel="stylesheet"/>
# <script crossorigin="anonymous" defer="" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" src="//code.jquery.com/jquery-3.6.0.min.js"></script>
# <script defer="" src="https://static.stands4.com/app_common/js/libs/jquery-ui-1.13.2.custom.min.js?v=1.0.1"></script>
# <script defer="" src="https://static.stands4.com/app_common/js/libs/chosen.jquery.min.js"></script>
# <script defer="" src="https://static.stands4.com/app_common/js/libs/wselect.min.js"></script>
# <script defer="" src="https://static.stands4.com/app_common/js/libs/bootstrap-3.4.1.min.js"></script>
# <script defer="" src="https://static.stands4.com/app_lyrics/js/lyrc.min.js?v=1.4.5"></script>
# <script data-id="UA-172613-15" defer="" id="s4-analytics" src="https://static.stands4.com/app_common/js/page.analytics.min.js?v=1.4.5"></script>
# <script defer="" src="https://www.googletagmanager.com/gtag/js?id=UA-172613-15"></script><script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-6071864913982699"></script>
# </body>
# </html>
# <!-- Timer: 0.7183 secs | Server: ip-172-30-5-142 -->

# %%
#obtiene el cuerpo del contenido autor - canción
results = soup.find(id="content-body")
print(results.prettify())
# Out:
# <div class="row" id="content-body">
#  <div class="col-xs-12 col-sm-12">
#   <div class="row">
#    <div class="adunit-middle adunit-middle-2col clearfix">
#     <div class="col-xs-12 col-sm-12">
#      <div id="div-gpt-ad-Lyrics_IA_300x250_A">
#       <script>
#        doDisplay('div-gpt-ad-Lyrics_IA_300x250_A');
#       </script>
#      </div>
#      <div id="div-gpt-ad-Lyrics_Mobile_IA_300x250_A">
#       <script>
#        doDisplay('div-gpt-ad-Lyrics_Mobile_IA_300x250_A');
#       </script>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="clearfix row" id="content-filters">
#    <div class="col-sm-5 col-xs-12 no-padding-right">
#     <div class="col-sm-2 col-xs-1 no-padding">
#      <strong>
#       Year:
#      </strong>
#     </div>
#     <div class="col-sm-4 col-xs-3 no-padding">
#      <div class="input-group">
#       <input class="year-filter form-control" data-link="genres.php?genre=" max="2022" min="1900" placeholder="Year" step="1" type="number" value="">
#        <input name="page" type="hidden" value="serp"/>
#        <input name="qtype" type="hidden" value="1"/>
#        <input name="stype" type="hidden" value="0"/>
#        <span class="input-group-btn">
#         <button class="btn primary" id="filter-year" type="button">
#          Apply
#         </button>
#        </span>
#       </input>
#      </div>
#     </div>
#     <div class="col-sm-4 col-xs-3 no-padding">
#      <div class="decades">
#       <select class="decades-filter">
#        <option value="">
#         Decade
#        </option>
#        <option value="1930">
#         1930's
#        </option>
#        <option value="1940">
#         1940's
#        </option>
#        <option value="1950">
#         1950's
#        </option>
#        <option value="1960">
#         1960's
#        </option>
#        <option value="1970">
#         1970's
#        </option>
#        <option value="1980">
#         1980's
#        </option>
#        <option value="1990">
#         1990's
#        </option>
#        <option value="2000">
#         2000's
#        </option>
#        <option value="2010">
#         2010's
#        </option>
#        <option value="2020">
#         2020's
#        </option>
#       </select>
#      </div>
#     </div>
#    </div>
#    <div class="col-sm-7 col-xs-12 no-padding-left">
#     <span class="sort">
#      <span class="sort">
#       <strong>
#        Search type:
#       </strong>
#       <a class="rc3 s" href="/lyrics/hawai%20maluma">
#        Within Lyrics
#       </a>
#       <a class="rc3" href="serp.php?st=hawai+maluma&amp;stype=2">
#        Lyrics Exact Match
#       </a>
#       <a class="rc3" href="serp.php?st=hawai+maluma&amp;stype=1">
#        Titles
#        <span class="hidden-xs">
#         Exact Match
#        </span>
#       </a>
#      </span>
#     </span>
#    </div>
#    <br/>
#    <br/>
#    <div class="col-xs-12">
#     <strong>
#      Filter by gender:
#     </strong>
#     <div aria-label="genders" class="btn-group genders-group" role="group">
#      <button class="filter-gender btn btn-default xsml" data-val="m" onclick="javascript: location.href='serp.php?st=hawai+maluma&amp;gender=m';" title="Male" type="button">
#       <i class="fas fa-male">
#       </i>
#      </button>
#      <button class="filter-gender btn btn-default xsml" data-val="f" onclick="javascript: location.href='serp.php?st=hawai+maluma&amp;gender=f';" title="Female" type="button">
#       <i class="fas fa-female">
#       </i>
#      </button>
#      <button class="filter-gender btn btn-default xsml" data-val="g" onclick="javascript: location.href='serp.php?st=hawai+maluma&amp;gender=g';" title="Group" type="button">
#       <i class="fas fa-users">
#       </i>
#      </button>
#     </div>
#    </div>
#   </div>
#   <div>
#    <h3>
#     Artists:
#    </h3>
#    <table class="table tdata">
#     <colgroup>
#      <col style="width: 210px;"/>
#      <col style="width: 210px;"/>
#      <col style="width: 210px;"/>
#     </colgroup>
#     <tbody>
#      <tr>
#       <td class="tal fx">
#        <a aria-label="TLOTW Hawai'i" href="artist/TLOTW-Hawai%27i/2138049269" title="TLOTW Hawai'i">
#         <img alt="" class="author-thumb-xs" loading="lazy" src="https://static.stands4.com/app_common/img/avatar_male.jpg"/>
#        </a>
#        <a class="name" href="artist/TLOTW-Hawai%27i/2138049269" title="TLOTW Hawai'i">
#         TLOTW Hawai'i
#        </a>
#       </td>
#       <td class="tal fx">
#        <a aria-label="Larry Maluma" href="artist/Larry-Maluma/309342" title="Larry Maluma">
#         <img alt="" class="author-thumb-xs" loading="lazy" src="https://static.stands4.com/app_common/img/avatar_male.jpg"/>
#        </a>
#        <a class="name" href="artist/Larry-Maluma/309342" title="Larry Maluma">
#         Larry Maluma
#        </a>
#       </td>
#       <td class="tal fx">
#        <a aria-label="Maluma" href="artist/Maluma/2669415" title="Maluma">
#         <img alt="" class="author-thumb-xs" loading="lazy" src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Maluma_-_Espaço_das_Américas_(37591053894).jpg/244px-Maluma_-_Espaço_das_Américas_(37591053894).jpg"/>
#        </a>
#        <a class="name" href="artist/Maluma/2669415" title="Maluma">
#         Maluma
#        </a>
#       </td>
#      </tr>
#      <tr>
#       <td class="tal fx">
#        <a aria-label="Ilyas Maluma" href="artist/Ilyas-Maluma/2138070413" title="Ilyas Maluma">
#         <img alt="" class="author-thumb-xs" loading="lazy" src="https://static.stands4.com/app_common/img/avatar_male.jpg"/>
#        </a>
#        <a class="name" href="artist/Ilyas-Maluma/2138070413" title="Ilyas Maluma">
#         Ilyas Maluma
#        </a>
#       </td>
#       <td class="tal fx">
#        <a aria-label="Maluma" href="sub-artist/Maluma/35607" title="Maluma">
#         <img alt="" class="author-thumb-xs" loading="lazy" src="https://www.lyrics.com/images/artist/sub/35607_maluma.png"/>
#        </a>
#        <a class="name" href="sub-artist/Maluma/35607" title="Maluma">
#         Maluma
#        </a>
#       </td>
#       <td class="tal fx">
#       </td>
#      </tr>
#     </tbody>
#    </table>
#   </div>
#   <div>
#    <h3>
#     Albums:
#    </h3>
#    <table class="table tdata">
#     <colgroup>
#      <col style="width: 210px;"/>
#      <col style="width: 210px;"/>
#      <col style="width: 210px;"/>
#     </colgroup>
#     <tbody>
#      <tr>
#       <td class="tal fx df">
#        <div>
#         <a aria-label="50 Greatest Songs of Hawai'i" href="/album/1316889/50-Greatest-Songs-of-Hawai%27i" title="50 Greatest Songs of Hawai'i">
#          <img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRxF-Ey_Ikn2S9uBqn6YEC9FYPYUWV9ujMQ-ZuUyjkkI0OEzauabLLFRe0"/>
#         </a>
#        </div>
#        <div>
#         <div>
#          <a class="name" href="/album/1316889/50-Greatest-Songs-of-Hawai%27i" title="50 Greatest Songs of Hawai'i">
#           50 Greatest Songs o…
#          </a>
#         </div>
#         <div style="font-weight: 500;">
#          <span>
#           Various Artists
#          </span>
#         </div>
#        </div>
#       </td>
#       <td class="tal fx df">
#        <div>
#         <a aria-label="Boat Days in Hawai'i" href="/album/815342/Boat-Days-in-Hawai%27i" title="Boat Days in Hawai'i">
#          <img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRfJrSPrqd9X0JRZZqBMDC6CFXSxgJpW__STJiTb0Di-BUR0Cpd9BXudA&amp;s"/>
#         </a>
#        </div>
#        <div>
#         <div>
#          <a class="name" href="/album/815342/Boat-Days-in-Hawai%27i" title="Boat Days in Hawai'i">
#           Boat Days in Hawai'i
#          </a>
#         </div>
#         <div style="font-weight: 500;">
#          <a href="artist/Moana-Chang/531945">
#           Moana Chang
#          </a>
#         </div>
#        </div>
#       </td>
#       <td class="tal fx df">
#        <div>
#         <a aria-label="Christmas in Hawai'i" href="/album/812302/Christmas-in-Hawai%27i" title="Christmas in Hawai'i">
#          <img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTqewRBvcYmAg7kc69VIOG2cEAwdLypElzkPe56DwYzwj8i4cRXfBzEusg&amp;s"/>
#         </a>
#        </div>
#        <div>
#         <div>
#          <a class="name" href="/album/812302/Christmas-in-Hawai%27i" title="Christmas in Hawai'i">
#           Christmas in Hawai'i
#          </a>
#         </div>
#         <div style="font-weight: 500;">
#          <a href="artist/Danny-Couch/276738">
#           Danny Couch
#          </a>
#         </div>
#        </div>
#       </td>
#      </tr>
#      <tr>
#       <td class="tal fx df">
#        <div>
#         <a aria-label="Hawaï" href="/album/537649/Hawa%C3%AF" title="Hawaï">
#          <img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTIPUj_nPgMpMqx_hUKXL3ANQsXX36fxcXiiIKOZ7xm0JWm28M5xG-yj8UT"/>
#         </a>
#        </div>
#        <div>
#         <div>
#          <a class="name" href="/album/537649/Hawa%C3%AF" title="Hawaï">
#           Hawaï
#          </a>
#         </div>
#         <div style="font-weight: 500;">
#          <a href="artist/Java/482497">
#           Java
#          </a>
#         </div>
#        </div>
#       </td>
#       <td class="tal fx df">
#        <div>
#         <a aria-label="Hawaï [Bonus Tracks]" href="/album/981509/Hawa%C3%AF-%5BBonus-Tracks%5D" title="Hawaï [Bonus Tracks]">
#          <img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT_iu2Wy7ITr9VBHPbNRo9x33O_rGXe0FsR6NeKsgz8ROk9wG07yWi0fhY"/>
#         </a>
#        </div>
#        <div>
#         <div>
#          <a class="name" href="/album/981509/Hawa%C3%AF-%5BBonus-Tracks%5D" title="Hawaï [Bonus Tracks]">
#           Hawaï [Bonus Tracks]
#          </a>
#         </div>
#         <div style="font-weight: 500;">
#          <a href="artist/Java/482497">
#           Java
#          </a>
#         </div>
#        </div>
#       </td>
#       <td class="tal fx df">
#        <div>
#         <a aria-label="I Miss You My Hawai'i" href="/album/514371/I-Miss-You-My-Hawai%27i" title="I Miss You My Hawai'i">
#          <img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQY9AKLwaDCSe0xpZVsY3Bnm8ubqeGNN9vwi-evsmqLnouqqL5gGNKHfxds_Q"/>
#         </a>
#        </div>
#        <div>
#         <div>
#          <a class="name" href="/album/514371/I-Miss-You-My-Hawai%27i" title="I Miss You My Hawai'i">
#           I Miss You My Hawai…
#          </a>
#         </div>
#         <div style="font-weight: 500;">
#          <a href="artist/N%C3%A3-Leo-Pilimehana/205947">
#           Nã Leo Pilimehana
#          </a>
#         </div>
#        </div>
#       </td>
#      </tr>
#      <tr>
#       <td class="tal fx df">
#        <div>
#         <a aria-label="Mele O Hawai'i (Songs of Hawaii)" href="/album/2170095/Mele-O-Hawai%27i-%28Songs-of-Hawaii%29" title="Mele O Hawai'i (Songs of Hawaii)">
#          <img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRE9l-BpMiq-exPxJXi6RsOwlFDghNn_AEMf4gcop0hWIPGVf8aJywfziA"/>
#         </a>
#        </div>
#        <div>
#         <div>
#          <a class="name" href="/album/2170095/Mele-O-Hawai%27i-%28Songs-of-Hawaii%29" title="Mele O Hawai'i (Songs of Hawaii)">
#           Mele O Hawai'i (Son…
#          </a>
#         </div>
#         <div style="font-weight: 500;">
#          <a href="artist/Hapa/169773">
#           Hapa
#          </a>
#         </div>
#        </div>
#       </td>
#       <td class="tal fx df">
#        <div>
#         <a aria-label="No Hawai" href="/album/382376/No-Hawai" title="No Hawai">
#          <img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRepmXSiZfgICsNkbvGkbbwRCLNKGAx6BwkSLwCEd7bp9QFABQEvYpISw"/>
#         </a>
#        </div>
#        <div>
#         <div>
#          <a class="name" href="/album/382376/No-Hawai" title="No Hawai">
#           No Hawai
#          </a>
#         </div>
#         <div style="font-weight: 500;">
#          <a href="artist/%C3%89-o-Tchan/210617">
#           É o Tchan
#          </a>
#         </div>
#        </div>
#       </td>
#       <td class="tal fx df">
#        <div>
#         <a aria-label="Over Hawai'i" href="/album/2403113/Over-Hawai%27i" title="Over Hawai'i">
#          <img alt="" class="album-thumb-xs" loading="lazy" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQkHyxqAmCEDsIGF-p8Tcn10PqUdq3kvGpLYFhzwXygrze3CDEEF8J3PDZg&amp;s"/>
#         </a>
#        </div>
#        <div>
#         <div>
#          <a class="name" href="/album/2403113/Over-Hawai%27i" title="Over Hawai'i">
#           Over Hawai'i
#          </a>
#         </div>
#         <div style="font-weight: 500;">
#          <a href="artist/Hapa/169773">
#           Hapa
#          </a>
#         </div>
#        </div>
#       </td>
#      </tr>
#     </tbody>
#    </table>
#   </div>
#   <div>
#    <h3>
#     Lyrics:
#    </h3>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/5883205/Poeta+Alternativo/Mueve+tus+neuronas">
#        Mueve tus neuronas
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Poeta-Alternativo/2137958449">
#        Poeta Alternativo
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5883205/Poeta+Alternativo/Mueve+tus+neuronas';">Yo ofreciéndole hasta la luna
# Y quiere un caramelo de Ozuna
# Se siente en <em>Hawái</em> con <em>Maluma</em>
# Pero viven en mi colonia
# La bebida les endemonia
# Homenajean</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/6190838/Danny+Romero/El+Otro">
#        El Otro
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Danny-Romero/2024124">
#        Danny Romero
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6190838/Danny+Romero/El+Otro';">Que ni <em>Maluma</em> por <em>Hawái</em>
#
# Emborracharnos con ganas
# En una calita escondía
# Hacerlo toda la noche
# Hasta que no podamos más
#
# Dime si la Luna te la</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/5767654/Antonio+Delight/Desentendida">
#        Desentendida
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Antonio-Delight/2137976548">
#        Antonio Delight
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5767654/Antonio+Delight/Desentendida';">se esconde del puma
# Antes sacaba dieces, ahora diez se fuma
# Roba más suspiros que <em>Hawai</em> a <em>Maluma</em>
# Se excusa diciendo "no somos nada" si te engaña
# Pobre</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/6232647/Pelouv/Entro+fresco+al+party+%28Radio+Edit%29">
#        Entro fresco al party (Radio Edit)
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Pelouv/2137990826">
#        Pelouv
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6232647/Pelouv/Entro+fresco+al+party+%28Radio+Edit%29';">tienes envidia pai. Muy lindo lo que en instagram posteas, <em>maluma</em> <em>Hawai</em>. Im nobody quiero una shorty que se quite el pantie quiero agraderme a mi. Hablar</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/5531410/Camy+Gonzz%2C+Nico+R/Odisea">
#        Odisea
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Camy-Gonzz%2C-Nico-R/2138208387">
#        Camy Gonzz, Nico R
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5531410/Camy+Gonzz%2C+Nico+R/Odisea';">Déjame decirte nena, tu ausencia y la distancia
# Es lo que mi mente mas suena
# <em>Hawái</em> de vacaciones flow <em>Maluma</em>, ese es mi lema
# Bichota como Karol se te nota</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/5293843/strak+baby/Esc%C3%A1pate+Conmigo+%28Kidd+Kream%29">
#        Escápate Conmigo (Kidd Kream)
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/strak-baby/2137917359">
#        strak baby
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5293843/strak+baby/Esc%C3%A1pate+Conmigo+%28Kidd+Kream%29';">fortuna
# Es mas caro que un viaje a la luna
# Baby como tu no hay otra, no existe ninguna
# Vacaciones en <em>Hawai</em> como lo dice <em>Maluma</em>
# Baby me tienes Hookeao' sin</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/2413107/Wuiinpic/En+TikTok">
#        En TikTok
#       </a>
#      </p>
#      <p class="lyric-meta-artists">
#       <a href="artist/Wuiinpic">
#        Wuiinpic
#       </a>
#      </p>
#      <div class="album-thumb">
#       <a aria-label="En TikTok by Wuiinpic" href="/album/">
#        <img alt="" loading="lazy" src="..." title="En TikTok by Wuiinpic"/>
#       </a>
#      </div>
#      <div class="clearfix">
#      </div>
#      <p class="lyric-meta-album">
#       <a href="/album/">
#       </a>
#      </p>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/2413107/Wuiinpic/En+TikTok';">TikTok TikTok TikTok
# que lo bailen que lo bailen
# TikTok TikTok TikTok  TikTok TikTok TikTok
# que lo bailen en TikTok
#
# Yo no soy <em>Maluma</em> dedicándote en <em>Hawái</em></pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/2384582/The+Weeknd/Haw%C3%A1i+%5BRemix%5D">
#        Hawái [Remix]
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/The-Weeknd/2377309">
#        The Weeknd
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/2384582/The+Weeknd/Haw%C3%A1i+%5BRemix%5D';">we'll share something that's real (oh yeah)
# I can tell that you're just tryna feel (oh no)
#
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/6055786/Maluma/La+Botella">
#        La Botella
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Maluma/2669415">
#        Maluma
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6055786/Maluma/La+Botella';">Yeah-yeah-yeah
# <em>Maluma</em>, baby
# J Quiles
# Ay, Justin Quiles, mami
# For you my lova
# <em>Maluma</em>
#
# Me cansé, me cansé de buscar
# En otros beso' los labios</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/6393896/Rodri+Roberts/La+Botella+%28Si+Estuviera+Ella%29">
#        La Botella (Si Estuviera Ella)
#       </a>
#      </p>
#      <p class="lyric-meta-artists">
#       <a href="artist/Rodri-Roberts">
#        Rodri Roberts
#       </a>
#      </p>
#      <div class="album-thumb">
#       <a aria-label="La Botella (Si Estuviera Ella) by Rodri Roberts" href="/album/">
#        <img alt="" loading="lazy" src="..." title="La Botella (Si Estuviera Ella) by Rodri Roberts"/>
#       </a>
#      </div>
#      <div class="clearfix">
#      </div>
#      <p class="lyric-meta-album">
#       <a href="/album/">
#       </a>
#      </p>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6393896/Rodri+Roberts/La+Botella+%28Si+Estuviera+Ella%29';">[Verso 2: <em>Maluma</em>]
# Ya he pasado por <em>Hawái</em> y Madrid (Yeah, yeah)
# Me he comido cuantos culo' por ahí
# Pero ninguna daría la vida por la mía
# Del modo que lo</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/1843281/Maluma/Haw%C3%A1i">
#        Hawái
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Maluma/2669415">
#        Maluma
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/1843281/Maluma/Haw%C3%A1i';">yo llegué primero
# Sé que te va ir bien pero no te quiere como yo te quiero
#
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones,</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/6135931/DJ+Gustavo+Cabrera/Perreo+En+Hawai">
#        Perreo En Hawai
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/DJ-Gustavo-Cabrera/2138335471">
#        DJ Gustavo Cabrera
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6135931/DJ+Gustavo+Cabrera/Perreo+En+Hawai';">falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones
# Muy lindo en Instagram lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/2373405/MASSIVO/Haw%C3%A1i">
#        Hawái
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/MASSIVO/2137864630">
#        MASSIVO
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/2373405/MASSIVO/Haw%C3%A1i';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/3145286/Jhonny+Evidence/Hawai">
#        Hawai
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Jhonny-Evidence/2137853027">
#        Jhonny Evidence
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/3145286/Jhonny+Evidence/Hawai';">a ir bien, pero no te quiere como yo te quiero
#
# Puede que no te haga falta nada, aparentemente nada
# <em>Hawái</em> de vacaciones, mis felicitaciones
# Muy lindo en</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/6303861/Pablo+Mariano/Hawaii">
#        Hawaii
#       </a>
#      </p>
#      <p class="lyric-meta-artists">
#       <a href="artist/Pablo-Mariano">
#        Pablo Mariano
#       </a>
#      </p>
#      <div class="album-thumb">
#       <a aria-label="Hawaii by Pablo Mariano" href="/album/">
#        <img alt="" loading="lazy" src="..." title="Hawaii by Pablo Mariano"/>
#       </a>
#      </div>
#      <div class="clearfix">
#      </div>
#      <p class="lyric-meta-album">
#       <a href="/album/">
#       </a>
#      </p>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6303861/Pablo+Mariano/Hawaii';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/3149480/Miky+Mendozza/Haw%C3%A1i">
#        Hawái
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Miky-Mendozza/2137958309">
#        Miky Mendozza
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/3149480/Miky+Mendozza/Haw%C3%A1i';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/7372960/Boricua+Boys/Haw%C3%A1i">
#        Hawái
#       </a>
#      </p>
#      <p class="lyric-meta-artists">
#       <a href="artist/Boricua-Boys">
#        Boricua Boys
#       </a>
#      </p>
#      <div class="album-thumb">
#       <a aria-label="Hawái by Boricua Boys" href="/album/">
#        <img alt="" loading="lazy" src="..." title="Hawái by Boricua Boys"/>
#       </a>
#      </div>
#      <div class="clearfix">
#      </div>
#      <p class="lyric-meta-album">
#       <a href="/album/">
#       </a>
#      </p>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/7372960/Boricua+Boys/Haw%C3%A1i';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/5974729/Almighty/Me+Llueven+2">
#        Me Llueven 2
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Almighty/3527">
#        Almighty
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5974729/Almighty/Me+Llueven+2';">pa' que lo' recoja' (baby)
# No quiere' bala', mi herma, desaloja (¡wuh!)
# Aprende a surfear, por ahí viene la ola
# Yo vivo en <em>hawái</em>, bajo el cristal,</pre>
#    </div>
#    <div class="sec-lyric clearfix">
#     <div class="lyric-meta within-lyrics">
#      <p class="lyric-meta-title">
#       <a href="/lyric-lf/5974712/Almighty/Me+Llueven+%5BExtended%5D">
#        Me Llueven [Extended]
#       </a>
#      </p>
#      <p class="lyric-meta-album-artist">
#       <a href="artist/Almighty/3527">
#        Almighty
#       </a>
#      </p>
#      <div class="clearfix">
#      </div>
#     </div>
#     <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5974712/Almighty/Me+Llueven+%5BExtended%5D';">(baby)
# No quiere' bala', mi herma, desaloja (¡wuh!)
# Aprende a surfear, por ahí viene la ola
# Yo vivo en <em>Hawái</em>, bajo el cristal, grito: "Aloha" (hello)
# Y</pre>
#    </div>
#    <div class="tdata-ext">
#     <div class="hidden-xs">
#     </div>
#     <div class="hidden-sm hidden-md hidden-lg">
#     </div>
#    </div>
#   </div>
#   <div class="row visible-xs">
#    <div class="adunit-middle adunit-middle-2col clearfix">
#     <div class="col-xs-12 col-sm-6 text-center">
#      <div id="div-gpt-ad-Lyrics_Mobile_LR_300x250_D">
#       <script>
#        doDisplay('div-gpt-ad-Lyrics_Mobile_LR_300x250_D');
#       </script>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="callout comments-area">
#    <div id="s4-comments">
#     <h4>
#      Discuss these
#      <a href="/lyrics/hawai%20maluma">
#       hawai maluma Lyrics
#      </a>
#      with the community:
#     </h4>
#     <div class="comment-form-container">
#      <form id="frm-comment">
#       <input id="commentId" name="comment_id" type="hidden">
#        <input id="cmtPart" name="cmt_part" type="hidden" value="1">
#         <input id="current-website" type="hidden" value="3">
#          <input id="current-entity" type="hidden" value="">
#           <input id="current-entityid" type="hidden" value="">
#            <input id="comments-limit" type="hidden" value="10">
#             <div class="form-group">
#              <h5 id="frm-comment-count">
#               0 Comments
#              </h5>
#              <div class="form-control" contenteditable="true" data-placeholder="Add a comment..." id="comment">
#              </div>
#              <div class="cmt-options">
#               <div class="cmt-tools">
#                <span class="cmt-tool rc5" data-action="picture" id="pic-toggle" title="Upload an image">
#                 <span class="glyphicon glyphicon-picture">
#                 </span>
#                </span>
#                <div class="hidden" id="picture-btns">
#                 <input accept="image/*" class="pic-upload hidden" type="file"/>
#                 <input id="pic-stream" name="picture" type="hidden"/>
#                 <input id="pic-type" name="picture_type" type="hidden"/>
#                 <img alt="" height="14" id="pic-preview" src="" title="Preview" width="14"/>
#                 <span class="pic-name hidden-xs" style="display:none;">
#                 </span>
#                 <button class="btn secondary xxsml pic-clear" id="pic-clear" style="display:none;" type="button">
#                  <i class="fas fa-trash-alt">
#                  </i>
#                 </button>
#                </div>
#                <span class="cmt-tool record-tool rc5 text-center" data-action="sound" id="start" title="Record a sound">
#                 <!-- <span class="glyphicon glyphicon-music"></span> -->
#                 <span class="ready">
#                  <i class="fas fa-microphone">
#                  </i>
#                 </span>
#                 <span class="recording equalizer hidden">
#                  <span class="bar bar-1">
#                  </span>
#                  <span class="bar bar-2">
#                  </span>
#                  <span class="bar bar-3">
#                  </span>
#                 </span>
#                </span>
#                <div class="record-tool hidden" id="record-btns">
#                 <button class="btn tertiary xxsml hidden" id="stop" title="Stop Recording" type="button">
#                  <i class="fas fa-stop">
#                  </i>
#                 </button>
#                 <button class="btn tertiary xxsml hidden" id="play" title="Play" type="button">
#                  <i class="fas fa-play">
#                  </i>
#                 </button>
#                 <audio hidden="" id="recorder" muted="">
#                 </audio>
#                 <audio hidden="" id="player">
#                 </audio>
#                 <small hidden="" id="play-time">
#                  0:00
#                 </small>
#                 <small hidden="" id="rec-time">
#                  0:00
#                 </small>
#                 <small>
#                  <button class="btn xxsml" hidden="" id="clear-audio" type="button">
#                   clear
#                  </button>
#                 </small>
#                 <input id="rec-stream" name="sound" type="hidden"/>
#                </div>
#               </div>
#               <div class="cmt-publish clearfix">
#                <div class="col-xs-10 no-padding">
#                 <div class="checkbox" id="notify-box">
#                  <label class="small">
#                   <input id="notify" type="checkbox"/>
#                   Notify me of new comments via email.
#                  </label>
#                 </div>
#                </div>
#                <div class="col-xs-2 no-padding text-right">
#                 <button aria-label="Publish" class="btn btn-submit primary btn-sm btn-3" data-target="#login-modal" data-uid="" id="submitButton" type="button">
#                  <span class="hidden-xs">
#                   Publish
#                  </span>
#                  <span class="visible-xs">
#                   <span class="glyphicon glyphicon-check">
#                   </span>
#                  </span>
#                 </button>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div id="comment-message">
#             </div>
#            </input>
#           </input>
#          </input>
#         </input>
#        </input>
#       </input>
#      </form>
#     </div>
#     <ul class="clearfix" id="comments-list">
#     </ul>
#    </div>
#    <!-- Modal -->
#    <div aria-hidden="true" aria-labelledby="cmt-report-label" class="modal fade" id="cmt-report-modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button class="close" data-dismiss="modal" type="button">
#         <span aria-hidden="true">
#          ×
#         </span>
#         <span class="sr-only">
#          Close
#         </span>
#        </button>
#        <h4 class="modal-title" id="cmt-report-label">
#         Report Comment
#        </h4>
#       </div>
#       <div class="modal-body">
#        <p>
#         We're doing our best to make sure our content is useful, accurate and safe.
#         <br/>
#         If by any chance you spot an inappropriate comment while navigating through our website please use this form to let us know, and we'll take care of it shortly.
#        </p>
#        <div class="form-group">
#         <textarea class="form-control" id="cmt-report-reason" placeholder="You may specify the reason for the report here..." rows="3"></textarea>
#        </div>
#        <input id="cmt-reported" type="hidden"/>
#       </div>
#       <div class="modal-footer">
#        <button class="btn" data-dismiss="modal" type="button">
#         Cancel
#        </button>
#        <button class="btn primary report-comment" type="button">
#         Report
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" aria-labelledby="cmt-attachment-label" class="modal fade" id="cmt-attachment-modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button class="close" data-dismiss="modal" type="button">
#         <span aria-hidden="true">
#          ×
#         </span>
#         <span class="sr-only">
#          Close
#         </span>
#        </button>
#        <h4 class="modal-title" id="cmt-attachment-label">
#         Attachment
#        </h4>
#       </div>
#       <div class="modal-body flex-align-center justify-center">
#        <img alt="" class="thumbnail" id="cmt-image"/>
#        <audio controls="" id="cmt-player">
#        </audio>
#       </div>
#       <div class="modal-footer">
#        <button class="btn tertiary" data-dismiss="modal" type="button">
#         Close
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#    <style>
#     #login-modal.modal #or{background-color:#fff}#login-modal.modal .sn-message{list-style:none;font-size:11px;text-align:center;padding:0;margin:20px 0 -20px}#login-modal.modal .ptext{font-size:12px}#login-modal.modal .waiting{opacity:0;font-size:5px;height:15px}#login-modal.modal ul.errors-list{margin:0 0 10px;padding:0;list-style:none;line-height:12px;font-size:12px}
#    </style>
#    <div aria-hidden="true" aria-labelledby="loginModal" class="modal fade" id="login-modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#         ×
#        </button>
#        <h4 class="modal-title" id="loginModal">
#         You need to be logged in to
#         <span class="modal-type">
#          favorite
#         </span>
#         .
#        </h4>
#       </div>
#       <div class="modal-body edit-content">
#        <div class="row social-signin">
#         <div class="col-xs-12 col-sm-6">
#          <div class="g-signin2" data-height="40" data-longtitle="true" data-onfailure="onFailure" data-onsuccess="onSuccess" data-scope="profile email" data-theme="dark" data-width="240">
#          </div>
#         </div>
#         <div class="col-xs-12 col-sm-6">
#          <div class="fb-login-button" data-auto-logout-link="false" data-max-rows="3" data-onlogin="checkLoginState();" data-scope="email" data-show-faces="false" data-size="large" data-use-continue-as="true" data-width="240px">
#          </div>
#         </div>
#        </div>
#        <ul class="sn-message">
#        </ul>
#        <div class="or-container">
#         <hr class="or-hr"/>
#         <div id="or">
#          or fill the form below
#         </div>
#        </div>
#        <div class="row">
#         <div class="col-sm-6 short_signin">
#          <h4>
#           Create a new account
#          </h4>
#          <div class="text-center waiting">
#           <i class="fas fa-spinner fa-spin fa-3x fa-fw">
#           </i>
#          </div>
#          <form id="modal-signup-frm" method="post">
#           <ul class="errors-list">
#           </ul>
#           <input id="frm-action" name="action" type="hidden" value="short_signin"/>
#           <input id="frm-source" name="source" type="hidden" value="0"/>
#           <input id="website" name="website" type="hidden" value="3"/>
#           <input id="fld-sra" name="sra" type="hidden" value="200.105.247.2"/>
#           <div class="bcols clearfix row">
#            <section class="col-xs-12">
#             <div class="col-left">
#              <p>
#               <label for="fld-rname">
#                Your name:
#                <span class="mandatory">
#                 *
#                 <span>
#                  Required
#                 </span>
#                </span>
#               </label>
#               <input class="fw" id="fld-rname" maxlength="100" name="rname" type="text" value=""/>
#              </p>
#             </div>
#            </section>
#            <section class="col-xs-12">
#             <div class="col-left">
#              <p>
#               <label for="fld-uemail">
#                Your email address:
#                <span class="mandatory">
#                 *
#                 <span>
#                  Required
#                 </span>
#                </span>
#               </label>
#               <input class="fw" id="fld-uemail" maxlength="100" name="uemail" type="text" value=""/>
#              </p>
#             </div>
#            </section>
#            <section class="col-xs-12">
#             <div class="col-left">
#              <p>
#               <label for="fld-uname">
#                Pick a user name:
#                <span class="mandatory">
#                 *
#                 <span>
#                  Required
#                 </span>
#                </span>
#               </label>
#               <input class="fw" id="fld-uname" maxlength="50" name="uname" type="text" value=""/>
#              </p>
#             </div>
#            </section>
#            <section class="col-xs-12">
#             <div class="col-left text-right">
#              <p>
#               <button class="btn primary" type="submit">
#                Join
#               </button>
#              </p>
#             </div>
#            </section>
#           </div>
#          </form>
#         </div>
#         <div class="col-sm-6 short_login">
#          <h4>
#           Log In
#          </h4>
#          <div class="text-center waiting">
#           <i class="fas fa-spinner fa-spin fa-3x fa-fw">
#           </i>
#          </div>
#          <form id="modal-login-frm" method="post">
#           <ul class="errors-list">
#           </ul>
#           <input id="frm-action-2" name="action" type="hidden" value="short_login"/>
#           <div class="scols clearfix">
#            <section>
#             <p>
#              <label for="fld-uname-2">
#               Username:
#               <span class="mandatory">
#                *
#                <span>
#                 Required
#                </span>
#               </span>
#              </label>
#              <input class="fw" id="fld-uname-2" maxlength="50" name="uname" type="text" value=""/>
#             </p>
#            </section>
#            <section>
#             <p>
#              <label for="fld-upass">
#               Password:
#               <span class="mandatory">
#                *
#                <span>
#                 Required
#                </span>
#               </span>
#              </label>
#              <input autocomplete="off" class="fw" id="fld-upass" maxlength="30" name="upass" type="password" value=""/>
#             </p>
#            </section>
#            <section>
#             <div class="inner-section text-right">
#              <p>
#               <button class="btn primary" type="submit">
#                Log In
#               </button>
#              </p>
#              <br/>
#              <p class="ptext">
#               Forgot your password?
#               <button class="btn secondary xxsml" onclick="location.href='https://www.lyrics.com/forgotpass.php';" type="button">
#                Retrieve it
#               </button>
#              </p>
#             </div>
#            </section>
#           </div>
#          </form>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="callout clearfix row">
#    <div>
#     <div class="callout-int">
#      <div class="row">
#       <div class="col-xs-12 col-sm-8">
#        <hgroup>
#         <h2>
#          We need you!
#         </h2>
#         <h3>
#          Help build the largest human-edited lyrics collection on the web!
#         </h3>
#        </hgroup>
#       </div>
#       <div class="col-xs-12 col-sm-4">
#        <div class="actions">
#         <button class="btn btn-2 primary lrg" onclick="location.href='https://www.lyrics.com/addlyric.php';" type="button">
#          Add Lyrics
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>

# %%
#obtiene los elementos del cuerpo letra del autor - canción y parte de la letra
job_elements = results.find_all("div", class_="sec-lyric clearfix")
print(job_elements)
# Out:
# [<div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5883205/Poeta+Alternativo/Mueve+tus+neuronas">Mueve tus neuronas</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Poeta-Alternativo/2137958449">Poeta Alternativo</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5883205/Poeta+Alternativo/Mueve+tus+neuronas';">Yo ofreciéndole hasta la luna
# Y quiere un caramelo de Ozuna
# Se siente en <em>Hawái</em> con <em>Maluma</em>
# Pero viven en mi colonia
# La bebida les endemonia
# Homenajean</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6190838/Danny+Romero/El+Otro">El Otro</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Danny-Romero/2024124">Danny Romero</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6190838/Danny+Romero/El+Otro';">Que ni <em>Maluma</em> por <em>Hawái</em>
#
# Emborracharnos con ganas
# En una calita escondía
# Hacerlo toda la noche
# Hasta que no podamos más
#
# Dime si la Luna te la</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5767654/Antonio+Delight/Desentendida">Desentendida</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Antonio-Delight/2137976548">Antonio Delight</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5767654/Antonio+Delight/Desentendida';">se esconde del puma
# Antes sacaba dieces, ahora diez se fuma
# Roba más suspiros que <em>Hawai</em> a <em>Maluma</em>
# Se excusa diciendo "no somos nada" si te engaña
# Pobre</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6232647/Pelouv/Entro+fresco+al+party+%28Radio+Edit%29">Entro fresco al party (Radio Edit)</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Pelouv/2137990826">Pelouv</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6232647/Pelouv/Entro+fresco+al+party+%28Radio+Edit%29';">tienes envidia pai. Muy lindo lo que en instagram posteas, <em>maluma</em> <em>Hawai</em>. Im nobody quiero una shorty que se quite el pantie quiero agraderme a mi. Hablar</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5531410/Camy+Gonzz%2C+Nico+R/Odisea">Odisea</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Camy-Gonzz%2C-Nico-R/2138208387">Camy Gonzz, Nico R</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5531410/Camy+Gonzz%2C+Nico+R/Odisea';">Déjame decirte nena, tu ausencia y la distancia
# Es lo que mi mente mas suena
# <em>Hawái</em> de vacaciones flow <em>Maluma</em>, ese es mi lema
# Bichota como Karol se te nota</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5293843/strak+baby/Esc%C3%A1pate+Conmigo+%28Kidd+Kream%29">Escápate Conmigo (Kidd Kream)</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/strak-baby/2137917359">strak baby</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5293843/strak+baby/Esc%C3%A1pate+Conmigo+%28Kidd+Kream%29';">fortuna
# Es mas caro que un viaje a la luna
# Baby como tu no hay otra, no existe ninguna
# Vacaciones en <em>Hawai</em> como lo dice <em>Maluma</em>
# Baby me tienes Hookeao' sin</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/2413107/Wuiinpic/En+TikTok">En TikTok</a></p>
# <p class="lyric-meta-artists"><a href="artist/Wuiinpic">Wuiinpic</a></p>
# <div class="album-thumb"><a aria-label="En TikTok by Wuiinpic" href="/album/"><img alt="" loading="lazy" src="..." title="En TikTok by Wuiinpic"/></a></div>
# <div class="clearfix"></div>
# <p class="lyric-meta-album"><a href="/album/"></a></p>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/2413107/Wuiinpic/En+TikTok';">TikTok TikTok TikTok
# que lo bailen que lo bailen
# TikTok TikTok TikTok  TikTok TikTok TikTok
# que lo bailen en TikTok
#
# Yo no soy <em>Maluma</em> dedicándote en <em>Hawái</em></pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/2384582/The+Weeknd/Haw%C3%A1i+%5BRemix%5D">Hawái [Remix]</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/The-Weeknd/2377309">The Weeknd</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/2384582/The+Weeknd/Haw%C3%A1i+%5BRemix%5D';">we'll share something that's real (oh yeah)
# I can tell that you're just tryna feel (oh no)
#
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6055786/Maluma/La+Botella">La Botella</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Maluma/2669415">Maluma</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6055786/Maluma/La+Botella';">Yeah-yeah-yeah
# <em>Maluma</em>, baby
# J Quiles
# Ay, Justin Quiles, mami
# For you my lova
# <em>Maluma</em>
#
# Me cansé, me cansé de buscar
# En otros beso' los labios</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6393896/Rodri+Roberts/La+Botella+%28Si+Estuviera+Ella%29">La Botella (Si Estuviera Ella)</a></p>
# <p class="lyric-meta-artists"><a href="artist/Rodri-Roberts">Rodri Roberts</a></p>
# <div class="album-thumb"><a aria-label="La Botella (Si Estuviera Ella) by Rodri Roberts" href="/album/"><img alt="" loading="lazy" src="..." title="La Botella (Si Estuviera Ella) by Rodri Roberts"/></a></div>
# <div class="clearfix"></div>
# <p class="lyric-meta-album"><a href="/album/"></a></p>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6393896/Rodri+Roberts/La+Botella+%28Si+Estuviera+Ella%29';">[Verso 2: <em>Maluma</em>]
# Ya he pasado por <em>Hawái</em> y Madrid (Yeah, yeah)
# Me he comido cuantos culo' por ahí
# Pero ninguna daría la vida por la mía
# Del modo que lo</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/1843281/Maluma/Haw%C3%A1i">Hawái</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Maluma/2669415">Maluma</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/1843281/Maluma/Haw%C3%A1i';">yo llegué primero
# Sé que te va ir bien pero no te quiere como yo te quiero
#
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones,</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6135931/DJ+Gustavo+Cabrera/Perreo+En+Hawai">Perreo En Hawai</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/DJ-Gustavo-Cabrera/2138335471">DJ Gustavo Cabrera</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6135931/DJ+Gustavo+Cabrera/Perreo+En+Hawai';">falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones
# Muy lindo en Instagram lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/2373405/MASSIVO/Haw%C3%A1i">Hawái</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/MASSIVO/2137864630">MASSIVO</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/2373405/MASSIVO/Haw%C3%A1i';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/3145286/Jhonny+Evidence/Hawai">Hawai</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Jhonny-Evidence/2137853027">Jhonny Evidence</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/3145286/Jhonny+Evidence/Hawai';">a ir bien, pero no te quiere como yo te quiero
#
# Puede que no te haga falta nada, aparentemente nada
# <em>Hawái</em> de vacaciones, mis felicitaciones
# Muy lindo en</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/6303861/Pablo+Mariano/Hawaii">Hawaii</a></p>
# <p class="lyric-meta-artists"><a href="artist/Pablo-Mariano">Pablo Mariano</a></p>
# <div class="album-thumb"><a aria-label="Hawaii by Pablo Mariano" href="/album/"><img alt="" loading="lazy" src="..." title="Hawaii by Pablo Mariano"/></a></div>
# <div class="clearfix"></div>
# <p class="lyric-meta-album"><a href="/album/"></a></p>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/6303861/Pablo+Mariano/Hawaii';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/3149480/Miky+Mendozza/Haw%C3%A1i">Hawái</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Miky-Mendozza/2137958309">Miky Mendozza</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/3149480/Miky+Mendozza/Haw%C3%A1i';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/7372960/Boricua+Boys/Haw%C3%A1i">Hawái</a></p>
# <p class="lyric-meta-artists"><a href="artist/Boricua-Boys">Boricua Boys</a></p>
# <div class="album-thumb"><a aria-label="Hawái by Boricua Boys" href="/album/"><img alt="" loading="lazy" src="..." title="Hawái by Boricua Boys"/></a></div>
# <div class="clearfix"></div>
# <p class="lyric-meta-album"><a href="/album/"></a></p>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/7372960/Boricua+Boys/Haw%C3%A1i';">primero
# Sé que te va ir bien pero no te quiere como yo te quiero
# Puede que no te haga falta na', aparentemente na'
# <em>Hawái</em> de vacaciones, mis felicitaciones</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5974729/Almighty/Me+Llueven+2">Me Llueven 2</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Almighty/3527">Almighty</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5974729/Almighty/Me+Llueven+2';">pa' que lo' recoja' (baby)
# No quiere' bala', mi herma, desaloja (¡wuh!)
# Aprende a surfear, por ahí viene la ola
# Yo vivo en <em>hawái</em>, bajo el cristal,</pre>
# </div>, <div class="sec-lyric clearfix">
# <div class="lyric-meta within-lyrics">
# <p class="lyric-meta-title"><a href="/lyric-lf/5974712/Almighty/Me+Llueven+%5BExtended%5D">Me Llueven [Extended]</a></p>
# <p class="lyric-meta-album-artist"><a href="artist/Almighty/3527">Almighty</a></p>
# <div class="clearfix"></div>
# </div>
# <pre class="lyric-body" onclick="location.href='https://www.lyrics.com/lyric-lf/5974712/Almighty/Me+Llueven+%5BExtended%5D';">(baby)
# No quiere' bala', mi herma, desaloja (¡wuh!)
# Aprende a surfear, por ahí viene la ola
# Yo vivo en <em>Hawái</em>, bajo el cristal, grito: "Aloha" (hello)
# Y</pre>
# </div>]

# %%
# obtiene elementos del autor, cancion y enlace donde está la letra de la canción
for job_element in job_elements:
    cancion = job_element.find("p", class_="lyric-meta-title")
    autor = job_element.find("p", class_="lyric-meta-album-artist")
    
    if autor == None:
        print ("no tiene autor")
    else:
        print("autor cancion: ", autor.text)

    print("titulo cancion: ", cancion.text)
    ref = job_element.find("pre", class_="lyric-body")
    print("url cancion: ", ref.attrs['onclick'])
    print('-----------------')
# Out:
# autor cancion:  Poeta Alternativo
# titulo cancion:  Mueve tus neuronas
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/5883205/Poeta+Alternativo/Mueve+tus+neuronas';
# -----------------
# autor cancion:  Danny Romero
# titulo cancion:  El Otro
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/6190838/Danny+Romero/El+Otro';
# -----------------
# autor cancion:  Antonio Delight
# titulo cancion:  Desentendida
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/5767654/Antonio+Delight/Desentendida';
# -----------------
# autor cancion:  Pelouv
# titulo cancion:  Entro fresco al party (Radio Edit)
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/6232647/Pelouv/Entro+fresco+al+party+%28Radio+Edit%29';
# -----------------
# autor cancion:  Camy Gonzz, Nico R
# titulo cancion:  Odisea
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/5531410/Camy+Gonzz%2C+Nico+R/Odisea';
# -----------------
# autor cancion:  strak baby
# titulo cancion:  Escápate Conmigo (Kidd Kream)
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/5293843/strak+baby/Esc%C3%A1pate+Conmigo+%28Kidd+Kream%29';
# -----------------
# no tiene autor
# titulo cancion:  En TikTok
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/2413107/Wuiinpic/En+TikTok';
# -----------------
# autor cancion:  The Weeknd
# titulo cancion:  Hawái [Remix]
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/2384582/The+Weeknd/Haw%C3%A1i+%5BRemix%5D';
# -----------------
# autor cancion:  Maluma
# titulo cancion:  La Botella
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/6055786/Maluma/La+Botella';
# -----------------
# no tiene autor
# titulo cancion:  La Botella (Si Estuviera Ella)
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/6393896/Rodri+Roberts/La+Botella+%28Si+Estuviera+Ella%29';
# -----------------
# autor cancion:  Maluma
# titulo cancion:  Hawái
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/1843281/Maluma/Haw%C3%A1i';
# -----------------
# autor cancion:  DJ Gustavo Cabrera
# titulo cancion:  Perreo En Hawai
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/6135931/DJ+Gustavo+Cabrera/Perreo+En+Hawai';
# -----------------
# autor cancion:  MASSIVO
# titulo cancion:  Hawái
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/2373405/MASSIVO/Haw%C3%A1i';
# -----------------
# autor cancion:  Jhonny Evidence
# titulo cancion:  Hawai
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/3145286/Jhonny+Evidence/Hawai';
# -----------------
# no tiene autor
# titulo cancion:  Hawaii
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/6303861/Pablo+Mariano/Hawaii';
# -----------------
# autor cancion:  Miky Mendozza
# titulo cancion:  Hawái
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/3149480/Miky+Mendozza/Haw%C3%A1i';
# -----------------
# no tiene autor
# titulo cancion:  Hawái
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/7372960/Boricua+Boys/Haw%C3%A1i';
# -----------------
# autor cancion:  Almighty
# titulo cancion:  Me Llueven 2
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/5974729/Almighty/Me+Llueven+2';
# -----------------
# autor cancion:  Almighty
# titulo cancion:  Me Llueven [Extended]
# url cancion:  location.href='https://www.lyrics.com/lyric-lf/5974712/Almighty/Me+Llueven+%5BExtended%5D';
# -----------------

# %%
'''
Crear método: Validar autor, canción y retornar el enlace o url de la canción
'''
url_letra_cancion = "https://www.lyrics.com/lyric-lf/1843281/Maluma/Haw%C3%A1i"

# %%
# obtiene contenido de la página web de la letra de la canción
page_letra_cancion = requests.get(url_letra_cancion)
soup_letra_cancion = BeautifulSoup(page_letra_cancion.content, "html.parser")
print(soup_letra_cancion)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Maluma - Hawái Lyrics | Lyrics.com</title>
# <meta content="Hawái Lyrics by Maluma from the custom_album_6029074 album - including song video, artist biography, translations and more: Deja de mentirte (ah)
# La foto que subiste con él diciendo que era tu cielo
# Bebé, yo te conozco tan bien, sé que fue pa'…" name="description"/>
# <meta content="Hawái lyrics, lyrics for Hawái, Hawái song, Hawái words, lyrics from custom_album_6029074" name="keywords"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="#830C66" name="theme-color">
# <base href="https://www.lyrics.com/"/>
# <script>
# s4Prefix = 'https://static.stands4.com';
# version = '1.4.5';
# </script>
# <link as="style" href="https://static.stands4.com/app_common/css/bootstrap-3.4.1.min.css" rel="preload"/>
# <link href="https://static.stands4.com/app_common/css/bootstrap-3.4.1.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect">
# <link as="style" href="//fonts.googleapis.com/css2?family=Yanone+Kaffeesatz:wght@400;700&amp;family=Oxygen:wght@400;700&amp;family=Droid+Serif:ital,wght@0,400;0,700;1,400;1,700&amp;family=Droid+Sans+Mono&amp;family=Alegreya+Sans:wght@800&amp;family=Original+Surfer&amp;display=swap" rel="preload">
# <link href="//fonts.googleapis.com/css2?family=Yanone+Kaffeesatz:wght@400;700&amp;family=Oxygen:wght@400;700&amp;family=Droid+Serif:ital,wght@0,400;0,700;1,400;1,700&amp;family=Droid+Sans+Mono&amp;family=Alegreya+Sans:wght@800&amp;family=Original+Surfer&amp;display=swap" media="print" onload="this.media='all'" rel="stylesheet"/>
# <noscript><link href="//fonts.googleapis.com/css2?family=Yanone+Kaffeesatz:wght@400;700&amp;family=Oxygen:wght@400;700&amp;family=Droid+Serif:ital,wght@0,400;0,700;1,400;1,700&amp;family=Droid+Sans+Mono&amp;family=Alegreya+Sans:wght@800&amp;family=Original+Surfer&amp;display=swap" rel="stylesheet"/></noscript>
# <link href="https://static.stands4.com/app_common/css/lyrc.css?v=1.8.80" rel="stylesheet"/>
# <link href="https://static.stands4.com/app_common/img/favicon_lyrc.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://static.stands4.com/app_common/img/favicon_lyrc.ico" rel="icon" type="image/x-icon"/>
# <link href="https://static.stands4.com/app_lyrics/open-search.xml" rel="search" title="Lyrics.com" type="application/opensearchdescription+xml"/>
# <!-- DFP head code - START -->
# <script>
#     var adsStart = (new Date()).getTime();
#     function detectWidth() {
#         return window.screen.width || window.innerWidth || window.document.documentElement.clientWidth || Math.min(window.innerWidth, window.document.documentElement.clientWidth) || window.innerWidth || window.document.documentElement.clientWidth || window.document.getElementsByTagName('body')[0].clientWidth;
#     }
#
#     function doDisplay(code){
#         for (var i = adUnits.length - 1; i >= 0; i--) {
#             if(adUnits[i].code == code){
#                 googletag.cmd.push(function() { googletag.display(code); });
#                 return true;
#             }
#         }
#         return false;
#     }
#
#     var TIMEOUT = 1000;
#     var EXCHANGE_RATE = 3.45;
#     var screenSizeMobile = 768;
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     var pbjs = pbjs || {};
#     pbjs.que = pbjs.que || [];
#     var adUnits = adUnits || [];
#
#     function initAdServer() {
#         if (pbjs.initAdserverSet) return;
#         (function() {
#             var gads = document.createElement('script');
#             gads.async = true;
#             gads.type = 'text/javascript';
#             gads.src = 'https://securepubads.g.doubleclick.net/tag/js/gpt.js';
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(gads, node);
#         })();
#         pbjs.initAdserverSet = true;
#     };
#     pbjs.timeout = setTimeout(initAdServer, TIMEOUT);
#     pbjs.timeStart = adsStart;
#
#     var dfpNetwork = '52304935';
#
#     // SizeMapping
#     var isDesk = detectWidth() >= screenSizeMobile;
#     var mapSizeMRU = [[300, 250], [300, 600]];
#     if(!isDesk) mapSizeMRU = [[300, 250]];
#
#     // START: Defining Adunits
#     if(isDesk){
#         /* Desktop Adunits */
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_IA_300x250_A",
#                 size: [[300, 250],[1,1]],
#                 code: 'div-gpt-ad-Lyrics_IA_300x250_A',
#                 assignToVariableName: false // false if not in use
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_IA_300x250_B",
#                 size: [[300, 250]],
#                 code: 'div-gpt-ad-Lyrics_IA_300x250_B',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_LR_300x250_A",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_LR_300x250_A',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_LR_300x250_B",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_LR_300x250_B',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_LR_300x250_C",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_LR_300x250_C',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_LR_300x250_D",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_LR_300x250_D',
#                 assignToVariableName: false
#              });
#     } else {
#         /* Mobile Adunits */
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_IA_300x250_A",
#                 size: [300, 250],
#                 code: 'div-gpt-ad-Lyrics_Mobile_IA_300x250_A',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_IA_300x250_B",
#                 size: [[300, 250]],
#                 code: 'div-gpt-ad-Lyrics_Mobile_IA_300x250_B',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_LR_300x250_A",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_Mobile_LR_300x250_A',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_LR_300x250_B",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_Mobile_LR_300x250_B',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_LR_300x250_C",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_Mobile_LR_300x250_C',
#                 assignToVariableName: false
#              });
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: "Lyrics_Mobile_LR_300x250_D",
#                 size: mapSizeMRU,
#                 code: 'div-gpt-ad-Lyrics_Mobile_LR_300x250_D',
#                 assignToVariableName: false
#              });
#     }
#     /* All devices*/
#     adUnits.push({
#             network: dfpNetwork,
#             adunit: "Lyrics_LR_125x125",
#             size: [[125, 125]],
#             code: 'div-gpt-ad-Lyrics_LR_125x125',
#             assignToVariableName: false
#          });
#
#     // END: Defining Adunits
#
#     googletag.cmd.push(function() {
#       if(adUnits){
#         var dfpSlots = [];
#         for (var i = 0, len = adUnits.length; i < len; i++) {
#           dfpSlots[i] = googletag.defineSlot('/'+adUnits[i].network+'/'+adUnits[i].adunit, adUnits[i].size, adUnits[i].code).addService(googletag.pubads());
#           if(adUnits[i].assignToVariableName && (adUnits[i].assignToVariableName !== null)) window[adUnits[i].assignToVariableName] = dfpSlots[i];
#         }
#       }
#     });
#     googletag.cmd.push(function() {
#         // Header Bidding Targeting
#         pbjs.que.push(function() {pbjs.setTargetingForGPTAsync();});
#
#         // Set targeting
#         googletag.pubads().setTargeting("device", !isDesk ? "mobile" : "desktop");
#
#         // Init DFP
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().collapseEmptyDivs();
#         googletag.enableServices();
#     });
# </script>
# <script async="" src="https://static.stands4.com/app_common/js/prebid.js" type="text/javascript"></script>
# <!-- DFP head code - END --><meta content="118234861672613" property="fb:app_id">
# <meta content="567628204450-49mrbnlqde6k322k6j1nmpstf86djv24.apps.googleusercontent.com" name="google-signin-client_id"/>
# </meta></link></link></meta></head>
# <body data-atp="ra-4f75bf3d5305fac2" data-fb="118234861672613" id="s4-page-lyric">
# <div id="page-container">
# <header id="header">
# <div class="clearfix" id="header-int">
# <div id="user-hist"><a href="/search-history" title="History"><i class="fas fa-history"></i></a></div>
# <div id="user-login">
# <a href="login.php">Login</a> <i aria-hidden="true" class="fas fa-sign-in-alt"></i>
# </div>
# <div id="network-header"><span id="network-header-trigger">The <span class="hidden-xs">STANDS4 </span>Network<span class="arw">☰</span></span>
# <ul id="network-header-links" style="display:none;">
# <li class="nw-abbreviations"><a href="https://www.abbreviations.com/">ABBREVIATIONS</a></li>
# <li class="nw-anagrams"><a href="https://www.anagrams.net/">ANAGRAMS</a></li>
# <li class="nw-biographies"><a href="https://www.biographies.net/">BIOGRAPHIES</a></li>
# <li class="nw-calculator"><a href="https://www.calculators.net/">CALCULATORS</a></li>
# <li class="nw-convert"><a href="https://www.convert.net/">CONVERSIONS</a></li>
# <li class="nw-definitions"><a href="https://www.definitions.net/">DEFINITIONS</a></li>
# <li class="nw-grammar"><a href="https://www.grammar.com/">GRAMMAR</a></li>
# <li class="nw-literature"><a href="https://www.literature.com/">LITERATURE</a></li>
# <li class="nw-lyrics"><a href="https://www.lyrics.com/">LYRICS</a></li>
# <li class="nw-phrases"><a href="https://www.phrases.com/">PHRASES</a></li>
# <li class="nw-poetry"><a href="https://www.poetry.com/">POETRY</a></li>
# <li class="nw-quotes"><a href="https://www.quotes.net/">QUOTES</a></li>
# <li class="nw-references"><a href="https://www.references.net/">REFERENCES</a></li>
# <li class="nw-rhymes"><a href="https://www.rhymes.com/">RHYMES</a></li>
# <li class="nw-scripts"><a href="https://www.scripts.com/">SCRIPTS</a></li>
# <li class="nw-symbols"><a href="https://www.symbols.com/">SYMBOLS</a></li>
# <li class="nw-synonyms"><a href="https://www.synonyms.com/">SYNONYMS</a></li>
# <li class="nw-uszip"><a href="https://www.uszip.com/">USZIP</a></li>
# </ul>
# </div> </div>
# </header><div class="container" id="main" role="main"><div class="content-top" id="content-top">
# <div class="view-search view-desktop hidden-xs">
# <form action="subserp.php" id="search-frm" method="get">
# <input name="genre" type="hidden" value=""/>
# <input name="style" type="hidden" value=""/>
# <input name="year" type="hidden" value=""/>
# <input name="dec" type="hidden" value=""/>
# <div class="page-top-search rc5">
# <div class="page-word-search">
# <input autocomplete="off" class="page-word-search-query rc5" id="search" name="st" placeholder="Search for lyrics or artists..." type="text" value=""/>
# <div class="page-word-search-icon"><i aria-hidden="true" class="fas fa-search"></i></div>
# <button class="btn primary" id="page-word-search-button" type="submit">Search</button>
# </div>
# <div class="page-word-search-ops">
# <div><input checked="checked" class="custom-rb" id="page-word-search-op1" name="qtype" type="radio" value="1"/><label for="page-word-search-op1"><span>In Lyrics</span></label></div>
# <div><input class="custom-rb" id="page-word-search-op2" name="qtype" type="radio" value="2"/><label for="page-word-search-op2"><span>By Artist</span></label></div>
# <div><input class="custom-rb" id="page-word-search-op3" name="qtype" type="radio" value="3"/><label for="page-word-search-op3"><span>By Album</span></label></div>
# </div>
# </div>
# <div class="page-letter-search rc5"><a href="/artists/0">#</a><a href="/artists/A">A</a><a href="/artists/B">B</a><a href="/artists/C">C</a><a href="/artists/D">D</a><a href="/artists/E">E</a><a href="/artists/F">F</a><a href="/artists/G">G</a><a href="/artists/H">H</a><a href="/artists/I">I</a><a href="/artists/J">J</a><a href="/artists/K">K</a><a href="/artists/L">L</a><a href="/artists/M">M</a><a href="/artists/N">N</a><a href="/artists/O">O</a><a href="/artists/P">P</a><a href="/artists/Q">Q</a><a href="/artists/R">R</a><a href="/artists/S">S</a><a href="/artists/T">T</a><a href="/artists/U">U</a><a href="/artists/V">V</a><a href="/artists/W">W</a><a href="/artists/X">X</a><a href="/artists/Y">Y</a><a href="/artists/Z">Z</a><span class="vbar"> </span><a class="z" href="/justadded">NEW</a><a aria-label="Random Lyrics" class="z" href="random.php"><i aria-hidden="true" class="fas fa-random"></i></a></div>
# </form> <div class="page-top-logo" onclick="location.href='https://www.lyrics.com/';"><img alt="Lyrics.com" src="https://static.stands4.com/app_common/img/top_logo_lyr.png" title="Lyrics.com"/></div>
# </div>
# <div class="view-search view-mobile visible-xs">
# <form action="subserp.php" id="search-frm-mob" method="get">
# <input name="genre" type="hidden" value=""/>
# <input name="style" type="hidden" value=""/>
# <input name="year" type="hidden" value=""/>
# <input name="dec" type="hidden" value=""/>
# <div class="page-top-search">
# <div class="page-word-search" style="width: calc(100% - 110px);">
# <div class="input-group">
# <input autocomplete="off" class="page-word-search-query form-control rc5" id="search-mob" name="st" placeholder="Search for lyrics..." type="text" value=""/>
# <span class="input-group-btn"><button aria-label="Search for lyrics or artists" class="btn primary" id="page-word-search-button-mob" type="submit"><i aria-hidden="true" class="fas fa-search"></i></button></span>
# </div>
# </div>
# <div class="page-word-search-ops">
# <div><input checked="checked" class="custom-rb" id="page-word-search-m-op1" name="qtype" type="radio" value="1"/><label for="page-word-search-m-op1"><span>In Lyrics</span></label></div>
# <div><input class="custom-rb" id="page-word-search-m-op2" name="qtype" type="radio" value="2"/><label for="page-word-search-m-op2"><span>By Artist</span></label></div>
# <div><input class="custom-rb" id="page-word-search-m-op3" name="qtype" type="radio" value="3"/><label for="page-word-search-m-op3"><span>by Album</span></label></div>
# </div>
# </div>
# <div class="page-letter-search"></div>
# </form> <div class="page-top-logo" onclick="location.href='https://www.lyrics.com/';"><img alt="Lyrics.com" src="https://static.stands4.com/app_common/img/top_logo_lyr.png" title="Lyrics.com"/></div>
# </div>
# </div>
# <div class="row">
# <div class="col-sm-8 col-sm-push-4" id="content-main">
# <div id="content-body">
# <div class="clearfix">
# <div class="lyric clearfix">
# <div class="head-btns">
# <p class="print-style-icon">
# <span class="rc3 s fsize" title="Change text size"><span class="glyphicon glyphicon-text-size"></span></span>
# 							<a class="rc3 s" href="email.php?id=37493623&amp;type=lyric" target="_blank" title="click to email Hawái to a friend"><i class="fas fa-paper-plane"></i></a>
# 							<a class="rc3 s" href="print.php?id=37493623" target="_blank" title="click to send Hawái to your printer"><span class="glyphicon glyphicon-print"></span></a>
# 							<a class="add-to-list s rc3" href="/lyrics-pdf/37493623" title="click to down the Hawái lyrics as PDF"><i class="far fa-file-pdf"></i> PDF</a>
# 							<a class="rc3 s" href="sheetmusic.php?id=37493623" title="click for Hawái sheet music"><span class="glyphicon glyphicon-music" style="margin-left: -1px;"></span></a>
# 							<a class="rc3 s" href="/song-parody-maker/37493623" title="click to create a parody of this song"><b><i class="far fa-smile"></i></b></a>
# 							<a class="rc3 s" href="playlist.php?add=37493623&amp;sub=0" title="click to add Hawái to your playlist"><span class="glyphicon glyphicon-list"></span><span class="hidden-xs"> Playlist</span></a>
# 							<span class="audio tts-icon rc3 s" data-code="en-US" data-lang="Google US English" title="Hear this lyrics"><i aria-hidden="true" class="fas fa-volume-up"></i></span>
# 													</p>
# </div>
# <hgroup dir="ltr">
# <h1 class="lyric-title" id="lyric-title-text">Hawái</h1>
# <div class="mstore">
# <a href="https://music.apple.com/us/search?term=Haw%C3%A1i+by+Maluma" target="_blank" title="Listen to this song on Apple Music">
# <span class="shop"><i aria-hidden="true" class="fab fa-apple"></i></span>
# </a>
# <a class="store-amz" href="https://www.amazon.com/gp/search?index=digital-music&amp;keywords=Haw%C3%A1i+by+Maluma&amp;tag=stands4com-20" target="_blank" title="Listen to this song on Amazon">
# <span class="shop"><i aria-hidden="true" class="fab fa-amazon"></i></span>
# </a>
# <a href="https://www.amazon.com/gp/search?index=digital-music&amp;keywords=Haw%C3%A1i+by+Maluma&amp;tag=stands4com-20" target="_blank" title="Listen to this song on Amazon"><small>Listen online</small></a>
# </div>
# <h3 class="lyric-artist"><a href="artist/Maluma/2669415">Maluma</a></h3>
# </hgroup>
# <div class="lyric-infobox clearfix">
# <div class="artist-thumb" data-artist="Maluma" data-img="1" id="featured-artist-avatar">
# <a href="artist/Maluma/2669415" title="Maluma">
# <img alt="" height="125" loading="lazy" src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Maluma_-_Espaço_das_Américas_(37591053894).jpg/244px-Maluma_-_Espaço_das_Américas_(37591053894).jpg" style="margin-left:0;" title="Maluma" width="120"/>
# </a>
# <div class="wiki-credit"><span class="wiki-name hidden">Maluma</span><span data-type="2">Maluma <i class="fa-info-circle fas"></i></span></div> </div>
# <div class="artist-meta">
# <div class="flr"><p class="favorite-style-select" data-key="2669415" data-page="lyric">
# <button class="btn s" data-aid="2669415" data-sub="0" data-target="#login-modal" data-uid="" data-votes="2" id="artist-rate-btn" title="click to add your vote"><i aria-hidden="true" class="fas fa-star"></i> <span>FAVORITE</span></button>
# <span id="author-rate-votes" onclick="location.href='https://www.lyrics.com/artist-fans/2669415';">(2 fans)</span>
# </p></div>
# <h4><a href="artist/Maluma/2669415">Maluma</a></h4>
# <p class="bio">Juan Luis Londoño Arias (born 28 January 1994), known professionally as Maluma, is a Colombian singer, songwriter, and actor signed to Sony Music Colombia, Sony Latin and Fox Music. Born and raised in Medellín, he developed an interest in music at a young age, and began recording songs at age 16. He released his debut album, Magia, a year later in 2012. However, his breakthrough album was 2015's Pretty Boy, Dirty Boy, which led to successful collaborations with artists Thalía, Shakira and Ricky Martin. He released F.A.M.E. in 2018, to further commercial success. He followed it up with 11:11, released the next year. <a href="artist/Maluma/2669415">more »</a></p>
# </div>
# <br/>
# <div class="lyric-details">
# <input data-id="37493623" data-type="lyric" id="lyric-data" type="hidden"/>
# <dl>
# <dt><i aria-hidden="true" class="far fa-clock" title="Duration"></i></dt>
# <dd class="dd-margin">3:20</dd>
# <dt><i aria-hidden="true" class="far fa-eye"></i></dt>
# <dd class="c-views">74 <span class="hidden-xs">Views</span></dd>
# </dl>
# </div>
# </div>
# <div class="row">
# <div class="adunit-middle adunit-middle-2col clearfix">
# <div class="col-xs-12 col-sm-12"><div id="div-gpt-ad-Lyrics_IA_300x250_A">
# <script>
# doDisplay('div-gpt-ad-Lyrics_IA_300x250_A');
# </script>
# </div>
# <div id="div-gpt-ad-Lyrics_Mobile_IA_300x250_A">
# <script>
# doDisplay('div-gpt-ad-Lyrics_Mobile_IA_300x250_A');
# </script>
# </div></div>
# </div>
# </div>
# <script>
# /* Lyrics.net - TFP - Above */
# (function() {
#                 var opts = {
# 		                		artist: "",
# 		                        song: "",
#                                 adunit_id: 39384263,
#                                 div_id: "cf_async_" + Math.floor((Math.random() * 999999999))
#                 };
#                 document.write('<div id="'+opts.div_id+'"></div>');var c=function(){cf.showAsyncAd(opts)};if(window.cf)c();else{cf_async=!0;var r=document.createElement("script"),s=document.getElementsByTagName("script")[0];r.async=!0;r.src="https://srv.clickfuse.com/showads/showad.js";r.readyState?r.onreadystatechange=function(){if("loaded"==r.readyState||"complete"==r.readyState)r.onreadystatechange=null,c()}:r.onload=c;s.parentNode.insertBefore(r,s)};
# })();
# </script> <h3 class="lyric-artist text-center">
# <span style="font-weight: 700; font-size: 15px;">
# <a href="https://www.30daysinger.com/a/8328/LfArfDh6?utm_campaign=lyrics_top_link&amp;title=4" rel="nofollow" target="_blank"><i aria-hidden="true" class="fas fa-check" style="color: #666;"></i> Struggling with Hawái? Become a better singer <u>in 30 days</u> with these videos!</a>
# </span>
# </h3>
# <pre class="lyric-body" data-lang="en" dir="ltr" id="lyric-body-text">Deja de <a href="https://www.definitions.net/definition/mentirte" style="color:#222;">mentirte</a> (ah)
# La foto que <a href="https://www.definitions.net/definition/subiste" style="color:#222;">subiste</a> con él <a href="https://www.definitions.net/definition/diciendo" style="color:#222;">diciendo</a> que era tu cielo
# Bebé, yo te <a href="https://www.definitions.net/definition/conozco" style="color:#222;">conozco</a> tan bien, sé que fue pa' <a href="https://www.definitions.net/definition/darme" style="color:#222;">darme</a> celos
# No te diré quién, pero <a href="https://www.definitions.net/definition/llorando" style="color:#222;">llorando</a> por mí te vieron
# Por mí te vieron
#
# Déjame decirte
# Se ve que él te <a href="https://www.definitions.net/definition/trata" style="color:#222;">trata</a> bien, que es todo un caballero
# Pero eso no cambiará que yo llegué primero
# Sé que te va ir bien pero no te <a href="https://www.definitions.net/definition/quiere" style="color:#222;">quiere</a> como yo te quiero
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea como te va de bien, pero te <a href="https://www.definitions.net/definition/haces" style="color:#222;">haces</a> mal
# Porque el amor no se <a href="https://www.definitions.net/definition/compra" style="color:#222;">compra</a> na'
#
# Miéntele a <a href="https://www.definitions.net/definition/todos" style="color:#222;">todos</a> tus seguidore'
# Dile que los tiempo' de <a href="https://www.definitions.net/definition/ahora" style="color:#222;">ahora</a> son mejore'
# No creo que <a href="https://www.definitions.net/definition/cuando" style="color:#222;">cuando</a> te <a href="https://www.definitions.net/definition/llame" style="color:#222;">llame</a> me ignores
# Si después de mí ya no habrán más amores
#
# Tú y yo fuimo' uno
# Lo hacíamo' en ayuna' <a href="https://www.definitions.net/definition/antes" style="color:#222;">antes</a> del desayuno
# Fumábamo' la <a href="https://www.definitions.net/definition/hookah" style="color:#222;">hookah</a> y te <a href="https://www.definitions.net/definition/pasaba" style="color:#222;">pasaba</a> el humo
# Y <a href="https://www.definitions.net/definition/ahora" style="color:#222;">ahora</a> en esta <a href="https://www.definitions.net/definition/guerra" style="color:#222;">guerra</a> no gana ninguno
#
# Si me preguntas, <a href="https://www.definitions.net/definition/nadie" style="color:#222;">nadie</a> tiene culpa
# A vece' los <a href="https://www.definitions.net/definition/problemas" style="color:#222;">problemas</a> a uno se le juntan
# Déjame hablar, porfa, no me interrumpas
# Si te hice algo malo, <a href="https://www.definitions.net/definition/entonces" style="color:#222;">entonces</a> discúlpame
# La <a href="https://www.definitions.net/definition/gente" style="color:#222;">gente</a> te lo va a creer, actúas bien ese papel
# Baby, pero no eres <a href="https://www.definitions.net/definition/feliz" style="color:#222;">feliz</a> con él
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea como te va de bien, pero te <a href="https://www.definitions.net/definition/haces" style="color:#222;">haces</a> mal
# Porque el amor no se <a href="https://www.definitions.net/definition/compra" style="color:#222;">compra</a> na'
#
# (Deja de mentirte
# La foto que <a href="https://www.definitions.net/definition/subiste" style="color:#222;">subiste</a> con él <a href="https://www.definitions.net/definition/diciendo" style="color:#222;">diciendo</a> que era tu cielo)
# Mamacita
# (Bebé, yo te <a href="https://www.definitions.net/definition/conozco" style="color:#222;">conozco</a> tan bien, sé que fue pa' <a href="https://www.definitions.net/definition/darme" style="color:#222;">darme</a> celos)
#
# Maluma, baby
# (No te diré quién, pero <a href="https://www.definitions.net/definition/llorando" style="color:#222;">llorando</a> por mí te vieron)
# Jaja
# (Por mí te vieron)
# Papi Juancho</pre>
# <h3 class="lyric-artist text-center">
# <span style="font-weight: 700; font-size: 15px;">
# <a href="https://www.30daysinger.com/a/8328/LfArfDh6?utm_campaign=lyrics_bottom_link&amp;title=3" rel="nofollow" target="_blank"><i aria-hidden="true" class="fas fa-check" style="color: #666;"></i> The easy, fast &amp; fun way to learn how to sing: 30DaySinger.com</a>
# </span>
# </h3> <script>
# /* Lyrics.net - TFP - Below */
# (function() {
#                 var opts = {
#                                 artist: "",
#                                 song: "Hawái",
#                                 adunit_id: 39384264,
#                                 div_id: "cf_async_" + Math.floor((Math.random() * 999999999))
#                 };
#                 document.write('<div id="'+opts.div_id+'"></div>');var c=function(){cf.showAsyncAd(opts)};if(window.cf)c();else{cf_async=!0;var r=document.createElement("script"),s=document.getElementsByTagName("script")[0];r.async=!0;r.src="https://srv.clickfuse.com/showads/showad.js";r.readyState?r.onreadystatechange=function(){if("loaded"==r.readyState||"complete"==r.readyState)r.onreadystatechange=null,c()}:r.onload=c;s.parentNode.insertBefore(r,s)};
# })();
# </script>
# <div class="lyric-credits clearfix">
# <div class="head-btns">
# <p class="print-style-icon">
# <a class="rc3 s" href="sheetmusic.php?id=37493623" target="_blank" title="click for Hawái sheet music"><span class="glyphicon glyphicon-music" style="margin-left: -1px;"></span> Sheet Music</a>
# 								<a class="rc3 s" href="email.php?id=37493623&amp;type=lyric" target="_blank" title="click to email Hawái to a friend"><i class="fas fa-paper-plane"></i></a>
# 								<a class="rc3 s" href="print.php?id=37493623" target="_blank" title="click to send Hawái to your printer"><span class="glyphicon glyphicon-print"></span></a>
# 								<a class="add-to-list s rc3" href="/lyrics-pdf/37493623" title="click to down the Hawái lyrics as PDF"><i class="far fa-file-pdf"></i> PDF</a>
# 								<a class="rc3 s" href="/song-parody-maker/37493623" title="click to create a parody of this song"><b><i class="far fa-smile"></i></b></a>
# 								<a class="rc3 s" href="playlist.php?add=37493623&amp;sub=0" title="click to add Hawái to your playlist"><span class="glyphicon glyphicon-list"></span><span class="hidden-xs"> Playlist</span></a>
# 							</p>
# </div>
# <p>Written by: Andres Uribe Marin, Bryan Snaider Lezcano Chaverra, Edgar Barrera, Johan Espinosa, Juan Camilo Vargas Vasquez, Juan Luis Londono Arias, Kevin Mauricio Jimenez Londono, Kevyn Mauricio Cruz Moreno, Rene Cano, Stiven Rojas</p>
# <p>Lyrics © DistroKid, Universal Music Publishing Group, Sony/ATV Music Publishing LLC, Warner Chappell Music, Inc.</p>
# <p>Lyrics Licensed &amp; Provided by <a href="http://www.lyricfind.com" rel="nofollow">LyricFind</a></p>
# </div>
# </div>
# <div class="row visible-xs">
# <div class="adunit-middle adunit-middle-2col clearfix">
# <div class="col-xs-12 col-sm-6 text-center"><div id="div-gpt-ad-Lyrics_Mobile_LR_300x250_D">
# <script>
# doDisplay('div-gpt-ad-Lyrics_Mobile_LR_300x250_D');
# </script>
# </div></div>
# </div>
# </div>
# <div class="callout comments-area">
# <div id="s4-comments">
# <h4>Discuss the <a href="/lyric-lf/1843281/Maluma/Haw%C3%A1i">Hawái Lyrics</a> with the community:</h4>
# <div class="comment-form-container">
# <form id="frm-comment">
# <input id="commentId" name="comment_id" type="hidden">
# <input id="cmtPart" name="cmt_part" type="hidden" value="1">
# <input id="current-website" type="hidden" value="3">
# <input id="current-entity" type="hidden" value="lyrics">
# <input id="current-entityid" type="hidden" value="37493623">
# <input id="comments-limit" type="hidden" value="10">
# <div class="form-group">
# <h5 id="frm-comment-count">0 Comments</h5>
# <div class="form-control" contenteditable="true" data-placeholder="Add a comment..." id="comment"></div>
# <div class="cmt-options">
# <div class="cmt-tools">
# <span class="cmt-tool rc5" data-action="picture" id="pic-toggle" title="Upload an image"><span class="glyphicon glyphicon-picture"></span></span>
# <div class="hidden" id="picture-btns">
# <input accept="image/*" class="pic-upload hidden" type="file"/>
# <input id="pic-stream" name="picture" type="hidden"/>
# <input id="pic-type" name="picture_type" type="hidden"/>
# <img alt="" height="14" id="pic-preview" src="" title="Preview" width="14"/>
# <span class="pic-name hidden-xs" style="display:none;"></span>
# <button class="btn secondary xxsml pic-clear" id="pic-clear" style="display:none;" type="button"><i class="fas fa-trash-alt"></i></button>
# </div>
# <span class="cmt-tool record-tool rc5 text-center" data-action="sound" id="start" title="Record a sound">
# <!-- <span class="glyphicon glyphicon-music"></span> -->
# <span class="ready"><i class="fas fa-microphone"></i></span>
# <span class="recording equalizer hidden"><span class="bar bar-1"></span><span class="bar bar-2"></span><span class="bar bar-3"></span></span>
# </span>
# <div class="record-tool hidden" id="record-btns">
# <button class="btn tertiary xxsml hidden" id="stop" title="Stop Recording" type="button"><i class="fas fa-stop"></i></button>
# <button class="btn tertiary xxsml hidden" id="play" title="Play" type="button"><i class="fas fa-play"></i></button>
# <audio hidden="" id="recorder" muted=""></audio>
# <audio hidden="" id="player"></audio>
# <small hidden="" id="play-time">0:00</small>
# <small hidden="" id="rec-time">0:00</small>
# <small> <button class="btn xxsml" hidden="" id="clear-audio" type="button">clear</button></small>
# <input id="rec-stream" name="sound" type="hidden"/>
# </div>
# </div>
# <div class="cmt-publish clearfix">
# <div class="col-xs-10 no-padding">
# <div class="checkbox" id="notify-box">
# <label class="small"><input id="notify" type="checkbox"/> Notify me of new comments via email.</label>
# </div>
# </div>
# <div class="col-xs-2 no-padding text-right">
# <button aria-label="Publish" class="btn btn-submit primary btn-sm btn-3" data-target="#login-modal" data-uid="" id="submitButton" type="button">
# <span class="hidden-xs">Publish</span><span class="visible-xs"><span class="glyphicon glyphicon-check"></span></span>
# </button>
# </div>
# </div>
# </div>
# </div>
# <div id="comment-message"></div>
# </input></input></input></input></input></input></form>
# </div>
# <ul class="clearfix" id="comments-list"></ul>
# </div>
# <!-- Modal -->
# <div aria-hidden="true" aria-labelledby="cmt-report-label" class="modal fade" id="cmt-report-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span><span class="sr-only">Close</span></button>
# <h4 class="modal-title" id="cmt-report-label">Report Comment</h4>
# </div>
# <div class="modal-body">
# <p>We're doing our best to make sure our content is useful, accurate and safe.<br/>If by any chance you spot an inappropriate comment while navigating through our website please use this form to let us know, and we'll take care of it shortly.</p>
# <div class="form-group">
# <textarea class="form-control" id="cmt-report-reason" placeholder="You may specify the reason for the report here..." rows="3"></textarea>
# </div>
# <input id="cmt-reported" type="hidden"/>
# </div>
# <div class="modal-footer">
# <button class="btn" data-dismiss="modal" type="button">Cancel</button>
# <button class="btn primary report-comment" type="button">Report</button>
# </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="cmt-attachment-label" class="modal fade" id="cmt-attachment-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span><span class="sr-only">Close</span></button>
# <h4 class="modal-title" id="cmt-attachment-label">Attachment</h4>
# </div>
# <div class="modal-body flex-align-center justify-center">
# <img alt="" class="thumbnail" id="cmt-image"/>
# <audio controls="" id="cmt-player"></audio>
# </div>
# <div class="modal-footer">
# <button class="btn tertiary" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# <style>#login-modal.modal #or{background-color:#fff}#login-modal.modal .sn-message{list-style:none;font-size:11px;text-align:center;padding:0;margin:20px 0 -20px}#login-modal.modal .ptext{font-size:12px}#login-modal.modal .waiting{opacity:0;font-size:5px;height:15px}#login-modal.modal ul.errors-list{margin:0 0 10px;padding:0;list-style:none;line-height:12px;font-size:12px}</style>
# <div aria-hidden="true" aria-labelledby="loginModal" class="modal fade" id="login-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title" id="loginModal">You need to be logged in to <span class="modal-type">favorite</span>.</h4>
# </div>
# <div class="modal-body edit-content">
# <div class="row social-signin">
# <div class="col-xs-12 col-sm-6">
# <div class="g-signin2" data-height="40" data-longtitle="true" data-onfailure="onFailure" data-onsuccess="onSuccess" data-scope="profile email" data-theme="dark" data-width="240"></div> </div>
# <div class="col-xs-12 col-sm-6">
# <div class="fb-login-button" data-auto-logout-link="false" data-max-rows="3" data-onlogin="checkLoginState();" data-scope="email" data-show-faces="false" data-size="large" data-use-continue-as="true" data-width="240px"></div> </div>
# </div>
# <ul class="sn-message"></ul>
# <div class="or-container">
# <hr class="or-hr"/>
# <div id="or">or fill the form below</div>
# </div>
# <div class="row">
# <div class="col-sm-6 short_signin">
# <h4>Create a new account</h4>
# <div class="text-center waiting"><i class="fas fa-spinner fa-spin fa-3x fa-fw"></i></div>
# <form id="modal-signup-frm" method="post">
# <ul class="errors-list"></ul>
# <input id="frm-action" name="action" type="hidden" value="short_signin"/>
# <input id="frm-source" name="source" type="hidden" value="0"/>
# <input id="website" name="website" type="hidden" value="3"/>
# <input id="fld-sra" name="sra" type="hidden" value="200.105.247.2"/>
# <div class="bcols clearfix row">
# <section class="col-xs-12">
# <div class="col-left">
# <p>
# <label for="fld-rname">Your name:<span class="mandatory">*<span>Required</span></span></label>
# <input class="fw" id="fld-rname" maxlength="100" name="rname" type="text" value=""/>
# </p>
# </div>
# </section>
# <section class="col-xs-12">
# <div class="col-left">
# <p>
# <label for="fld-uemail">Your email address:<span class="mandatory">*<span>Required</span></span></label>
# <input class="fw" id="fld-uemail" maxlength="100" name="uemail" type="text" value=""/>
# </p>
# </div>
# </section>
# <section class="col-xs-12">
# <div class="col-left">
# <p>
# <label for="fld-uname">Pick a user name:<span class="mandatory">*<span>Required</span></span></label>
# <input class="fw" id="fld-uname" maxlength="50" name="uname" type="text" value=""/>
# </p>
# </div>
# </section>
# <section class="col-xs-12">
# <div class="col-left text-right">
# <p><button class="btn primary" type="submit">Join</button></p>
# </div>
# </section>
# </div>
# </form>
# </div>
# <div class="col-sm-6 short_login">
# <h4>Log In</h4>
# <div class="text-center waiting"><i class="fas fa-spinner fa-spin fa-3x fa-fw"></i></div>
# <form id="modal-login-frm" method="post">
# <ul class="errors-list"></ul>
# <input id="frm-action-2" name="action" type="hidden" value="short_login"/>
# <div class="scols clearfix">
# <section>
# <p>
# <label for="fld-uname-2">Username:<span class="mandatory">*<span>Required</span></span></label>
# <input class="fw" id="fld-uname-2" maxlength="50" name="uname" type="text" value=""/>
# </p>
# </section>
# <section>
# <p>
# <label for="fld-upass">Password:<span class="mandatory">*<span>Required</span></span></label>
# <input autocomplete="off" class="fw" id="fld-upass" maxlength="30" name="upass" type="password" value=""/>
# </p>
# </section>
# <section>
# <div class="inner-section text-right">
# <p><button class="btn primary" type="submit">Log In</button></p>
# <br/>
# <p class="ptext">Forgot your password?   <button class="btn secondary xxsml" onclick="location.href='https://www.lyrics.com/forgotpass.php';" type="button">Retrieve it</button></p>
# </div>
# </section>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div> </div>
# <section class="biblio">
# <hgroup>
# <h3>Citation</h3>
# <h4>Use the citation below to add these lyrics to your bibliography:</h4>
# </hgroup>
# <div class="well rc5">
# <span class="cit-copy-frame"><span class="cit-copy" title="Copy to clipboard"><i aria-hidden="true" class="fas fa-clipboard"></i></span></span>
# <p data-aname="Maluma" data-is_lf="1" data-key="1843281" data-page="lyric" data-title="Hawái" id="cite-style-select"><strong>Style:</strong><span class="rc3 s" data-type="MLA" id="cite-style-select-MLA">MLA</span><span class="rc3" data-type="Chicago" id="cite-style-select-Chicago">Chicago</span><span class="rc3" data-type="APA" id="cite-style-select-APA">APA</span></p>
# <p id="cite-content"><cite>"Hawái Lyrics."</cite> <em>Lyrics.com.</em> STANDS4 LLC, 2022. Web. 27 Aug. 2022. &lt;<a class="force-wrap" href="https://www.lyrics.com/lyric-lf/1843281/Maluma/Haw%C3%A1i">https://www.lyrics.com/lyric-lf/1843281/Maluma/Haw%C3%A1i</a>&gt;.</p>
# </div>
# <div class="citation-footer">
# <span>Powered by <a href="https://www.cite.me" rel="noopener noreferrer nofollow" target="_blank" title="Cite.Me">CITE.ME</a></span>
# <a aria-label="Cite.Me" href="https://www.cite.me" rel="noopener noreferrer nofollow" target="_blank" title="Cite.Me"><img alt="Cite.Me" height="18" loading="lazy" src="https://static.stands4.com/app_common/img/cite-me-gray.png" style="filter: grayscale(100%);" title="Cite.Me" width="18"/></a>
# </div> </section>
# </div>
# <div class="callout clearfix row">
# <div>
# <div class="callout-int">
# <div class="row">
# <div class="col-xs-12 col-sm-8">
# <hgroup>
# <h2>Missing lyrics by Maluma?</h2>
# <h3>Know any other songs by Maluma? Don't keep it to yourself!</h3>
# </hgroup>
# </div>
# <div class="col-xs-12 col-sm-4">
# <div class="actions"><button class="btn primary lrg" onclick="location.href='https://www.lyrics.com/addlyric.php?aid=2669415';" type="button">Add it Here</button></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Modal -->
# <div aria-hidden="true" aria-labelledby="credit-label" class="modal fade" id="img-credit" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span><span class="sr-only">Close</span></button>
# <h4 class="modal-title" id="credit-label">Image Credit</h4>
# </div>
# <div class="modal-body table-responsive"></div>
# <div class="modal-footer">
# <button class="btn primary" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div> </div>
# <div class="col-sm-4 col-sm-pull-8" id="content-aside">
# <div class="hidden-xs">
# <div class="sep-area"><hr class="sep"/></div>
# <div class="tagline">
# <h3>The Web's Largest Resource for</h3>
# <h2>Music, Songs <span>&amp;</span> Lyrics</h2>
# </div> <div class="nsep"><hr/><h3>A Member Of The <span>STANDS4 Network</span></h3></div>
# <div id="sb-social">
# <div class="clearfix">
# <div class="social"><a href="#" id="share-facebook" rel="noopener noreferrer nofollow" target="_blank" title="Share this page on Facebook"><span class="fb"><i aria-hidden="true" class="fab fa-facebook-f"></i></span></a></div>
# <div class="social"><a href="#" id="share-twitter" rel="noopener noreferrer nofollow" target="_blank" title="Share this page on Twitter"><span class="tw"><i aria-hidden="true" class="fab fa-twitter"></i></span></a></div>
# <div class="social"><a href="#" id="share-reddit" rel="noopener noreferrer nofollow" target="_blank" title="Share this page on Reddit"><span class="rd"><i aria-hidden="true" class="fab fa-reddit-alien"></i></span></a></div>
# <div class="social"><a href="#" id="share-addthis" rel="noopener noreferrer nofollow" target="_blank" title="Share this page with AddThis"><span class="at"><i aria-hidden="true" class="fas fa-plus"></i></span></a></div>
# </div>
# </div> <div class="sep-area"><hr class="sep"/></div>
# </div><div class="cblocks">
# <div class="cblock falbum">
# <hgroup class="clearfix">
# <h4>Watch the song video</h4>
# <h3>Hawái</h3>
# </hgroup>
# <div class="youtube-content">
# <div class="youtube-player" data-id="5kHq6hqgROc"></div>
# <div class="youtube-infos">
# <div class="info-views"><i class="far fa-eye"></i> <span>96.9M</span></div>
# <div class="info-likes text-right">
# <i class="far fa-thumbs-up"></i> <span>436.1K</span>
# 		    			<i class="far fa-thumbs-down"></i> <span>22,649</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <section class="ad-slot"><div id="div-gpt-ad-Lyrics_LR_300x250_A">
# <script>
# doDisplay('div-gpt-ad-Lyrics_LR_300x250_A');
# </script>
# </div>
# <div id="div-gpt-ad-Lyrics_Mobile_LR_300x250_A">
# <script>
# doDisplay('div-gpt-ad-Lyrics_Mobile_LR_300x250_A');
# </script>
# </div></section>
# <div class="visible-xs cblocks">
# <div class="alpha-mob cblock">
# <hgroup class="clearfix">
# <h3>Browse Lyrics.com</h3>
# </hgroup>
# <div class="cblock-int">
# <div class="alpha-mob-list">
# <a href="/artists/0">#</a><a href="/artists/A">A</a><a href="/artists/B">B</a><a href="/artists/C">C</a><a href="/artists/D">D</a><a href="/artists/E">E</a><a href="/artists/F">F</a><a href="/artists/G">G</a><a href="/artists/H">H</a><a href="/artists/I">I</a><a href="/artists/J">J</a><a href="/artists/K">K</a><a href="/artists/L">L</a><a href="/artists/M">M</a><a href="/artists/N">N</a><a href="/artists/O">O</a><a href="/artists/P">P</a><a href="/artists/Q">Q</a><a href="/artists/R">R</a><a href="/artists/S">S</a><a href="/artists/T">T</a><a href="/artists/U">U</a><a href="/artists/V">V</a><a href="/artists/W">W</a><a href="/artists/X">X</a><a href="/artists/Y">Y</a><a href="/artists/Z">Z</a> </div>
# </div>
# </div>
# </div><section class="ad-slot"><div id="div-gpt-ad-Lyrics_LR_300x250_B">
# <script>
# doDisplay('div-gpt-ad-Lyrics_LR_300x250_B');
# </script>
# </div>
# <div id="div-gpt-ad-Lyrics_Mobile_LR_300x250_B">
# <script>
# doDisplay('div-gpt-ad-Lyrics_Mobile_LR_300x250_B');
# </script>
# </div></section>
# <div class="cblocks">
# <div class="cblock promotions-list">
# <hgroup class="clearfix">
# <h4>Our awesome collection of</h4>
# <h3>Promoted Songs</h3>
# </hgroup>
# <span class="more"><a href="/promoted-songs">»</a></span>
# <div class="cblock-int">
# ...
# </div>
# </div>
# </div>
# <div class="cblocks">
# <div class="cblock radio">
# <div class="radio-head">
# <div class="icon-radio">
# <span class="fa-stack fa-lg">
# <i class="fas fa-circle-notch fa-stack-2x"></i>
# <i class="fas fa-microphone fa-stack-1x"></i>
# </span>
# </div>
# <div class="radio-title">
# <div>Maluma tracks</div>
# <h4>On Radio Right Now</h4>
# </div>
# </div>
# <div class="cblock-int radio-container">
# <div id="dar_preview"><i class="fas fa-circle-notch fa-spin"></i> Loading...</div>
# <div class="image-viewer" data-name="Maluma"></div>
# </div>
# <p class="powered-by container-fluid">
# 			Powered by <strong><a href="http://onrad.io" rel="nofollow" target="_blank">OnRad.io</a></strong>
# </p>
# <hr/>
# <p class="powered-by container-fluid" style="text-align: center;">
# 			Think you know music? Test your <strong><a href="https://yourmusiciq.com/" rel="nofollow" target="_blank">MusicIQ here!</a></strong>
# </p>
# </div>
# </div><script>
# /* Lyrics.net - MedRec */
# cf_page_artist = "";
# cf_page_song = "Hawái";
# cf_adunit_id = "39381629";
# </script>
# <script async="" defer="" src="//srv.clickfuse.com/showads/showad.js"></script>
# <br/>
# <br/>
# </div>
# </div>
# </div>
# <footer id="footer">
# <div class="clearfix container-fluid" id="footer-int">
# <div class="clearfix">
# <div class="col-xs-12 col-sm-3">
# <div class="row">
# <div class="col-xs-6 col-sm-5">
# <div class="h5">Company</div>
# <ul>
# <li><a href="https://www.lyrics.com/">Home</a></li>
# <li><a href="about.php">About</a></li>
# <li><a href="news.php">News</a></li>
# <li class="ex"><a href="press.php">Press</a></li>
# <li><a href="awards.php">Awards</a></li>
# <li><a href="testimonials.php">Testimonials</a></li>
# </ul>
# </div>
# <div class="col-xs-6 col-sm-7">
# <div class="h5">Editorial</div>
# <ul>
# <li><a href="login.php">Login</a></li>
# <li><a href="addlyric.php">Add new Lyrics</a></li>
# <li><a href="addalbum.php">Add a new Album</a></li>
# <li class="ex"><a href="signup.php">Become a Member</a></li>
# <li><a href="editors.php">Meet the Editors</a></li>
# <li><a href="/justadded">Recently Added</a></li>
# <li class="ex"><a href="/song-parodies">Song Parodies <b><i class="far fa-smile"></i></b></a></li>
# <li><a href="activity.php">Activity Log</a></li>
# <li><a href="toplyrics.php">Most Popular</a></li>
# <li class="ex"><a href="/sell-your-lyrics">Sell Your Lyrics</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4">
# <div class="row">
# <div class="col-xs-6 col-sm-6">
# <div class="h5">Services</div>
# <ul>
# <li class="ex"><a href="/playlist">Your Playlist</a></li>
# <li><a href="invite.php">Tell a Friend</a></li>
# <li><a href="#" id="page-bookmark">Bookmark Us</a></li>
# <li class="ex"><a href="promotion.php">Promote <i class="fas fa-bullhorn fa-1x"></i></a></li>
# <li><a href="help-me-find-the-song.php">Help me Out!</a></li>
# <li><a href="lyrics_api.php">Lyrics API</a></li>
# <li class="ex"><a href="top-on-radio.php">Top on Radio <i class="fas fa-microphone fa-1x"></i></a></li>
# <li><a href="/song-lyrics-generator">Lyrics Generator</a></li>
# <li class="ex"><a href="https://www.lyrics.com/lyrics-quiz">The Lyrics Quiz</a></li>
# <li><a href="/marketplace">Marketplace <i class="fas fa-shopping-bag fa-1x"></i></a></li>
# <li><a href="articles.php">Articles</a></li>
# </ul>
# </div>
# <div class="col-xs-6 col-sm-6">
# <div class="h5">Legal &amp; Contact</div>
# <ul class="last">
# <li><a href="terms.php">Terms of Use</a></li>
# <li><a href="privacy.php">Privacy Policy</a></li>
# <li><a href="contact.php">Contact Us</a></li>
# <li class="ex"><a href="advertise.php">Advertise</a></li>
# <li><a href="affiliate-program.php">Affiliate Program	</a></li>
# <li> </li>
# <li><span class="light">Get the Apps:</span></li>
# <li>
# <a aria-label="Lyrics.com on App Store" href="https://apps.apple.com/us/app/lyrics-com/id1467868195" style="font-size:20px; display: inline-block;" target="_blank">
# <i class="fab fa-apple"></i>
# </a>
# 								<a aria-label="Lyrics.com on Google Play" href="https://play.google.com/store/apps/details?id=com.stand4.lyrics" style="font-size:20px; display: inline-block" target="_blank">
# <i class="fab fa-android"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-5" id="s4-network">
# <div class="row">
# <div class="h5 col-xs-12 col-sm-12">The STANDS4 Network</div>
# </div>
# <!-- Desktop version -->
# <div class="clearfix row hidden-xs">
# <div class="col-xs-12 col-sm-8">
# <div class="row">
# <div class="col-xs-6 col-sm-6">
# <ul>
# <li class="nw-abbreviations"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.abbreviations.com/" rel="nofollow noopener noreferrer">Abbreviations</a></li>
# <li class="nw-calculator"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.calculators.net/" rel="nofollow noopener noreferrer">Calculators</a></li>
# <li class="nw-grammar"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.grammar.com/" rel="nofollow noopener noreferrer">Grammar</a></li>
# <li class="nw-phrases"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.phrases.com/" rel="nofollow noopener noreferrer">Phrases</a></li>
# <li class="nw-references"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.references.net/" rel="nofollow noopener noreferrer">References</a></li>
# <li class="nw-symbols"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.symbols.com/" rel="nofollow noopener noreferrer">Symbols</a></li>
# </ul>
# </div>
# <div class="col-xs-6 col-sm-6">
# <ul>
# <li class="nw-anagrams"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.anagrams.net/" rel="nofollow noopener noreferrer">Anagrams</a></li>
# <li class="nw-convert"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.convert.net/" rel="nofollow noopener noreferrer">Conversions</a></li>
# <li class="nw-ua"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.literature.com/" rel="nofollow noopener noreferrer">Literature</a></li>
# <li class="nw-poetry"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.poetry.com/" rel="nofollow noopener noreferrer">Poetry</a></li>
# <li class="nw-rhymes"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.rhymes.com/" rel="nofollow noopener noreferrer">Rhymes</a></li>
# <li class="nw-synonyms"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.synonyms.com/" rel="nofollow noopener noreferrer">Synonyms</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4">
# <ul class="last">
# <li class="nw-biographies"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.biographies.net/" rel="nofollow noopener noreferrer">Biographies</a></li>
# <li class="nw-definitions"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.definitions.net/" rel="nofollow noopener noreferrer">Definitions</a></li>
# <li class="nw-lyrics"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.lyrics.com/" rel="nofollow noopener noreferrer">Lyrics</a></li>
# <li class="nw-quotes"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.quotes.net/" rel="nofollow noopener noreferrer">Quotes</a></li>
# <li class="nw-scripts"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.scripts.com/" rel="nofollow noopener noreferrer">Scripts</a></li>
# <li class="nw-uszip"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.uszip.com/" rel="nofollow noopener noreferrer">Zip Codes</a></li>
# </ul>
# </div>
# </div>
# <!-- Mobile version -->
# <div class="clearfix row hidden-sm hidden-md hidden-lg">
# <div class="col-xs-12 col-sm-8">
# <div class="row">
# <div class="col-xs-6 col-sm-6">
# <ul>
# <li class="nw-abbreviations"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.abbreviations.com/" rel="nofollow noopener noreferrer">Abbreviations</a></li>
# <li class="nw-anagrams"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.anagrams.net/" rel="nofollow noopener noreferrer">Anagrams</a></li>
# <li class="nw-biographies"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.biographies.net/" rel="nofollow noopener noreferrer">Biographies</a></li>
# <li class="nw-convert"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.convert.net/" rel="nofollow noopener noreferrer">Conversions</a></li>
# <li class="nw-calculator"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.calculators.net/" rel="nofollow noopener noreferrer">Calculators</a></li>
# <li class="nw-definitions"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.definitions.net/" rel="nofollow noopener noreferrer">Definitions</a></li>
# <li class="nw-grammar"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.grammar.com/" rel="nofollow noopener noreferrer">Grammar</a></li>
# <li class="nw-ua"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.literature.com/" rel="nofollow noopener noreferrer">Literature</a></li>
# <li class="nw-lyrics"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.lyrics.com/" rel="nofollow noopener noreferrer">Lyrics</a></li>
# </ul>
# </div>
# <div class="col-xs-6 col-sm-6">
# <ul>
# <li class="nw-phrases"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.phrases.com/" rel="nofollow noopener noreferrer">Phrases</a></li>
# <li class="nw-poetry"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.poetry.com/" rel="nofollow noopener noreferrer">Poetry</a></li>
# <li class="nw-quotes"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.quotes.net/" rel="nofollow noopener noreferrer">Quotes</a></li>
# <li class="nw-references"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.references.net/" rel="nofollow noopener noreferrer">References</a></li>
# <li class="nw-rhymes"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.rhymes.com/" rel="nofollow noopener noreferrer">Rhymes</a></li>
# <li class="nw-scripts"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.scripts.com/" rel="nofollow noopener noreferrer">Scripts</a></li>
# <li class="nw-symbols"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.symbols.com/" rel="nofollow noopener noreferrer">Symbols</a></li>
# <li class="nw-synonyms"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.synonyms.com/" rel="nofollow noopener noreferrer">Synonyms</a></li>
# <li class="nw-uszip"><svg class="s4-shape"><polygon points="0,1 10,0 10,15 0,9"></polygon><polygon points="20,1 10,0 10,15 20,9"></polygon></svg><a href="https://www.uszip.com/" rel="nofollow noopener noreferrer">Zip Codes</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix">
# <div class="copyright"><strong>© 2001-2022 STANDS4 LLC.</strong><br/>All rights reserved.</div>
# <div id="social-icons">
# <a href="https://www.facebook.com/STANDS4" rel="nofollow noopener noreferrer" target="_blank" title="Facebook"><span class="social fb"><i aria-hidden="true" class="fab fa-facebook-f"></i></span></a>
# <a href="https://twitter.com/lyrics_dot_com" rel="nofollow noopener noreferrer" target="_blank" title="Twitter"><span class="social tw"><i aria-hidden="true" class="fab fa-twitter"></i></span></a>
# <a href="https://www.linkedin.com/company/stands4/" rel="nofollow noopener noreferrer" target="_blank" title="LinkedIn"><span class="social lkd"><i aria-hidden="true" class="fab fa-linkedin-in"></i></span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <link href="https://static.stands4.com/app_common/css/font-awesome-5.0.min.css" rel="stylesheet"/>
# <link href="https://static.stands4.com/app_common/css/smoothness/jquery-ui-1.13.2.custom.min.css?v=1.0.1" rel="stylesheet"/>
# <script crossorigin="anonymous" defer="" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" src="//code.jquery.com/jquery-3.6.0.min.js"></script>
# <script defer="" src="https://static.stands4.com/app_common/js/libs/jquery-ui-1.13.2.custom.min.js?v=1.0.1"></script>
# <script defer="" src="https://static.stands4.com/app_lyrics/js/onradio/inline.js?v=1.4.5"></script>
# <script defer="" src="https://static.stands4.com/app_common/js/libs/wselect.min.js"></script>
# <script defer="" src="https://static.stands4.com/app_common/js/libs/bootstrap-3.4.1.min.js"></script>
# <script defer="" src="https://static.stands4.com/app_lyrics/js/lyrc.min.js?v=1.4.5"></script>
# <script data-id="UA-172613-15" defer="" id="s4-analytics" src="https://static.stands4.com/app_common/js/page.analytics.min.js?v=1.4.5"></script>
# <script defer="" src="https://www.googletagmanager.com/gtag/js?id=UA-172613-15"></script><script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-6071864913982699"></script>
# </body>
# </html>
# <!-- Timer: 0.4319 secs | Server: ip-172-30-3-253 -->

# %%
# obtiene el cuerpo del contenido web de la letra de la canción
results_letra_cancion = soup_letra_cancion.find(id="content-body")
print(results_letra_cancion.prettify())
# Out:
# <div id="content-body">
#  <div class="clearfix">
#   <div class="lyric clearfix">
#    <div class="head-btns">
#     <p class="print-style-icon">
#      <span class="rc3 s fsize" title="Change text size">
#       <span class="glyphicon glyphicon-text-size">
#       </span>
#      </span>
#      <a class="rc3 s" href="email.php?id=37493623&amp;type=lyric" target="_blank" title="click to email Hawái to a friend">
#       <i class="fas fa-paper-plane">
#       </i>
#      </a>
#      <a class="rc3 s" href="print.php?id=37493623" target="_blank" title="click to send Hawái to your printer">
#       <span class="glyphicon glyphicon-print">
#       </span>
#      </a>
#      <a class="add-to-list s rc3" href="/lyrics-pdf/37493623" title="click to down the Hawái lyrics as PDF">
#       <i class="far fa-file-pdf">
#       </i>
#       PDF
#      </a>
#      <a class="rc3 s" href="sheetmusic.php?id=37493623" title="click for Hawái sheet music">
#       <span class="glyphicon glyphicon-music" style="margin-left: -1px;">
#       </span>
#      </a>
#      <a class="rc3 s" href="/song-parody-maker/37493623" title="click to create a parody of this song">
#       <b>
#        <i class="far fa-smile">
#        </i>
#       </b>
#      </a>
#      <a class="rc3 s" href="playlist.php?add=37493623&amp;sub=0" title="click to add Hawái to your playlist">
#       <span class="glyphicon glyphicon-list">
#       </span>
#       <span class="hidden-xs">
#        Playlist
#       </span>
#      </a>
#      <span class="audio tts-icon rc3 s" data-code="en-US" data-lang="Google US English" title="Hear this lyrics">
#       <i aria-hidden="true" class="fas fa-volume-up">
#       </i>
#      </span>
#     </p>
#    </div>
#    <hgroup dir="ltr">
#     <h1 class="lyric-title" id="lyric-title-text">
#      Hawái
#     </h1>
#     <div class="mstore">
#      <a href="https://music.apple.com/us/search?term=Haw%C3%A1i+by+Maluma" target="_blank" title="Listen to this song on Apple Music">
#       <span class="shop">
#        <i aria-hidden="true" class="fab fa-apple">
#        </i>
#       </span>
#      </a>
#      <a class="store-amz" href="https://www.amazon.com/gp/search?index=digital-music&amp;keywords=Haw%C3%A1i+by+Maluma&amp;tag=stands4com-20" target="_blank" title="Listen to this song on Amazon">
#       <span class="shop">
#        <i aria-hidden="true" class="fab fa-amazon">
#        </i>
#       </span>
#      </a>
#      <a href="https://www.amazon.com/gp/search?index=digital-music&amp;keywords=Haw%C3%A1i+by+Maluma&amp;tag=stands4com-20" target="_blank" title="Listen to this song on Amazon">
#       <small>
#        Listen online
#       </small>
#      </a>
#     </div>
#     <h3 class="lyric-artist">
#      <a href="artist/Maluma/2669415">
#       Maluma
#      </a>
#     </h3>
#    </hgroup>
#    <div class="lyric-infobox clearfix">
#     <div class="artist-thumb" data-artist="Maluma" data-img="1" id="featured-artist-avatar">
#      <a href="artist/Maluma/2669415" title="Maluma">
#       <img alt="" height="125" loading="lazy" src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Maluma_-_Espaço_das_Américas_(37591053894).jpg/244px-Maluma_-_Espaço_das_Américas_(37591053894).jpg" style="margin-left:0;" title="Maluma" width="120"/>
#      </a>
#      <div class="wiki-credit">
#       <span class="wiki-name hidden">
#        Maluma
#       </span>
#       <span data-type="2">
#        Maluma
#        <i class="fa-info-circle fas">
#        </i>
#       </span>
#      </div>
#     </div>
#     <div class="artist-meta">
#      <div class="flr">
#       <p class="favorite-style-select" data-key="2669415" data-page="lyric">
#        <button class="btn s" data-aid="2669415" data-sub="0" data-target="#login-modal" data-uid="" data-votes="2" id="artist-rate-btn" title="click to add your vote">
#         <i aria-hidden="true" class="fas fa-star">
#         </i>
#         <span>
#          FAVORITE
#         </span>
#        </button>
#        <span id="author-rate-votes" onclick="location.href='https://www.lyrics.com/artist-fans/2669415';">
#         (2 fans)
#        </span>
#       </p>
#      </div>
#      <h4>
#       <a href="artist/Maluma/2669415">
#        Maluma
#       </a>
#      </h4>
#      <p class="bio">
#       Juan Luis Londoño Arias (born 28 January 1994), known professionally as Maluma, is a Colombian singer, songwriter, and actor signed to Sony Music Colombia, Sony Latin and Fox Music. Born and raised in Medellín, he developed an interest in music at a young age, and began recording songs at age 16. He released his debut album, Magia, a year later in 2012. However, his breakthrough album was 2015's Pretty Boy, Dirty Boy, which led to successful collaborations with artists Thalía, Shakira and Ricky Martin. He released F.A.M.E. in 2018, to further commercial success. He followed it up with 11:11, released the next year.
#       <a href="artist/Maluma/2669415">
#        more »
#       </a>
#      </p>
#     </div>
#     <br/>
#     <div class="lyric-details">
#      <input data-id="37493623" data-type="lyric" id="lyric-data" type="hidden"/>
#      <dl>
#       <dt>
#        <i aria-hidden="true" class="far fa-clock" title="Duration">
#        </i>
#       </dt>
#       <dd class="dd-margin">
#        3:20
#       </dd>
#       <dt>
#        <i aria-hidden="true" class="far fa-eye">
#        </i>
#       </dt>
#       <dd class="c-views">
#        74
#        <span class="hidden-xs">
#         Views
#        </span>
#       </dd>
#      </dl>
#     </div>
#    </div>
#    <div class="row">
#     <div class="adunit-middle adunit-middle-2col clearfix">
#      <div class="col-xs-12 col-sm-12">
#       <div id="div-gpt-ad-Lyrics_IA_300x250_A">
#        <script>
#         doDisplay('div-gpt-ad-Lyrics_IA_300x250_A');
#        </script>
#       </div>
#       <div id="div-gpt-ad-Lyrics_Mobile_IA_300x250_A">
#        <script>
#         doDisplay('div-gpt-ad-Lyrics_Mobile_IA_300x250_A');
#        </script>
#       </div>
#      </div>
#     </div>
#    </div>
#    <script>
#     /* Lyrics.net - TFP - Above */
# (function() {
#                 var opts = {
# 		                		artist: "",
# 		                        song: "",
#                                 adunit_id: 39384263,
#                                 div_id: "cf_async_" + Math.floor((Math.random() * 999999999))
#                 };
#                 document.write('<div id="'+opts.div_id+'"></div>');var c=function(){cf.showAsyncAd(opts)};if(window.cf)c();else{cf_async=!0;var r=document.createElement("script"),s=document.getElementsByTagName("script")[0];r.async=!0;r.src="https://srv.clickfuse.com/showads/showad.js";r.readyState?r.onreadystatechange=function(){if("loaded"==r.readyState||"complete"==r.readyState)r.onreadystatechange=null,c()}:r.onload=c;s.parentNode.insertBefore(r,s)};
# })();
#    </script>
#    <h3 class="lyric-artist text-center">
#     <span style="font-weight: 700; font-size: 15px;">
#      <a href="https://www.30daysinger.com/a/8328/LfArfDh6?utm_campaign=lyrics_top_link&amp;title=4" rel="nofollow" target="_blank">
#       <i aria-hidden="true" class="fas fa-check" style="color: #666;">
#       </i>
#       Struggling with Hawái? Become a better singer
#       <u>
#        in 30 days
#       </u>
#       with these videos!
#      </a>
#     </span>
#    </h3>
#    <pre class="lyric-body" data-lang="en" dir="ltr" id="lyric-body-text">Deja de <a href="https://www.definitions.net/definition/mentirte" style="color:#222;">mentirte</a> (ah)
# La foto que <a href="https://www.definitions.net/definition/subiste" style="color:#222;">subiste</a> con él <a href="https://www.definitions.net/definition/diciendo" style="color:#222;">diciendo</a> que era tu cielo
# Bebé, yo te <a href="https://www.definitions.net/definition/conozco" style="color:#222;">conozco</a> tan bien, sé que fue pa' <a href="https://www.definitions.net/definition/darme" style="color:#222;">darme</a> celos
# No te diré quién, pero <a href="https://www.definitions.net/definition/llorando" style="color:#222;">llorando</a> por mí te vieron
# Por mí te vieron
#
# Déjame decirte
# Se ve que él te <a href="https://www.definitions.net/definition/trata" style="color:#222;">trata</a> bien, que es todo un caballero
# Pero eso no cambiará que yo llegué primero
# Sé que te va ir bien pero no te <a href="https://www.definitions.net/definition/quiere" style="color:#222;">quiere</a> como yo te quiero
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea como te va de bien, pero te <a href="https://www.definitions.net/definition/haces" style="color:#222;">haces</a> mal
# Porque el amor no se <a href="https://www.definitions.net/definition/compra" style="color:#222;">compra</a> na'
#
# Miéntele a <a href="https://www.definitions.net/definition/todos" style="color:#222;">todos</a> tus seguidore'
# Dile que los tiempo' de <a href="https://www.definitions.net/definition/ahora" style="color:#222;">ahora</a> son mejore'
# No creo que <a href="https://www.definitions.net/definition/cuando" style="color:#222;">cuando</a> te <a href="https://www.definitions.net/definition/llame" style="color:#222;">llame</a> me ignores
# Si después de mí ya no habrán más amores
#
# Tú y yo fuimo' uno
# Lo hacíamo' en ayuna' <a href="https://www.definitions.net/definition/antes" style="color:#222;">antes</a> del desayuno
# Fumábamo' la <a href="https://www.definitions.net/definition/hookah" style="color:#222;">hookah</a> y te <a href="https://www.definitions.net/definition/pasaba" style="color:#222;">pasaba</a> el humo
# Y <a href="https://www.definitions.net/definition/ahora" style="color:#222;">ahora</a> en esta <a href="https://www.definitions.net/definition/guerra" style="color:#222;">guerra</a> no gana ninguno
#
# Si me preguntas, <a href="https://www.definitions.net/definition/nadie" style="color:#222;">nadie</a> tiene culpa
# A vece' los <a href="https://www.definitions.net/definition/problemas" style="color:#222;">problemas</a> a uno se le juntan
# Déjame hablar, porfa, no me interrumpas
# Si te hice algo malo, <a href="https://www.definitions.net/definition/entonces" style="color:#222;">entonces</a> discúlpame
# La <a href="https://www.definitions.net/definition/gente" style="color:#222;">gente</a> te lo va a creer, actúas bien ese papel
# Baby, pero no eres <a href="https://www.definitions.net/definition/feliz" style="color:#222;">feliz</a> con él
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea como te va de bien, pero te <a href="https://www.definitions.net/definition/haces" style="color:#222;">haces</a> mal
# Porque el amor no se <a href="https://www.definitions.net/definition/compra" style="color:#222;">compra</a> na'
#
# (Deja de mentirte
# La foto que <a href="https://www.definitions.net/definition/subiste" style="color:#222;">subiste</a> con él <a href="https://www.definitions.net/definition/diciendo" style="color:#222;">diciendo</a> que era tu cielo)
# Mamacita
# (Bebé, yo te <a href="https://www.definitions.net/definition/conozco" style="color:#222;">conozco</a> tan bien, sé que fue pa' <a href="https://www.definitions.net/definition/darme" style="color:#222;">darme</a> celos)
#
# Maluma, baby
# (No te diré quién, pero <a href="https://www.definitions.net/definition/llorando" style="color:#222;">llorando</a> por mí te vieron)
# Jaja
# (Por mí te vieron)
# Papi Juancho</pre>
#    <h3 class="lyric-artist text-center">
#     <span style="font-weight: 700; font-size: 15px;">
#      <a href="https://www.30daysinger.com/a/8328/LfArfDh6?utm_campaign=lyrics_bottom_link&amp;title=3" rel="nofollow" target="_blank">
#       <i aria-hidden="true" class="fas fa-check" style="color: #666;">
#       </i>
#       The easy, fast &amp; fun way to learn how to sing: 30DaySinger.com
#      </a>
#     </span>
#    </h3>
#    <script>
#     /* Lyrics.net - TFP - Below */
# (function() {
#                 var opts = {
#                                 artist: "",
#                                 song: "Hawái",
#                                 adunit_id: 39384264,
#                                 div_id: "cf_async_" + Math.floor((Math.random() * 999999999))
#                 };
#                 document.write('<div id="'+opts.div_id+'"></div>');var c=function(){cf.showAsyncAd(opts)};if(window.cf)c();else{cf_async=!0;var r=document.createElement("script"),s=document.getElementsByTagName("script")[0];r.async=!0;r.src="https://srv.clickfuse.com/showads/showad.js";r.readyState?r.onreadystatechange=function(){if("loaded"==r.readyState||"complete"==r.readyState)r.onreadystatechange=null,c()}:r.onload=c;s.parentNode.insertBefore(r,s)};
# })();
#    </script>
#    <div class="lyric-credits clearfix">
#     <div class="head-btns">
#      <p class="print-style-icon">
#       <a class="rc3 s" href="sheetmusic.php?id=37493623" target="_blank" title="click for Hawái sheet music">
#        <span class="glyphicon glyphicon-music" style="margin-left: -1px;">
#        </span>
#        Sheet Music
#       </a>
#       <a class="rc3 s" href="email.php?id=37493623&amp;type=lyric" target="_blank" title="click to email Hawái to a friend">
#        <i class="fas fa-paper-plane">
#        </i>
#       </a>
#       <a class="rc3 s" href="print.php?id=37493623" target="_blank" title="click to send Hawái to your printer">
#        <span class="glyphicon glyphicon-print">
#        </span>
#       </a>
#       <a class="add-to-list s rc3" href="/lyrics-pdf/37493623" title="click to down the Hawái lyrics as PDF">
#        <i class="far fa-file-pdf">
#        </i>
#        PDF
#       </a>
#       <a class="rc3 s" href="/song-parody-maker/37493623" title="click to create a parody of this song">
#        <b>
#         <i class="far fa-smile">
#         </i>
#        </b>
#       </a>
#       <a class="rc3 s" href="playlist.php?add=37493623&amp;sub=0" title="click to add Hawái to your playlist">
#        <span class="glyphicon glyphicon-list">
#        </span>
#        <span class="hidden-xs">
#         Playlist
#        </span>
#       </a>
#      </p>
#     </div>
#     <p>
#      Written by: Andres Uribe Marin, Bryan Snaider Lezcano Chaverra, Edgar Barrera, Johan Espinosa, Juan Camilo Vargas Vasquez, Juan Luis Londono Arias, Kevin Mauricio Jimenez Londono, Kevyn Mauricio Cruz Moreno, Rene Cano, Stiven Rojas
#     </p>
#     <p>
#      Lyrics © DistroKid, Universal Music Publishing Group, Sony/ATV Music Publishing LLC, Warner Chappell Music, Inc.
#     </p>
#     <p>
#      Lyrics Licensed &amp; Provided by
#      <a href="http://www.lyricfind.com" rel="nofollow">
#       LyricFind
#      </a>
#     </p>
#    </div>
#   </div>
#   <div class="row visible-xs">
#    <div class="adunit-middle adunit-middle-2col clearfix">
#     <div class="col-xs-12 col-sm-6 text-center">
#      <div id="div-gpt-ad-Lyrics_Mobile_LR_300x250_D">
#       <script>
#        doDisplay('div-gpt-ad-Lyrics_Mobile_LR_300x250_D');
#       </script>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="callout comments-area">
#    <div id="s4-comments">
#     <h4>
#      Discuss the
#      <a href="/lyric-lf/1843281/Maluma/Haw%C3%A1i">
#       Hawái Lyrics
#      </a>
#      with the community:
#     </h4>
#     <div class="comment-form-container">
#      <form id="frm-comment">
#       <input id="commentId" name="comment_id" type="hidden">
#        <input id="cmtPart" name="cmt_part" type="hidden" value="1">
#         <input id="current-website" type="hidden" value="3">
#          <input id="current-entity" type="hidden" value="lyrics">
#           <input id="current-entityid" type="hidden" value="37493623">
#            <input id="comments-limit" type="hidden" value="10">
#             <div class="form-group">
#              <h5 id="frm-comment-count">
#               0 Comments
#              </h5>
#              <div class="form-control" contenteditable="true" data-placeholder="Add a comment..." id="comment">
#              </div>
#              <div class="cmt-options">
#               <div class="cmt-tools">
#                <span class="cmt-tool rc5" data-action="picture" id="pic-toggle" title="Upload an image">
#                 <span class="glyphicon glyphicon-picture">
#                 </span>
#                </span>
#                <div class="hidden" id="picture-btns">
#                 <input accept="image/*" class="pic-upload hidden" type="file"/>
#                 <input id="pic-stream" name="picture" type="hidden"/>
#                 <input id="pic-type" name="picture_type" type="hidden"/>
#                 <img alt="" height="14" id="pic-preview" src="" title="Preview" width="14"/>
#                 <span class="pic-name hidden-xs" style="display:none;">
#                 </span>
#                 <button class="btn secondary xxsml pic-clear" id="pic-clear" style="display:none;" type="button">
#                  <i class="fas fa-trash-alt">
#                  </i>
#                 </button>
#                </div>
#                <span class="cmt-tool record-tool rc5 text-center" data-action="sound" id="start" title="Record a sound">
#                 <!-- <span class="glyphicon glyphicon-music"></span> -->
#                 <span class="ready">
#                  <i class="fas fa-microphone">
#                  </i>
#                 </span>
#                 <span class="recording equalizer hidden">
#                  <span class="bar bar-1">
#                  </span>
#                  <span class="bar bar-2">
#                  </span>
#                  <span class="bar bar-3">
#                  </span>
#                 </span>
#                </span>
#                <div class="record-tool hidden" id="record-btns">
#                 <button class="btn tertiary xxsml hidden" id="stop" title="Stop Recording" type="button">
#                  <i class="fas fa-stop">
#                  </i>
#                 </button>
#                 <button class="btn tertiary xxsml hidden" id="play" title="Play" type="button">
#                  <i class="fas fa-play">
#                  </i>
#                 </button>
#                 <audio hidden="" id="recorder" muted="">
#                 </audio>
#                 <audio hidden="" id="player">
#                 </audio>
#                 <small hidden="" id="play-time">
#                  0:00
#                 </small>
#                 <small hidden="" id="rec-time">
#                  0:00
#                 </small>
#                 <small>
#                  <button class="btn xxsml" hidden="" id="clear-audio" type="button">
#                   clear
#                  </button>
#                 </small>
#                 <input id="rec-stream" name="sound" type="hidden"/>
#                </div>
#               </div>
#               <div class="cmt-publish clearfix">
#                <div class="col-xs-10 no-padding">
#                 <div class="checkbox" id="notify-box">
#                  <label class="small">
#                   <input id="notify" type="checkbox"/>
#                   Notify me of new comments via email.
#                  </label>
#                 </div>
#                </div>
#                <div class="col-xs-2 no-padding text-right">
#                 <button aria-label="Publish" class="btn btn-submit primary btn-sm btn-3" data-target="#login-modal" data-uid="" id="submitButton" type="button">
#                  <span class="hidden-xs">
#                   Publish
#                  </span>
#                  <span class="visible-xs">
#                   <span class="glyphicon glyphicon-check">
#                   </span>
#                  </span>
#                 </button>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div id="comment-message">
#             </div>
#            </input>
#           </input>
#          </input>
#         </input>
#        </input>
#       </input>
#      </form>
#     </div>
#     <ul class="clearfix" id="comments-list">
#     </ul>
#    </div>
#    <!-- Modal -->
#    <div aria-hidden="true" aria-labelledby="cmt-report-label" class="modal fade" id="cmt-report-modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button class="close" data-dismiss="modal" type="button">
#         <span aria-hidden="true">
#          ×
#         </span>
#         <span class="sr-only">
#          Close
#         </span>
#        </button>
#        <h4 class="modal-title" id="cmt-report-label">
#         Report Comment
#        </h4>
#       </div>
#       <div class="modal-body">
#        <p>
#         We're doing our best to make sure our content is useful, accurate and safe.
#         <br/>
#         If by any chance you spot an inappropriate comment while navigating through our website please use this form to let us know, and we'll take care of it shortly.
#        </p>
#        <div class="form-group">
#         <textarea class="form-control" id="cmt-report-reason" placeholder="You may specify the reason for the report here..." rows="3"></textarea>
#        </div>
#        <input id="cmt-reported" type="hidden"/>
#       </div>
#       <div class="modal-footer">
#        <button class="btn" data-dismiss="modal" type="button">
#         Cancel
#        </button>
#        <button class="btn primary report-comment" type="button">
#         Report
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div aria-hidden="true" aria-labelledby="cmt-attachment-label" class="modal fade" id="cmt-attachment-modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button class="close" data-dismiss="modal" type="button">
#         <span aria-hidden="true">
#          ×
#         </span>
#         <span class="sr-only">
#          Close
#         </span>
#        </button>
#        <h4 class="modal-title" id="cmt-attachment-label">
#         Attachment
#        </h4>
#       </div>
#       <div class="modal-body flex-align-center justify-center">
#        <img alt="" class="thumbnail" id="cmt-image"/>
#        <audio controls="" id="cmt-player">
#        </audio>
#       </div>
#       <div class="modal-footer">
#        <button class="btn tertiary" data-dismiss="modal" type="button">
#         Close
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#    <style>
#     #login-modal.modal #or{background-color:#fff}#login-modal.modal .sn-message{list-style:none;font-size:11px;text-align:center;padding:0;margin:20px 0 -20px}#login-modal.modal .ptext{font-size:12px}#login-modal.modal .waiting{opacity:0;font-size:5px;height:15px}#login-modal.modal ul.errors-list{margin:0 0 10px;padding:0;list-style:none;line-height:12px;font-size:12px}
#    </style>
#    <div aria-hidden="true" aria-labelledby="loginModal" class="modal fade" id="login-modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#         ×
#        </button>
#        <h4 class="modal-title" id="loginModal">
#         You need to be logged in to
#         <span class="modal-type">
#          favorite
#         </span>
#         .
#        </h4>
#       </div>
#       <div class="modal-body edit-content">
#        <div class="row social-signin">
#         <div class="col-xs-12 col-sm-6">
#          <div class="g-signin2" data-height="40" data-longtitle="true" data-onfailure="onFailure" data-onsuccess="onSuccess" data-scope="profile email" data-theme="dark" data-width="240">
#          </div>
#         </div>
#         <div class="col-xs-12 col-sm-6">
#          <div class="fb-login-button" data-auto-logout-link="false" data-max-rows="3" data-onlogin="checkLoginState();" data-scope="email" data-show-faces="false" data-size="large" data-use-continue-as="true" data-width="240px">
#          </div>
#         </div>
#        </div>
#        <ul class="sn-message">
#        </ul>
#        <div class="or-container">
#         <hr class="or-hr"/>
#         <div id="or">
#          or fill the form below
#         </div>
#        </div>
#        <div class="row">
#         <div class="col-sm-6 short_signin">
#          <h4>
#           Create a new account
#          </h4>
#          <div class="text-center waiting">
#           <i class="fas fa-spinner fa-spin fa-3x fa-fw">
#           </i>
#          </div>
#          <form id="modal-signup-frm" method="post">
#           <ul class="errors-list">
#           </ul>
#           <input id="frm-action" name="action" type="hidden" value="short_signin"/>
#           <input id="frm-source" name="source" type="hidden" value="0"/>
#           <input id="website" name="website" type="hidden" value="3"/>
#           <input id="fld-sra" name="sra" type="hidden" value="200.105.247.2"/>
#           <div class="bcols clearfix row">
#            <section class="col-xs-12">
#             <div class="col-left">
#              <p>
#               <label for="fld-rname">
#                Your name:
#                <span class="mandatory">
#                 *
#                 <span>
#                  Required
#                 </span>
#                </span>
#               </label>
#               <input class="fw" id="fld-rname" maxlength="100" name="rname" type="text" value=""/>
#              </p>
#             </div>
#            </section>
#            <section class="col-xs-12">
#             <div class="col-left">
#              <p>
#               <label for="fld-uemail">
#                Your email address:
#                <span class="mandatory">
#                 *
#                 <span>
#                  Required
#                 </span>
#                </span>
#               </label>
#               <input class="fw" id="fld-uemail" maxlength="100" name="uemail" type="text" value=""/>
#              </p>
#             </div>
#            </section>
#            <section class="col-xs-12">
#             <div class="col-left">
#              <p>
#               <label for="fld-uname">
#                Pick a user name:
#                <span class="mandatory">
#                 *
#                 <span>
#                  Required
#                 </span>
#                </span>
#               </label>
#               <input class="fw" id="fld-uname" maxlength="50" name="uname" type="text" value=""/>
#              </p>
#             </div>
#            </section>
#            <section class="col-xs-12">
#             <div class="col-left text-right">
#              <p>
#               <button class="btn primary" type="submit">
#                Join
#               </button>
#              </p>
#             </div>
#            </section>
#           </div>
#          </form>
#         </div>
#         <div class="col-sm-6 short_login">
#          <h4>
#           Log In
#          </h4>
#          <div class="text-center waiting">
#           <i class="fas fa-spinner fa-spin fa-3x fa-fw">
#           </i>
#          </div>
#          <form id="modal-login-frm" method="post">
#           <ul class="errors-list">
#           </ul>
#           <input id="frm-action-2" name="action" type="hidden" value="short_login"/>
#           <div class="scols clearfix">
#            <section>
#             <p>
#              <label for="fld-uname-2">
#               Username:
#               <span class="mandatory">
#                *
#                <span>
#                 Required
#                </span>
#               </span>
#              </label>
#              <input class="fw" id="fld-uname-2" maxlength="50" name="uname" type="text" value=""/>
#             </p>
#            </section>
#            <section>
#             <p>
#              <label for="fld-upass">
#               Password:
#               <span class="mandatory">
#                *
#                <span>
#                 Required
#                </span>
#               </span>
#              </label>
#              <input autocomplete="off" class="fw" id="fld-upass" maxlength="30" name="upass" type="password" value=""/>
#             </p>
#            </section>
#            <section>
#             <div class="inner-section text-right">
#              <p>
#               <button class="btn primary" type="submit">
#                Log In
#               </button>
#              </p>
#              <br/>
#              <p class="ptext">
#               Forgot your password?
#               <button class="btn secondary xxsml" onclick="location.href='https://www.lyrics.com/forgotpass.php';" type="button">
#                Retrieve it
#               </button>
#              </p>
#             </div>
#            </section>
#           </div>
#          </form>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <section class="biblio">
#    <hgroup>
#     <h3>
#      Citation
#     </h3>
#     <h4>
#      Use the citation below to add these lyrics to your bibliography:
#     </h4>
#    </hgroup>
#    <div class="well rc5">
#     <span class="cit-copy-frame">
#      <span class="cit-copy" title="Copy to clipboard">
#       <i aria-hidden="true" class="fas fa-clipboard">
#       </i>
#      </span>
#     </span>
#     <p data-aname="Maluma" data-is_lf="1" data-key="1843281" data-page="lyric" data-title="Hawái" id="cite-style-select">
#      <strong>
#       Style:
#      </strong>
#      <span class="rc3 s" data-type="MLA" id="cite-style-select-MLA">
#       MLA
#      </span>
#      <span class="rc3" data-type="Chicago" id="cite-style-select-Chicago">
#       Chicago
#      </span>
#      <span class="rc3" data-type="APA" id="cite-style-select-APA">
#       APA
#      </span>
#     </p>
#     <p id="cite-content">
#      <cite>
#       "Hawái Lyrics."
#      </cite>
#      <em>
#       Lyrics.com.
#      </em>
#      STANDS4 LLC, 2022. Web. 27 Aug. 2022. &lt;
#      <a class="force-wrap" href="https://www.lyrics.com/lyric-lf/1843281/Maluma/Haw%C3%A1i">
#       https://www.lyrics.com/lyric-lf/1843281/Maluma/Haw%C3%A1i
#      </a>
#      &gt;.
#     </p>
#    </div>
#    <div class="citation-footer">
#     <span>
#      Powered by
#      <a href="https://www.cite.me" rel="noopener noreferrer nofollow" target="_blank" title="Cite.Me">
#       CITE.ME
#      </a>
#     </span>
#     <a aria-label="Cite.Me" href="https://www.cite.me" rel="noopener noreferrer nofollow" target="_blank" title="Cite.Me">
#      <img alt="Cite.Me" height="18" loading="lazy" src="https://static.stands4.com/app_common/img/cite-me-gray.png" style="filter: grayscale(100%);" title="Cite.Me" width="18"/>
#     </a>
#    </div>
#   </section>
#  </div>
#  <div class="callout clearfix row">
#   <div>
#    <div class="callout-int">
#     <div class="row">
#      <div class="col-xs-12 col-sm-8">
#       <hgroup>
#        <h2>
#         Missing lyrics by Maluma?
#        </h2>
#        <h3>
#         Know any other songs by Maluma? Don't keep it to yourself!
#        </h3>
#       </hgroup>
#      </div>
#      <div class="col-xs-12 col-sm-4">
#       <div class="actions">
#        <button class="btn primary lrg" onclick="location.href='https://www.lyrics.com/addlyric.php?aid=2669415';" type="button">
#         Add it Here
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>

# %%
# obtiene el contenedor principal donde está la letra de la canción
job_elements_letra = results_letra_cancion.find_all("div", class_="lyric clearfix")
print(job_elements_letra)
# Out:
# [<div class="lyric clearfix">
# <div class="head-btns">
# <p class="print-style-icon">
# <span class="rc3 s fsize" title="Change text size"><span class="glyphicon glyphicon-text-size"></span></span>
# 							<a class="rc3 s" href="email.php?id=37493623&amp;type=lyric" target="_blank" title="click to email Hawái to a friend"><i class="fas fa-paper-plane"></i></a>
# 							<a class="rc3 s" href="print.php?id=37493623" target="_blank" title="click to send Hawái to your printer"><span class="glyphicon glyphicon-print"></span></a>
# 							<a class="add-to-list s rc3" href="/lyrics-pdf/37493623" title="click to down the Hawái lyrics as PDF"><i class="far fa-file-pdf"></i> PDF</a>
# 							<a class="rc3 s" href="sheetmusic.php?id=37493623" title="click for Hawái sheet music"><span class="glyphicon glyphicon-music" style="margin-left: -1px;"></span></a>
# 							<a class="rc3 s" href="/song-parody-maker/37493623" title="click to create a parody of this song"><b><i class="far fa-smile"></i></b></a>
# 							<a class="rc3 s" href="playlist.php?add=37493623&amp;sub=0" title="click to add Hawái to your playlist"><span class="glyphicon glyphicon-list"></span><span class="hidden-xs"> Playlist</span></a>
# 							<span class="audio tts-icon rc3 s" data-code="en-US" data-lang="Google US English" title="Hear this lyrics"><i aria-hidden="true" class="fas fa-volume-up"></i></span>
# 													</p>
# </div>
# <hgroup dir="ltr">
# <h1 class="lyric-title" id="lyric-title-text">Hawái</h1>
# <div class="mstore">
# <a href="https://music.apple.com/us/search?term=Haw%C3%A1i+by+Maluma" target="_blank" title="Listen to this song on Apple Music">
# <span class="shop"><i aria-hidden="true" class="fab fa-apple"></i></span>
# </a>
# <a class="store-amz" href="https://www.amazon.com/gp/search?index=digital-music&amp;keywords=Haw%C3%A1i+by+Maluma&amp;tag=stands4com-20" target="_blank" title="Listen to this song on Amazon">
# <span class="shop"><i aria-hidden="true" class="fab fa-amazon"></i></span>
# </a>
# <a href="https://www.amazon.com/gp/search?index=digital-music&amp;keywords=Haw%C3%A1i+by+Maluma&amp;tag=stands4com-20" target="_blank" title="Listen to this song on Amazon"><small>Listen online</small></a>
# </div>
# <h3 class="lyric-artist"><a href="artist/Maluma/2669415">Maluma</a></h3>
# </hgroup>
# <div class="lyric-infobox clearfix">
# <div class="artist-thumb" data-artist="Maluma" data-img="1" id="featured-artist-avatar">
# <a href="artist/Maluma/2669415" title="Maluma">
# <img alt="" height="125" loading="lazy" src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Maluma_-_Espaço_das_Américas_(37591053894).jpg/244px-Maluma_-_Espaço_das_Américas_(37591053894).jpg" style="margin-left:0;" title="Maluma" width="120"/>
# </a>
# <div class="wiki-credit"><span class="wiki-name hidden">Maluma</span><span data-type="2">Maluma <i class="fa-info-circle fas"></i></span></div> </div>
# <div class="artist-meta">
# <div class="flr"><p class="favorite-style-select" data-key="2669415" data-page="lyric">
# <button class="btn s" data-aid="2669415" data-sub="0" data-target="#login-modal" data-uid="" data-votes="2" id="artist-rate-btn" title="click to add your vote"><i aria-hidden="true" class="fas fa-star"></i> <span>FAVORITE</span></button>
# <span id="author-rate-votes" onclick="location.href='https://www.lyrics.com/artist-fans/2669415';">(2 fans)</span>
# </p></div>
# <h4><a href="artist/Maluma/2669415">Maluma</a></h4>
# <p class="bio">Juan Luis Londoño Arias (born 28 January 1994), known professionally as Maluma, is a Colombian singer, songwriter, and actor signed to Sony Music Colombia, Sony Latin and Fox Music. Born and raised in Medellín, he developed an interest in music at a young age, and began recording songs at age 16. He released his debut album, Magia, a year later in 2012. However, his breakthrough album was 2015's Pretty Boy, Dirty Boy, which led to successful collaborations with artists Thalía, Shakira and Ricky Martin. He released F.A.M.E. in 2018, to further commercial success. He followed it up with 11:11, released the next year. <a href="artist/Maluma/2669415">more »</a></p>
# </div>
# <br/>
# <div class="lyric-details">
# <input data-id="37493623" data-type="lyric" id="lyric-data" type="hidden"/>
# <dl>
# <dt><i aria-hidden="true" class="far fa-clock" title="Duration"></i></dt>
# <dd class="dd-margin">3:20</dd>
# <dt><i aria-hidden="true" class="far fa-eye"></i></dt>
# <dd class="c-views">74 <span class="hidden-xs">Views</span></dd>
# </dl>
# </div>
# </div>
# <div class="row">
# <div class="adunit-middle adunit-middle-2col clearfix">
# <div class="col-xs-12 col-sm-12"><div id="div-gpt-ad-Lyrics_IA_300x250_A">
# <script>
# doDisplay('div-gpt-ad-Lyrics_IA_300x250_A');
# </script>
# </div>
# <div id="div-gpt-ad-Lyrics_Mobile_IA_300x250_A">
# <script>
# doDisplay('div-gpt-ad-Lyrics_Mobile_IA_300x250_A');
# </script>
# </div></div>
# </div>
# </div>
# <script>
# /* Lyrics.net - TFP - Above */
# (function() {
#                 var opts = {
# 		                		artist: "",
# 		                        song: "",
#                                 adunit_id: 39384263,
#                                 div_id: "cf_async_" + Math.floor((Math.random() * 999999999))
#                 };
#                 document.write('<div id="'+opts.div_id+'"></div>');var c=function(){cf.showAsyncAd(opts)};if(window.cf)c();else{cf_async=!0;var r=document.createElement("script"),s=document.getElementsByTagName("script")[0];r.async=!0;r.src="https://srv.clickfuse.com/showads/showad.js";r.readyState?r.onreadystatechange=function(){if("loaded"==r.readyState||"complete"==r.readyState)r.onreadystatechange=null,c()}:r.onload=c;s.parentNode.insertBefore(r,s)};
# })();
# </script> <h3 class="lyric-artist text-center">
# <span style="font-weight: 700; font-size: 15px;">
# <a href="https://www.30daysinger.com/a/8328/LfArfDh6?utm_campaign=lyrics_top_link&amp;title=4" rel="nofollow" target="_blank"><i aria-hidden="true" class="fas fa-check" style="color: #666;"></i> Struggling with Hawái? Become a better singer <u>in 30 days</u> with these videos!</a>
# </span>
# </h3>
# <pre class="lyric-body" data-lang="en" dir="ltr" id="lyric-body-text">Deja de <a href="https://www.definitions.net/definition/mentirte" style="color:#222;">mentirte</a> (ah)
# La foto que <a href="https://www.definitions.net/definition/subiste" style="color:#222;">subiste</a> con él <a href="https://www.definitions.net/definition/diciendo" style="color:#222;">diciendo</a> que era tu cielo
# Bebé, yo te <a href="https://www.definitions.net/definition/conozco" style="color:#222;">conozco</a> tan bien, sé que fue pa' <a href="https://www.definitions.net/definition/darme" style="color:#222;">darme</a> celos
# No te diré quién, pero <a href="https://www.definitions.net/definition/llorando" style="color:#222;">llorando</a> por mí te vieron
# Por mí te vieron
#
# Déjame decirte
# Se ve que él te <a href="https://www.definitions.net/definition/trata" style="color:#222;">trata</a> bien, que es todo un caballero
# Pero eso no cambiará que yo llegué primero
# Sé que te va ir bien pero no te <a href="https://www.definitions.net/definition/quiere" style="color:#222;">quiere</a> como yo te quiero
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea como te va de bien, pero te <a href="https://www.definitions.net/definition/haces" style="color:#222;">haces</a> mal
# Porque el amor no se <a href="https://www.definitions.net/definition/compra" style="color:#222;">compra</a> na'
#
# Miéntele a <a href="https://www.definitions.net/definition/todos" style="color:#222;">todos</a> tus seguidore'
# Dile que los tiempo' de <a href="https://www.definitions.net/definition/ahora" style="color:#222;">ahora</a> son mejore'
# No creo que <a href="https://www.definitions.net/definition/cuando" style="color:#222;">cuando</a> te <a href="https://www.definitions.net/definition/llame" style="color:#222;">llame</a> me ignores
# Si después de mí ya no habrán más amores
#
# Tú y yo fuimo' uno
# Lo hacíamo' en ayuna' <a href="https://www.definitions.net/definition/antes" style="color:#222;">antes</a> del desayuno
# Fumábamo' la <a href="https://www.definitions.net/definition/hookah" style="color:#222;">hookah</a> y te <a href="https://www.definitions.net/definition/pasaba" style="color:#222;">pasaba</a> el humo
# Y <a href="https://www.definitions.net/definition/ahora" style="color:#222;">ahora</a> en esta <a href="https://www.definitions.net/definition/guerra" style="color:#222;">guerra</a> no gana ninguno
#
# Si me preguntas, <a href="https://www.definitions.net/definition/nadie" style="color:#222;">nadie</a> tiene culpa
# A vece' los <a href="https://www.definitions.net/definition/problemas" style="color:#222;">problemas</a> a uno se le juntan
# Déjame hablar, porfa, no me interrumpas
# Si te hice algo malo, <a href="https://www.definitions.net/definition/entonces" style="color:#222;">entonces</a> discúlpame
# La <a href="https://www.definitions.net/definition/gente" style="color:#222;">gente</a> te lo va a creer, actúas bien ese papel
# Baby, pero no eres <a href="https://www.definitions.net/definition/feliz" style="color:#222;">feliz</a> con él
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea
#
# Puede que no te haga <a href="https://www.definitions.net/definition/falta" style="color:#222;">falta</a> na', <a href="https://www.definitions.net/definition/aparentemente" style="color:#222;">aparentemente</a> na'
# Hawái de vacaciones, mis felicitaciones
# Muy <a href="https://www.definitions.net/definition/lindo" style="color:#222;">lindo</a> en <a href="https://www.definitions.net/definition/Instagram" style="color:#222;">Instagram</a> lo que posteas
# Pa' que yo vea como te va de bien, pero te <a href="https://www.definitions.net/definition/haces" style="color:#222;">haces</a> mal
# Porque el amor no se <a href="https://www.definitions.net/definition/compra" style="color:#222;">compra</a> na'
#
# (Deja de mentirte
# La foto que <a href="https://www.definitions.net/definition/subiste" style="color:#222;">subiste</a> con él <a href="https://www.definitions.net/definition/diciendo" style="color:#222;">diciendo</a> que era tu cielo)
# Mamacita
# (Bebé, yo te <a href="https://www.definitions.net/definition/conozco" style="color:#222;">conozco</a> tan bien, sé que fue pa' <a href="https://www.definitions.net/definition/darme" style="color:#222;">darme</a> celos)
#
# Maluma, baby
# (No te diré quién, pero <a href="https://www.definitions.net/definition/llorando" style="color:#222;">llorando</a> por mí te vieron)
# Jaja
# (Por mí te vieron)
# Papi Juancho</pre>
# <h3 class="lyric-artist text-center">
# <span style="font-weight: 700; font-size: 15px;">
# <a href="https://www.30daysinger.com/a/8328/LfArfDh6?utm_campaign=lyrics_bottom_link&amp;title=3" rel="nofollow" target="_blank"><i aria-hidden="true" class="fas fa-check" style="color: #666;"></i> The easy, fast &amp; fun way to learn how to sing: 30DaySinger.com</a>
# </span>
# </h3> <script>
# /* Lyrics.net - TFP - Below */
# (function() {
#                 var opts = {
#                                 artist: "",
#                                 song: "Hawái",
#                                 adunit_id: 39384264,
#                                 div_id: "cf_async_" + Math.floor((Math.random() * 999999999))
#                 };
#                 document.write('<div id="'+opts.div_id+'"></div>');var c=function(){cf.showAsyncAd(opts)};if(window.cf)c();else{cf_async=!0;var r=document.createElement("script"),s=document.getElementsByTagName("script")[0];r.async=!0;r.src="https://srv.clickfuse.com/showads/showad.js";r.readyState?r.onreadystatechange=function(){if("loaded"==r.readyState||"complete"==r.readyState)r.onreadystatechange=null,c()}:r.onload=c;s.parentNode.insertBefore(r,s)};
# })();
# </script>
# <div class="lyric-credits clearfix">
# <div class="head-btns">
# <p class="print-style-icon">
# <a class="rc3 s" href="sheetmusic.php?id=37493623" target="_blank" title="click for Hawái sheet music"><span class="glyphicon glyphicon-music" style="margin-left: -1px;"></span> Sheet Music</a>
# 								<a class="rc3 s" href="email.php?id=37493623&amp;type=lyric" target="_blank" title="click to email Hawái to a friend"><i class="fas fa-paper-plane"></i></a>
# 								<a class="rc3 s" href="print.php?id=37493623" target="_blank" title="click to send Hawái to your printer"><span class="glyphicon glyphicon-print"></span></a>
# 								<a class="add-to-list s rc3" href="/lyrics-pdf/37493623" title="click to down the Hawái lyrics as PDF"><i class="far fa-file-pdf"></i> PDF</a>
# 								<a class="rc3 s" href="/song-parody-maker/37493623" title="click to create a parody of this song"><b><i class="far fa-smile"></i></b></a>
# 								<a class="rc3 s" href="playlist.php?add=37493623&amp;sub=0" title="click to add Hawái to your playlist"><span class="glyphicon glyphicon-list"></span><span class="hidden-xs"> Playlist</span></a>
# 							</p>
# </div>
# <p>Written by: Andres Uribe Marin, Bryan Snaider Lezcano Chaverra, Edgar Barrera, Johan Espinosa, Juan Camilo Vargas Vasquez, Juan Luis Londono Arias, Kevin Mauricio Jimenez Londono, Kevyn Mauricio Cruz Moreno, Rene Cano, Stiven Rojas</p>
# <p>Lyrics © DistroKid, Universal Music Publishing Group, Sony/ATV Music Publishing LLC, Warner Chappell Music, Inc.</p>
# <p>Lyrics Licensed &amp; Provided by <a href="http://www.lyricfind.com" rel="nofollow">LyricFind</a></p>
# </div>
# </div>]

# %%
# obtiene la letra de la canción
for job_element in job_elements_letra:
    letra = job_element.find("pre", id="lyric-body-text")
print(letra.text)
# Out:
# Deja de mentirte (ah)
# La foto que subiste con él diciendo que era tu cielo
# Bebé, yo te conozco tan bien, sé que fue pa' darme celos
# No te diré quién, pero llorando por mí te vieron
# Por mí te vieron
#
# Déjame decirte
# Se ve que él te trata bien, que es todo un caballero
# Pero eso no cambiará que yo llegué primero
# Sé que te va ir bien pero no te quiere como yo te quiero
#
# Puede que no te haga falta na', aparentemente na'
# Hawái de vacaciones, mis felicitaciones
# Muy lindo en Instagram lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea
#
# Puede que no te haga falta na', aparentemente na'
# Hawái de vacaciones, mis felicitaciones
# Muy lindo en Instagram lo que posteas
# Pa' que yo vea como te va de bien, pero te haces mal
# Porque el amor no se compra na'
#
# Miéntele a todos tus seguidore'
# Dile que los tiempo' de ahora son mejore'
# No creo que cuando te llame me ignores
# Si después de mí ya no habrán más amores
#
# Tú y yo fuimo' uno
# Lo hacíamo' en ayuna' antes del desayuno
# Fumábamo' la hookah y te pasaba el humo
# Y ahora en esta guerra no gana ninguno
#
# Si me preguntas, nadie tiene culpa
# A vece' los problemas a uno se le juntan
# Déjame hablar, porfa, no me interrumpas
# Si te hice algo malo, entonces discúlpame
# La gente te lo va a creer, actúas bien ese papel
# Baby, pero no eres feliz con él
#
# Puede que no te haga falta na', aparentemente na'
# Hawái de vacaciones, mis felicitaciones
# Muy lindo en Instagram lo que posteas
# Pa' que yo vea cómo te va, pa' que yo vea
#
# Puede que no te haga falta na', aparentemente na'
# Hawái de vacaciones, mis felicitaciones
# Muy lindo en Instagram lo que posteas
# Pa' que yo vea como te va de bien, pero te haces mal
# Porque el amor no se compra na'
#
# (Deja de mentirte
# La foto que subiste con él diciendo que era tu cielo)
# Mamacita
# (Bebé, yo te conozco tan bien, sé que fue pa' darme celos)
#
# Maluma, baby
# (No te diré quién, pero llorando por mí te vieron)
# Jaja
# (Por mí te vieron)
# Papi Juancho
